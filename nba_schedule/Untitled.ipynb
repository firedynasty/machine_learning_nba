# %%
import pandas as pd

# %%
df = pd.read_csv('nba_schedule2021.csv')

# %%
df
# Out:
#                   Date  Start (ET)         Visitor/Neutral  PTS  \
# 0    Tue, Dec 22, 2020       7:00p   Golden State Warriors   99
# 1    Tue, Dec 22, 2020      10:00p    Los Angeles Clippers  116
# 2    Wed, Dec 23, 2020       7:00p       Charlotte Hornets  114
# 3    Wed, Dec 23, 2020       7:00p         New York Knicks  107
# 4    Wed, Dec 23, 2020       7:00p              Miami Heat  107
# 5    Wed, Dec 23, 2020       7:00p      Washington Wizards  107
# 6    Wed, Dec 23, 2020       7:30p    New Orleans Pelicans  113
# 7    Wed, Dec 23, 2020       7:30p         Milwaukee Bucks  121
# 8    Wed, Dec 23, 2020       8:00p           Atlanta Hawks  124
# 9    Wed, Dec 23, 2020       8:00p       San Antonio Spurs  131
# 10   Wed, Dec 23, 2020       8:00p         Detroit Pistons  101
# 11   Wed, Dec 23, 2020       9:00p        Sacramento Kings  124
# 12   Wed, Dec 23, 2020      10:00p               Utah Jazz  120
# 13   Wed, Dec 23, 2020      10:30p        Dallas Mavericks  102
# ...

# %%
df.head(100)
# Out:
#                  Date  Start (ET)         Visitor/Neutral  PTS  \
# 0   Tue, Dec 22, 2020       7:00p   Golden State Warriors   99
# 1   Tue, Dec 22, 2020      10:00p    Los Angeles Clippers  116
# 2   Wed, Dec 23, 2020       7:00p       Charlotte Hornets  114
# 3   Wed, Dec 23, 2020       7:00p         New York Knicks  107
# 4   Wed, Dec 23, 2020       7:00p              Miami Heat  107
# 5   Wed, Dec 23, 2020       7:00p      Washington Wizards  107
# 6   Wed, Dec 23, 2020       7:30p    New Orleans Pelicans  113
# 7   Wed, Dec 23, 2020       7:30p         Milwaukee Bucks  121
# 8   Wed, Dec 23, 2020       8:00p           Atlanta Hawks  124
# 9   Wed, Dec 23, 2020       8:00p       San Antonio Spurs  131
# 10  Wed, Dec 23, 2020       8:00p         Detroit Pistons  101
# 11  Wed, Dec 23, 2020       9:00p        Sacramento Kings  124
# 12  Wed, Dec 23, 2020      10:00p               Utah Jazz  120
# 13  Wed, Dec 23, 2020      10:30p        Dallas Mavericks  102
# ...

# %%
pd.set_option('max_rows', None)

# %%
df.head(100)
# Out:
#                  Date  Start (ET)         Visitor/Neutral  PTS  \
# 0   Tue, Dec 22, 2020       7:00p   Golden State Warriors   99
# 1   Tue, Dec 22, 2020      10:00p    Los Angeles Clippers  116
# 2   Wed, Dec 23, 2020       7:00p       Charlotte Hornets  114
# 3   Wed, Dec 23, 2020       7:00p         New York Knicks  107
# 4   Wed, Dec 23, 2020       7:00p              Miami Heat  107
# 5   Wed, Dec 23, 2020       7:00p      Washington Wizards  107
# 6   Wed, Dec 23, 2020       7:30p    New Orleans Pelicans  113
# 7   Wed, Dec 23, 2020       7:30p         Milwaukee Bucks  121
# 8   Wed, Dec 23, 2020       8:00p           Atlanta Hawks  124
# 9   Wed, Dec 23, 2020       8:00p       San Antonio Spurs  131
# 10  Wed, Dec 23, 2020       8:00p         Detroit Pistons  101
# 11  Wed, Dec 23, 2020       9:00p        Sacramento Kings  124
# 12  Wed, Dec 23, 2020      10:00p               Utah Jazz  120
# 13  Wed, Dec 23, 2020      10:30p        Dallas Mavericks  102
# ...

# %%
df = df.loc[df['Date'] != 'Date']

# %%
df = df.dropna(how='all')

# %%
# Out:
#                   Date Start (ET)         Visitor/Neutral  PTS  \
# 0    Tue, Dec 22, 2020      7:00p   Golden State Warriors   99
# 1    Tue, Dec 22, 2020     10:00p    Los Angeles Clippers  116
# 2    Wed, Dec 23, 2020      7:00p       Charlotte Hornets  114
# 3    Wed, Dec 23, 2020      7:00p         New York Knicks  107
# 4    Wed, Dec 23, 2020      7:00p              Miami Heat  107
# 5    Wed, Dec 23, 2020      7:00p      Washington Wizards  107
# 6    Wed, Dec 23, 2020      7:30p    New Orleans Pelicans  113
# 7    Wed, Dec 23, 2020      7:30p         Milwaukee Bucks  121
# 8    Wed, Dec 23, 2020      8:00p           Atlanta Hawks  124
# 9    Wed, Dec 23, 2020      8:00p       San Antonio Spurs  131
# 10   Wed, Dec 23, 2020      8:00p         Detroit Pistons  101
# 11   Wed, Dec 23, 2020      9:00p        Sacramento Kings  124
# 12   Wed, Dec 23, 2020     10:00p               Utah Jazz  120
# 13   Wed, Dec 23, 2020     10:30p        Dallas Mavericks  102
# ...

# %% [markdown]
# Tutorial ESCAPE
#
# ```
# data.loc[data.index != "Colorado"]
# ```
