# %%
import pandas as pd
diff_df = pd.read_csv('diff_df_feb_24.csv')

# %%
grouped_df = pd.read_csv('grouped_feb_24.csv')

# %%
diff_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home   PTS_away     MARGIN  \
# 0  2022-02-24       DET          CLE  0.975000  -4.262500   5.237500
# 1  2022-02-24       BRK          BOS -8.500000   8.300000 -16.800000
# 2  2022-02-24       CHI          ATL  1.757143  -2.941429   4.698571
# 3  2022-02-24       MIN          MEM  1.421429  -3.242857   4.664286
# 4  2022-02-24       OKC          PHO -9.700000   3.800000 -13.500000
# 5  2022-02-24       POR          GSW -5.760000 -10.500000   4.740000
# 6  2022-02-24       SAC          DEN -4.933333   1.403333  -6.336667
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.008250     0.043875      0.033300    -0.027850    -0.096113
# 1    -0.026275    -0.006500     -0.090800     0.025300     0.010000
# 2     0.022857    -0.026150      0.022029    -0.000027    -0.008916
# 3    -0.001386    -0.005729      0.014157    -0.025000     0.004500
# 4    -0.038400    -0.031300     -0.015400    -0.008500    -0.028600
# ...

# %%
grouped_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-02-24       DET          CLE     109.4     107.6     1.8       0.4495
# 1  2022-02-24       BRK          BOS     108.0     111.7    -3.7       0.4563
# 2  2022-02-24       CHI          ATL     120.1     111.4     8.7       0.5225
# 3  2022-02-24       MIN          MEM     114.0     119.7    -5.7       0.4553
# 4  2022-02-24       OKC          PHO     100.8     113.2   -12.4       0.4170
# 5  2022-02-24       POR          GSW     105.2     108.5    -3.3       0.4371
# 6  2022-02-24       SAC          DEN     117.5     111.9     5.6       0.4846
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.7835        0.3392       0.4880       0.7338        0.3570
# 1       0.7949        0.3126       0.4802       0.8170        0.3739
# 2       0.8399        0.3714       0.4548       0.8400        0.3415
# ...

# %%
date1 = grouped_df['DATE']
home_abbr1 = grouped_df['HOME_ABBR']
visitor_abbr1 = grouped_df['VISITOR_ABBR']
home_winning_percentage = grouped_df['home_winning_percentage']
visitor_winning_percentage = grouped_df['visitor_winning_percentage']
diff = grouped_df['diff_%']

# %%
grouped_df = grouped_df.drop('visitor_winning_percentage', 1)

# %%
grouped_df
# Out:
#    PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0     109.4     107.6     1.8       0.4495       0.7835        0.3392
# 1     108.0     111.7    -3.7       0.4563       0.7949        0.3126
# 2     120.1     111.4     8.7       0.5225       0.8399        0.3714
# 3     114.0     119.7    -5.7       0.4553       0.7331        0.3466
# 4     100.8     113.2   -12.4       0.4170       0.7777        0.3204
# 5     105.2     108.5    -3.3       0.4371       0.7272        0.3505
# 6     117.5     111.9     5.6       0.4846       0.7827        0.3820
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.4880       0.7338        0.3570
# 1       0.4802       0.8170        0.3739
# 2       0.4548       0.8400        0.3415
# 3       0.4689       0.6748        0.3206
# 4       0.4895       0.7841        0.3181
# 5       0.4451       0.8052        0.3639
# 6       0.4732       0.8259        0.3509

# %%
grouped_df = grouped_df.drop('diff_%', 1)

# %%
grouped_df = grouped_df.drop('DATE', 1)
grouped_df = grouped_df.drop('HOME_ABBR', 1)
grouped_df = grouped_df.drop('VISITOR_ABBR', 1)
grouped_df = grouped_df.drop('home_winning_percentage', 1)
grouped_df = grouped_df.drop('visitor_winning_percentage', 1)
grouped_df = grouped_df.drop('diff_%', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-11bda5494977> in <module>
#       3 grouped_df = grouped_df.drop('VISITOR_ABBR', 1)
#       4 grouped_df = grouped_df.drop('home_winning_percentage', 1)
# ----> 5 grouped_df = grouped_df.drop('visitor_percentage', 1)
#       6 grouped_df = grouped_df.drop('diff_%', 1)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4108                 weight  1.0     0.8
#    4109         """
# -> 4110         return super().drop(
#    4111             labels=labels,
#    4112             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
diff_df = diff_df.drop('DATE', 1)
diff_df = diff_df.drop('HOME_ABBR', 1)
diff_df = diff_df.drop('VISITOR_ABBR', 1)

# %%
diff_df
# Out:
#    PTS_home   PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  0.975000  -4.262500   5.237500     0.008250     0.043875      0.033300
# 1 -8.500000   8.300000 -16.800000    -0.026275    -0.006500     -0.090800
# 2  1.757143  -2.941429   4.698571     0.022857    -0.026150      0.022029
# 3  1.421429  -3.242857   4.664286    -0.001386    -0.005729      0.014157
# 4 -9.700000   3.800000 -13.500000    -0.038400    -0.031300     -0.015400
# 5 -5.760000 -10.500000   4.740000    -0.023180    -0.057680     -0.021340
# 6 -4.933333   1.403333  -6.336667    -0.016717     0.013433     -0.041750
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0    -0.027850    -0.096113     -0.004075
# 1     0.025300     0.010000      0.060100
# 2    -0.000027    -0.008916     -0.004469
# 3    -0.025000     0.004500     -0.000679
# 4    -0.008500    -0.028600     -0.001600
# 5    -0.004700    -0.043400     -0.077500
# 6    -0.000007     0.014913     -0.010133

# %%
combined_df = diff_df + grouped_df

# %%
combined_df
# Out:
#      PTS_home    PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  110.375000  103.337500   7.037500     0.457750     0.827375      0.372500
# 1   99.500000  120.000000 -20.500000     0.430025     0.788400      0.221800
# 2  121.857143  108.458571  13.398571     0.545357     0.813750      0.393429
# 3  115.421429  116.457143  -1.035714     0.453914     0.727371      0.360757
# 4   91.100000  117.000000 -25.900000     0.378600     0.746400      0.305000
# 5   99.440000   98.000000   1.440000     0.413920     0.669520      0.329160
# 6  112.566667  113.303333  -0.736667     0.467883     0.796133      0.340250
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0     0.460150     0.637687      0.352925
# 1     0.505500     0.827000      0.434000
# 2     0.454773     0.831084      0.337031
# 3     0.443900     0.679300      0.319921
# 4     0.481000     0.755500      0.316500
# 5     0.440400     0.761800      0.286400
# 6     0.473193     0.840813      0.340767

# %%
combined_df['DATE'] = date1
combined_df['HOME_ABBR'] = home_abbr1
combined_df['VISITOR_ABBR'] = visitor_abbr1
combined_df['home_winning_percentage'] = home_winning_percentage
combined_df['visitor_winning_percentage'] = visitor_winning_percentage
combined_df['diff_%'] = diff

# %%
combined_df.columns
# Out:
# Index(['PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'DATE',
#        'HOME_ABBR', 'VISITOR_ABBR', 'home_winning_percentage',
#        'visitor_winning_percentage', 'diff_%'],
#       dtype='object')

# %%
combined_df = combined_df[['DATE','HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away','home_winning_percentage',
       'visitor_winning_percentage', 'diff_%']]

# %%
diff_df
# Out:
#    PTS_home   PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  0.975000  -4.262500   5.237500     0.008250     0.043875      0.033300
# 1 -8.500000   8.300000 -16.800000    -0.026275    -0.006500     -0.090800
# 2  1.757143  -2.941429   4.698571     0.022857    -0.026150      0.022029
# 3  1.421429  -3.242857   4.664286    -0.001386    -0.005729      0.014157
# 4 -9.700000   3.800000 -13.500000    -0.038400    -0.031300     -0.015400
# 5 -5.760000 -10.500000   4.740000    -0.023180    -0.057680     -0.021340
# 6 -4.933333   1.403333  -6.336667    -0.016717     0.013433     -0.041750
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0    -0.027850    -0.096113     -0.004075
# 1     0.025300     0.010000      0.060100
# 2    -0.000027    -0.008916     -0.004469
# 3    -0.025000     0.004500     -0.000679
# 4    -0.008500    -0.028600     -0.001600
# 5    -0.004700    -0.043400     -0.077500
# 6    -0.000007     0.014913     -0.010133

# %%
grouped_df
# Out:
#    PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0     109.4     107.6     1.8       0.4495       0.7835        0.3392
# 1     108.0     111.7    -3.7       0.4563       0.7949        0.3126
# 2     120.1     111.4     8.7       0.5225       0.8399        0.3714
# 3     114.0     119.7    -5.7       0.4553       0.7331        0.3466
# 4     100.8     113.2   -12.4       0.4170       0.7777        0.3204
# 5     105.2     108.5    -3.3       0.4371       0.7272        0.3505
# 6     117.5     111.9     5.6       0.4846       0.7827        0.3820
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.4880       0.7338        0.3570
# 1       0.4802       0.8170        0.3739
# 2       0.4548       0.8400        0.3415
# 3       0.4689       0.6748        0.3206
# 4       0.4895       0.7841        0.3181
# 5       0.4451       0.8052        0.3639
# 6       0.4732       0.8259        0.3509

# %%
combined_df.to_csv('for_ml_feb_24.csv', index=False)

# %%
date1 = grouped_df['DATE']
home_abbr1 = grouped_df['HOME_ABBR']
visitor_abbr1 = grouped_df['VISITOR_ABBR']
home_winning_percentage = grouped_df['home_winning_percentage']
visitor_winning_percentage = grouped_df['visitor_winning_percentage']
diff = grouped_df['diff_%']
