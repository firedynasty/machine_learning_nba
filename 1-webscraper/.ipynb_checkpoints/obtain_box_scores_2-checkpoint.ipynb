# %%
import pandas as pd
box_score_df = pd.read_csv('scraped_box_scores/03_01_box_score.csv')

# %%
pwd
# Out:
# '/Users/stanleytan/Documents/ucb/ucb_/33-prev_projects/stack/4-Project/inclass/3rd_project_tied_4th/first_step/machine_learning_nba/1-webscraper'

# %%
user_input = input('required to get the latest boxscores')
# Out:
# required to get the latest boxscores

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0)

# adding winning percentage for another
# df = pd.read_csv('old_data/abbr_games.csv')

box_score_df["DATE"]= pd.to_datetime(box_score_df["DATE"])
box_score_df['PTS_home'] = pd.to_numeric(box_score_df['PTS_home'])
box_score_df['PTS_away'] = pd.to_numeric(box_score_df['PTS_away'])
box_score_df['MARGIN'] = pd.to_numeric(box_score_df['MARGIN'])
box_score_df['HOME_TEAM_WINS'] = pd.to_numeric(box_score_df['HOME_TEAM_WINS'])
box_score_df['FG_PCT_home'] = pd.to_numeric(box_score_df['FG_PCT_home'])
box_score_df['FT_PCT_home'] = pd.to_numeric(box_score_df['FT_PCT_home'])
box_score_df['FG3_PCT_home'] = pd.to_numeric(box_score_df['FG3_PCT_home'])
box_score_df['AST_home'] = pd.to_numeric(box_score_df['AST_home'])
box_score_df['REB_home'] = pd.to_numeric(box_score_df['REB_home'])
box_score_df['FG_PCT_away'] = pd.to_numeric(box_score_df['FG_PCT_away'])
box_score_df['FT_PCT_away'] = pd.to_numeric(box_score_df['FT_PCT_away'])
box_score_df['FG3_PCT_away'] = pd.to_numeric(box_score_df['FG3_PCT_away'])
box_score_df['AST_away'] = pd.to_numeric(box_score_df['AST_away'])
box_score_df['REB_away'] = pd.to_numeric(box_score_df['REB_away'])

box_score_df = box_score_df.reset_index(drop=True)

home_winning_percentage_list = []
visitor_winning_percentage_list = []
for ind in box_score_df.index:
    home_abbr = box_score_df.loc[ind]['HOME_ABBR']
    visitor_abbr = box_score_df.loc[ind]['VISITOR_ABBR']
    home_team_wins = box_score_df.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)
box_score_df['home_winning_percentage'] = home_winning_percentage_list
box_score_df['visitor_winning_percentage'] = visitor_winning_percentage_list

# adding the winning_percentages to the boxscore

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 915 2022-03-01       BOS          ATL       107        98       9
# 916 2022-03-01       TOR          BRK       109       108       1
# 917 2022-03-01       HOU          LAC       100       113     -13
# 918 2022-03-01       MIN          GSW       129       114      15
# 919 2022-03-01       LAL          DAL       104       109      -5
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
#schedule_df_dropped_dup = pd.read_csv('schedule_df_dropped_duplicates.csv')
# is this necessary?
# this creates a list of dates to create group and get the mean of the previous game scores.

# %%
#from basketball_reference_scraper.seasons import get_schedule, get_standings

#schedule_df = get_schedule(2022, playoffs=False)

# is this necessary? instead read it
#schedule_df.to_csv('basketball_reference_schedule_2022.csv', index=False)

#adjustment
#schedule_df = schedule_df.fillna(0)

# %%
schedule_df = pd.read_csv('data/basketball_reference_schedule_2022.csv')

# %%
schedule_df = schedule_df.loc[schedule_df['DATE'] >= '2021-11-15']

# %%
schedule_df = schedule_df.loc[schedule_df['DATE'] <= '2022-03-01']

# %%
user_input = input('this schedule will be used to get the grouped_by_date df')
# Out:
# this schedule will be used to get the grouped_by_date df

# %%
schedule_df = schedule_df.drop_duplicates(subset=['DATE'])

# %%
schedule_df = schedule_df.reset_index(drop=True)

# %%
date_list = schedule_df['DATE'].tolist()

# %%
#len(date_list)
#date_list[91:93]

#notes

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 909 2022-02-28       BRK          TOR        97       133     -36
# 910 2022-02-28       MIA          CHI       112        99      13
# 911 2022-02-28       MEM          SAS       118       105      13
# 912 2022-02-28       MIL          CHO       130       106      24
# 913 2022-02-28       OKC          SAC       110       131     -21
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
box_score_df["DATE"]= pd.to_datetime(box_score_df["DATE"])
box_score_df['PTS_home'] = pd.to_numeric(box_score_df['PTS_home'])
box_score_df['PTS_away'] = pd.to_numeric(box_score_df['PTS_away'])
box_score_df['MARGIN'] = pd.to_numeric(box_score_df['MARGIN'])
box_score_df['HOME_TEAM_WINS'] = pd.to_numeric(box_score_df['HOME_TEAM_WINS'])
box_score_df['FG_PCT_home'] = pd.to_numeric(box_score_df['FG_PCT_home'])
box_score_df['FT_PCT_home'] = pd.to_numeric(box_score_df['FT_PCT_home'])
box_score_df['FG3_PCT_home'] = pd.to_numeric(box_score_df['FG3_PCT_home'])
box_score_df['AST_home'] = pd.to_numeric(box_score_df['AST_home'])
box_score_df['REB_home'] = pd.to_numeric(box_score_df['REB_home'])
box_score_df['FG_PCT_away'] = pd.to_numeric(box_score_df['FG_PCT_away'])
box_score_df['FT_PCT_away'] = pd.to_numeric(box_score_df['FT_PCT_away'])
box_score_df['FG3_PCT_away'] = pd.to_numeric(box_score_df['FG3_PCT_away'])
box_score_df['AST_away'] = pd.to_numeric(box_score_df['AST_away'])
box_score_df['REB_away'] = pd.to_numeric(box_score_df['REB_away'])
box_score_df['home_winning_percentage'] = pd.to_numeric(box_score_df['home_winning_percentage'])
box_score_df['visitor_winning_percentage'] = pd.to_numeric(box_score_df['visitor_winning_percentage'])

# %%
group_by_date_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'home_winning_percentage', 'visitor_winning_percentage']
group_by_date_df = pd.DataFrame(columns=group_by_date_columns)


for j in date_list:
    obtain_ten_df_2 = box_score_df[box_score_df['DATE'] == j]
    for ind in obtain_ten_df_2.index:
        empty_ = []
        date_1 = obtain_ten_df_2.loc[ind]['DATE']
        home_1 = obtain_ten_df_2.loc[ind]['HOME_ABBR']
        visitor_1 = obtain_ten_df_2.loc[ind]['VISITOR_ABBR']
        empty_.append(date_1)
        empty_.append(home_1)
        empty_.append(visitor_1)
        home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] == home_1].tail(10).mean().reset_index()
        home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
        visitor_df_group_by = box_score_df.loc[box_score_df['VISITOR_ABBR'] == visitor_1].tail(10).mean().reset_index()
        visitor_df_dict = dict(zip(visitor_df_group_by.iloc[:,0].tolist(), visitor_df_group_by.iloc[:,1].tolist()))
        empty_.append(home_df_dict['PTS_home'])
        empty_.append(visitor_df_dict['PTS_away'])
        margin = home_df_dict['PTS_home'] - visitor_df_dict['PTS_away']
        empty_.append(margin)
        empty_.append(home_df_dict['FG_PCT_home'])
        empty_.append(home_df_dict['FT_PCT_home'])
        empty_.append(home_df_dict['FG3_PCT_home'])
        empty_.append(visitor_df_dict['FG_PCT_away'])
        empty_.append(visitor_df_dict['FT_PCT_away'])
        empty_.append(visitor_df_dict['FG3_PCT_away'])
        empty_.append(obtain_ten_df_2.loc[ind]['home_winning_percentage'])
        empty_.append(obtain_ten_df_2.loc[ind]['visitor_winning_percentage'])
        length_of_df = len(group_by_date_df)
        group_by_date_df.loc[length_of_df] = empty_

# %%
group_by_date_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-11-15       CLE          BOS     105.0     112.9    -7.9
# 1   2021-11-15       DET          SAC     107.4     107.4     0.0
# 2   2021-11-15       WAS          NOP     108.2     108.0     0.2
# 3   2021-11-15       ATL          ORL     120.4     108.6    11.8
# 4   2021-11-15       NYK          IND     106.0     108.5    -2.5
# ..         ...       ...          ...       ...       ...     ...
# 717 2022-03-01       BOS          ATL     110.5     108.1     2.4
# 718 2022-03-01       TOR          BRK     113.2     109.1     4.1
# 719 2022-03-01       HOU          LAC     107.6     107.1     0.5
# 720 2022-03-01       MIN          GSW     119.6     112.7     6.9
# 721 2022-03-01       LAL          DAL     106.8     108.6    -1.8
#
#      FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0         0.4621       0.7458        0.3372       0.4784       0.7998
# ...

# %%
user_input = input('adjust so accordingly, the number of rows is the same : box_score_df and grouped_by_date_df')
# Out:
# adjust so accordingly, the number of rows is the same : box_score_df and grouped_by_date_df

# %%
box_score_df = box_score_df.loc[box_score_df['DATE'] >= '2021-11-15']
box_score_df = box_score_df.loc[box_score_df['DATE'] <= '2022-03-01']

# at this point already have group_by_date_df
#################

# %%
user_input = input('do the dataframes match, new_box_score and grouped_by_date_df?')
# Out:
# do the dataframes match, new_box_score and grouped_by_date_df?

# %%
len(box_score_df)
# Out:
# 722

# %%
len(group_by_date_df)
# Out:
# 722

# %%
new_box_score = box_score_df.copy()
#the tail is the length of the group_by_date_df
new_box_score = new_box_score.reset_index(drop=True)
new_box_score.tail(1)
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 721 2022-03-01       LAL          DAL       104       109      -5
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 721               0        0.451          0.8         0.412        22
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 721        37          0.5         0.63         0.286        24        45
#
#      home_winning_percentage  visitor_winning_percentage
# 721                 0.442623                    0.596774

# %%
group_by_date_df.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away',
#        'FT_PCT_away', 'FG3_PCT_away', 'home_winning_percentage',
#        'visitor_winning_percentage'],
#       dtype='object')

# %%
new_box_score.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home',
#        'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'home_winning_percentage',
#        'visitor_winning_percentage'],
#       dtype='object')

# %%
date1 = group_by_date_df['DATE']
home_abbr1 = group_by_date_df['HOME_ABBR']
visitor_abbr1 = group_by_date_df['VISITOR_ABBR']
home_winning_percentage = group_by_date_df['home_winning_percentage']
visitor_winning_percentage = group_by_date_df['visitor_winning_percentage']

# %%
group_by_date_df = group_by_date_df.drop('DATE', 1)
group_by_date_df = group_by_date_df.drop('HOME_ABBR', 1)
group_by_date_df = group_by_date_df.drop('VISITOR_ABBR', 1)
group_by_date_df = group_by_date_df.drop('home_winning_percentage', 1)
group_by_date_df = group_by_date_df.drop('visitor_winning_percentage', 1)

# %%
new_box_score.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home',
#        'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'home_winning_percentage',
#        'visitor_winning_percentage'],
#       dtype='object')

# %%
new_box_score = new_box_score.drop('DATE', 1)
new_box_score = new_box_score.drop('HOME_ABBR', 1)
new_box_score = new_box_score.drop('VISITOR_ABBR', 1)
new_box_score = new_box_score.drop('home_winning_percentage', 1)
new_box_score = new_box_score.drop('visitor_winning_percentage', 1)
new_box_score = new_box_score.drop('HOME_TEAM_WINS', 1)
new_box_score = new_box_score.drop('AST_home', 1)
new_box_score = new_box_score.drop('REB_home', 1)
new_box_score = new_box_score.drop('AST_away', 1)
new_box_score = new_box_score.drop('REB_away', 1)

# %%
new_box_score.head(1)
# Out:
#    PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0        92        98      -6        0.386         0.75           0.4
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0        0.462          0.8         0.345

# %%
group_by_date_df
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0       105.0     112.9    -7.9       0.4621       0.7458        0.3372
# 1       107.4     107.4     0.0       0.4386       0.7811        0.3202
# 2       108.2     108.0     0.2       0.4616       0.8096        0.3263
# 3       120.4     108.6    11.8       0.5212       0.7941        0.4002
# 4       106.0     108.5    -2.5       0.4300       0.7380        0.3409
# ..        ...       ...     ...          ...          ...           ...
# 717     110.5     108.1     2.4       0.4725       0.8218        0.3407
# 718     113.2     109.1     4.1       0.4619       0.7777        0.3863
# 719     107.6     107.1     0.5       0.4437       0.6661        0.3382
# 720     119.6     112.7     6.9       0.4718       0.7590        0.3609
# 721     106.8     108.6    -1.8       0.4526       0.7092        0.3144
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0         0.4784       0.7998        0.3571
# ...

# %%
group_by_date_df.head(1)
# Out:
#    PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0     104.6     114.1    -9.5       0.4665       0.7188        0.3287
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.4868       0.7988        0.3766

# %%
new_box_score.columns
# Out:
# Index(['PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away'],
#       dtype='object')

# %%
group_by_date_df['PTS_home'] = pd.to_numeric(group_by_date_df['PTS_home'])
group_by_date_df['PTS_away'] = pd.to_numeric(group_by_date_df['PTS_away'])
group_by_date_df['MARGIN'] = pd.to_numeric(group_by_date_df['MARGIN'])
group_by_date_df['FG_PCT_home'] = pd.to_numeric(group_by_date_df['FG_PCT_home'])
group_by_date_df['FT_PCT_home'] = pd.to_numeric(group_by_date_df['FT_PCT_home'])
group_by_date_df['FG3_PCT_home'] = pd.to_numeric(group_by_date_df['FG3_PCT_home'])
group_by_date_df['FG_PCT_away'] = pd.to_numeric(group_by_date_df['FG_PCT_away'])
group_by_date_df['FT_PCT_away'] = pd.to_numeric(group_by_date_df['FT_PCT_away'])
group_by_date_df['FG3_PCT_away'] = pd.to_numeric(group_by_date_df['FG3_PCT_away'])

# %%
new_box_score['PTS_home'] = pd.to_numeric(new_box_score['PTS_home'])
new_box_score['PTS_away'] = pd.to_numeric(new_box_score['PTS_away'])
new_box_score['MARGIN'] = pd.to_numeric(new_box_score['MARGIN'])
new_box_score['FG_PCT_home'] = pd.to_numeric(new_box_score['FG_PCT_home'])
new_box_score['FT_PCT_home'] = pd.to_numeric(new_box_score['FT_PCT_home'])
new_box_score['FG3_PCT_home'] = pd.to_numeric(new_box_score['FG3_PCT_home'])
new_box_score['FG_PCT_away'] = pd.to_numeric(new_box_score['FG_PCT_away'])
new_box_score['FT_PCT_away'] = pd.to_numeric(new_box_score['FT_PCT_away'])
new_box_score['FG3_PCT_away'] = pd.to_numeric(new_box_score['FG3_PCT_away'])

# %%
group_by_date_df.columns
# Out:
# Index(['PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away'],
#       dtype='object')

# %%
new_box_score.columns
# Out:
# Index(['PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away'],
#       dtype='object')

# %%
new_box_score
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0          92        98      -6        0.386        0.750         0.400
# 1         107       129     -22        0.406        0.941         0.277
# 2         105       100       5        0.464        0.680         0.357
# 3         129       111      18        0.553        0.656         0.467
# 4          92        84       8        0.430        0.700         0.324
# ..        ...       ...     ...          ...          ...           ...
# 717       107        98       9        0.470        0.947         0.314
# 718       109       108       1        0.456        0.870         0.304
# 719       100       113     -13        0.396        0.647         0.333
# 720       129       114      15        0.528        0.826         0.400
# 721       104       109      -5        0.451        0.800         0.412
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0          0.462        0.800         0.345
# ...

# %%
group_by_date_df
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0       105.0     112.9    -7.9       0.4621       0.7458        0.3372
# 1       107.4     107.4     0.0       0.4386       0.7811        0.3202
# 2       108.2     108.0     0.2       0.4616       0.8096        0.3263
# 3       120.4     108.6    11.8       0.5212       0.7941        0.4002
# 4       106.0     108.5    -2.5       0.4300       0.7380        0.3409
# ..        ...       ...     ...          ...          ...           ...
# 717     110.5     108.1     2.4       0.4725       0.8218        0.3407
# 718     113.2     109.1     4.1       0.4619       0.7777        0.3863
# 719     107.6     107.1     0.5       0.4437       0.6661        0.3382
# 720     119.6     112.7     6.9       0.4718       0.7590        0.3609
# 721     106.8     108.6    -1.8       0.4526       0.7092        0.3144
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0         0.4784       0.7998        0.3571
# ...

# %%
calculated_df = new_box_score - group_by_date_df

# %%
calculated_df
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0       -13.0     -14.9     1.9      -0.0761       0.0042        0.0628
# 1        -0.4      21.6   -22.0      -0.0326       0.1599       -0.0432
# 2        -3.2      -8.0     4.8       0.0024      -0.1296        0.0307
# 3         8.6       2.4     6.2       0.0318      -0.1381        0.0668
# 4       -14.0     -24.5    10.5       0.0000      -0.0380       -0.0169
# ..        ...       ...     ...          ...          ...           ...
# 717      -3.5     -10.1     6.6      -0.0025       0.1252       -0.0267
# 718      -4.2      -1.1    -3.1      -0.0059       0.0923       -0.0823
# 719      -7.6       5.9   -13.5      -0.0477      -0.0191       -0.0052
# 720       9.4       1.3     8.1       0.0562       0.0670        0.0391
# 721      -2.8       0.4    -3.2      -0.0016       0.0908        0.0976
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0        -0.0164       0.0002       -0.0121
# ...

# %%
date1
# Out:
# 0     2021-11-15
# 1     2021-11-15
# 2     2021-11-15
# 3     2021-11-15
# 4     2021-11-15
#          ...
# 711   2022-02-28
# 712   2022-02-28
# 713   2022-02-28
# 714   2022-02-28
# 715   2022-02-28
# Name: DATE, Length: 716, dtype: datetime64[ns]

# %%
home_abbr1
# Out:
# 0      CLE
# 1      DET
# 2      WAS
# 3      ATL
# 4      NYK
#       ...
# 711    BRK
# 712    MIA
# 713    MEM
# 714    MIL
# 715    OKC
# Name: HOME_ABBR, Length: 716, dtype: object

# %%
calculated_df['DATE'] = date1
calculated_df['HOME_ABBR'] = home_abbr1
calculated_df['VISITOR_ABBR'] = visitor_abbr1
calculated_df['home_winning_percentage'] = home_winning_percentage
calculated_df['visitor_winning_percentage'] = visitor_winning_percentage

# %%
calculated_df = calculated_df[['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'home_winning_percentage',
       'visitor_winning_percentage']]

# %%
calculated_df
#calculated_df is the subtracted from box_score
# then it will be grouped and then that will will averaged to be subtracted from the group_by_date_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-11-15       CLE          BOS     -13.0     -14.9     1.9
# 1   2021-11-15       DET          SAC      -0.4      21.6   -22.0
# 2   2021-11-15       WAS          NOP      -3.2      -8.0     4.8
# 3   2021-11-15       ATL          ORL       8.6       2.4     6.2
# 4   2021-11-15       NYK          IND     -14.0     -24.5    10.5
# ..         ...       ...          ...       ...       ...     ...
# 717 2022-03-01       BOS          ATL      -3.5     -10.1     6.6
# 718 2022-03-01       TOR          BRK      -4.2      -1.1    -3.1
# 719 2022-03-01       HOU          LAC      -7.6       5.9   -13.5
# 720 2022-03-01       MIN          GSW       9.4       1.3     8.1
# 721 2022-03-01       LAL          DAL      -2.8       0.4    -3.2
#
#      FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0        -0.0761       0.0042        0.0628      -0.0164       0.0002
# ...

# %%
season_schedule_df = pd.read_csv('data/basketball_reference_schedule_2022.csv')
# this is the full schedule with all the games

# %%
season_schedule_df
# Out:
#             DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0     2021-10-19          Brooklyn Nets        104.0      Milwaukee Bucks
# 1     2021-10-19  Golden State Warriors        121.0   Los Angeles Lakers
# 2     2021-10-20         Indiana Pacers        122.0    Charlotte Hornets
# 3     2021-10-20          Chicago Bulls         94.0      Detroit Pistons
# 4     2021-10-20         Boston Celtics        134.0      New York Knicks
# ...          ...                    ...          ...                  ...
# 1225  2022-04-10     Los Angeles Lakers          0.0       Denver Nuggets
# 1226  2022-04-10      San Antonio Spurs          0.0     Dallas Mavericks
# 1227  2022-04-10        Milwaukee Bucks          0.0  Cleveland Cavaliers
# 1228  2022-04-10     Washington Wizards          0.0    Charlotte Hornets
# 1229  2022-04-10         Indiana Pacers          0.0        Brooklyn Nets
#
#       HOME_PTS
# 0        127.0
# 1        114.0
# 2        123.0
# ...

# %%
season_schedule_df = season_schedule_df.loc[season_schedule_df['DATE'] == '2022-03-02']
# grab the date that you need

# %%
user_input = input('which is the date that you need?')
# Out:
# which is the date that you need?

# %%
season_schedule_df
# Out:
#            DATE                 VISITOR  VISITOR_PTS                  HOME  \
# 927  2022-03-02       Charlotte Hornets          0.0   Cleveland Cavaliers
# 928  2022-03-02          Indiana Pacers          0.0         Orlando Magic
# 929  2022-03-02         New York Knicks          0.0    Philadelphia 76ers
# 930  2022-03-02               Utah Jazz          0.0       Houston Rockets
# 931  2022-03-02              Miami Heat          0.0       Milwaukee Bucks
# 932  2022-03-02        Sacramento Kings          0.0  New Orleans Pelicans
# 933  2022-03-02   Oklahoma City Thunder          0.0        Denver Nuggets
# 934  2022-03-02  Portland Trail Blazers          0.0          Phoenix Suns
#
#      HOME_PTS
# 927       0.0
# 928       0.0
# 929       0.0
# 930       0.0
# 931       0.0
# 932       0.0
# 933       0.0
# 934       0.0

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

season_schedule_df['HOME_ABBR'] = 0
season_schedule_df['VISITOR_ABBR'] = 0
season_schedule_df = season_schedule_df.fillna(0)

for ind in season_schedule_df.index: 
    season_schedule_df['VISITOR'][ind] = season_schedule_df['VISITOR'][ind].upper()
    season_schedule_df['HOME'][ind] = season_schedule_df['HOME'][ind].upper()
    season_schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[season_schedule_df['HOME'][ind]]
    season_schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[season_schedule_df['VISITOR'][ind]]
# Out:
# <ipython-input-41-3cbf05e219b4>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_schedule_df['HOME_ABBR'] = 0
# <ipython-input-41-3cbf05e219b4>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_schedule_df['VISITOR_ABBR'] = 0
# <ipython-input-41-3cbf05e219b4>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
season_schedule_df
# Out:
#            DATE                 VISITOR  VISITOR_PTS                  HOME  \
# 927  2022-03-02       CHARLOTTE HORNETS          0.0   CLEVELAND CAVALIERS
# 928  2022-03-02          INDIANA PACERS          0.0         ORLANDO MAGIC
# 929  2022-03-02         NEW YORK KNICKS          0.0    PHILADELPHIA 76ERS
# 930  2022-03-02               UTAH JAZZ          0.0       HOUSTON ROCKETS
# 931  2022-03-02              MIAMI HEAT          0.0       MILWAUKEE BUCKS
# 932  2022-03-02        SACRAMENTO KINGS          0.0  NEW ORLEANS PELICANS
# 933  2022-03-02   OKLAHOMA CITY THUNDER          0.0        DENVER NUGGETS
# 934  2022-03-02  PORTLAND TRAIL BLAZERS          0.0          PHOENIX SUNS
#
#      HOME_PTS HOME_ABBR VISITOR_ABBR
# 927       0.0       CLE          CHO
# 928       0.0       ORL          IND
# 929       0.0       PHI          NYK
# 930       0.0       HOU          UTA
# 931       0.0       MIL          MIA
# 932       0.0       NOP          SAC
# ...

# %%
new_box_score
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0          92        98      -6        0.386        0.750         0.400
# 1         107       129     -22        0.406        0.941         0.277
# 2         105       100       5        0.464        0.680         0.357
# 3         129       111      18        0.553        0.656         0.467
# 4          92        84       8        0.430        0.700         0.324
# ..        ...       ...     ...          ...          ...           ...
# 717       107        98       9        0.470        0.947         0.314
# 718       109       108       1        0.456        0.870         0.304
# 719       100       113     -13        0.396        0.647         0.333
# 720       129       114      15        0.528        0.826         0.400
# 721       104       109      -5        0.451        0.800         0.412
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0          0.462        0.800         0.345
# ...

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 198 2021-11-15       CLE          BOS        92        98      -6
# 199 2021-11-15       DET          SAC       107       129     -22
# 200 2021-11-15       WAS          NOP       105       100       5
# 201 2021-11-15       ATL          ORL       129       111      18
# 202 2021-11-15       NYK          IND        92        84       8
# ..         ...       ...          ...       ...       ...     ...
# 915 2022-03-01       BOS          ATL       107        98       9
# 916 2022-03-01       TOR          BRK       109       108       1
# 917 2022-03-01       HOU          LAC       100       113     -13
# 918 2022-03-01       MIN          GSW       129       114      15
# 919 2022-03-01       LAL          DAL       104       109      -5
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 198               0        0.386        0.750         0.400        18
# ...

# %%
box_score_2 = box_score_df.loc[box_score_df['DATE'] >= '2021-11-15']

box_score_2 = box_score_df.loc[box_score_df['DATE'] <= '2022-03-02']


# even if there is not 03-02-2022 it still works
#box_score_2 = box_score_df.tail(692)
#trying to copy that

# %%
season_schedule_df
# Out:
#            DATE                 VISITOR  VISITOR_PTS                  HOME  \
# 927  2022-03-02       CHARLOTTE HORNETS          0.0   CLEVELAND CAVALIERS
# 928  2022-03-02          INDIANA PACERS          0.0         ORLANDO MAGIC
# 929  2022-03-02         NEW YORK KNICKS          0.0    PHILADELPHIA 76ERS
# 930  2022-03-02               UTAH JAZZ          0.0       HOUSTON ROCKETS
# 931  2022-03-02              MIAMI HEAT          0.0       MILWAUKEE BUCKS
# 932  2022-03-02        SACRAMENTO KINGS          0.0  NEW ORLEANS PELICANS
# 933  2022-03-02   OKLAHOMA CITY THUNDER          0.0        DENVER NUGGETS
# 934  2022-03-02  PORTLAND TRAIL BLAZERS          0.0          PHOENIX SUNS
#
#      HOME_PTS HOME_ABBR VISITOR_ABBR
# 927       0.0       CLE          CHO
# 928       0.0       ORL          IND
# 929       0.0       PHI          NYK
# 930       0.0       HOU          UTA
# 931       0.0       MIL          MIA
# 932       0.0       NOP          SAC
# ...

# %%
group_by_date_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away']
group_by_date_for_ml = pd.DataFrame(columns=group_by_date_columns)

# set a new pandas dataframe
for ind in season_schedule_df.index:
    empty_ = []
    date_1 = season_schedule_df.loc[ind]['DATE']
    home_1 = season_schedule_df.loc[ind]['HOME_ABBR']
    visitor_1 = season_schedule_df.loc[ind]['VISITOR_ABBR']
    empty_.append(date_1)
    empty_.append(home_1)
    empty_.append(visitor_1)
    home_df_group_by = box_score_2.loc[box_score_2['HOME_ABBR'] == home_1].tail(10).mean().reset_index()
    home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
    visitor_df_group_by = box_score_2.loc[box_score_2['VISITOR_ABBR'] == visitor_1].tail(10).mean().reset_index()
    visitor_df_dict = dict(zip(visitor_df_group_by.iloc[:,0].tolist(), visitor_df_group_by.iloc[:,1].tolist()))
    empty_.append(home_df_dict['PTS_home'])
    empty_.append(visitor_df_dict['PTS_away'])
    margin = home_df_dict['PTS_home'] - visitor_df_dict['PTS_away']
    empty_.append(margin)
    empty_.append(home_df_dict['FG_PCT_home'])
    empty_.append(home_df_dict['FT_PCT_home'])
    empty_.append(home_df_dict['FG3_PCT_home'])
    empty_.append(visitor_df_dict['FG_PCT_away'])
    empty_.append(visitor_df_dict['FT_PCT_away'])
    empty_.append(visitor_df_dict['FG3_PCT_away'])
    length_of_df = len(group_by_date_for_ml)
    group_by_date_for_ml.loc[length_of_df] = empty_

# %%
group_by_date_for_ml
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-03-01       WAS          DET     108.4     105.8     2.6       0.4593
# 1  2022-03-01       BOS          ATL     111.2     109.1     2.1       0.4744
# 2  2022-03-01       TOR          BRK     115.2     110.0     5.2       0.4632
# 3  2022-03-01       HOU          LAC     108.2     106.9     1.3       0.4466
# 4  2022-03-01       MIN          GSW     116.5     112.1     4.4       0.4590
# 5  2022-03-01       LAL          DAL     109.8     110.7    -0.9       0.4570
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.8101        0.3108       0.4316       0.7623        0.3585
# 1       0.8166        0.3439       0.4426       0.8192        0.3360
# 2       0.7631        0.3968       0.4548       0.7845        0.3580
# 3       0.6704        0.3328       0.4685       0.7376        0.3567
# 4       0.7464        0.3482       0.4537       0.8063        0.3793
# ...

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
winning_percentage_dict = dict.fromkeys(list_, 0)

for _, row in box_score_2.iterrows():
    home_team = row['HOME_ABBR']
    visitor_team = row['VISITOR_ABBR']
    home_winning_percentage = row['home_winning_percentage']
    visitor_winning_percentage = row['visitor_winning_percentage']
    
    if home_team in winning_percentage_dict:
            winning_percentage_dict[home_team] = home_winning_percentage
    elif visitor_team in winning_percentage_dict:
            winning_percentage_dict[visitor_team] = visitor_winning_percentage
            
# inserting winning_percentage into the dataframe

home_winning_percentage_list = []
visitor_winning_percentage_list = []
for ind in group_by_date_for_ml.index:
    home_abbr = group_by_date_for_ml.loc[ind]['HOME_ABBR']
    visitor_abbr = group_by_date_for_ml.loc[ind]['VISITOR_ABBR']
    home_winning_percentage_list.append(winning_percentage_dict[home_abbr])
    visitor_winning_percentage_list.append(winning_percentage_dict[visitor_abbr])
group_by_date_for_ml['home_winning_percentage'] = home_winning_percentage_list
group_by_date_for_ml['visitor_winning_percentage'] = visitor_winning_percentage_list


group_by_date_for_ml['diff_%'] = group_by_date_for_ml['home_winning_percentage'] - group_by_date_for_ml['visitor_winning_percentage']
group_by_date_for_ml = group_by_date_for_ml.round({"diff_%":1})

# %%
group_by_date_for_ml
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-03-02       CLE          CHO     105.0     118.3   -13.3       0.4621
# 1  2022-03-02       ORL          IND     109.5     108.5     1.0       0.4622
# 2  2022-03-02       PHI          NYK     105.0     104.2     0.8       0.4454
# 3  2022-03-02       HOU          UTA     107.6     108.4    -0.8       0.4437
# 4  2022-03-02       MIL          MIA     117.3     109.6     7.7       0.4657
# 5  2022-03-02       NOP          SAC     110.0     107.4     2.6       0.4764
# 6  2022-03-02       DEN          OKC     122.2     104.4    17.8       0.5054
# 7  2022-03-02       PHO          POR     119.1     107.4    11.7       0.5078
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.7458        0.3372       0.4755       0.7112        0.3617
# 1       0.8187        0.3346       0.4432       0.7118        0.3573
# ...

# %%
calculated_df.head()
#remember calculated_df is new_box_score - grouped_by_date_df
# there is an adjustment
# Out:
#         DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0 2021-11-15       CLE          BOS     -13.0     -14.9     1.9      -0.0761
# 1 2021-11-15       DET          SAC      -0.4      21.6   -22.0      -0.0326
# 2 2021-11-15       WAS          NOP      -3.2      -8.0     4.8       0.0024
# 3 2021-11-15       ATL          ORL       8.6       2.4     6.2       0.0318
# 4 2021-11-15       NYK          IND     -14.0     -24.5    10.5       0.0000
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.0042        0.0628      -0.0164       0.0002       -0.0121
# 1       0.1599       -0.0432       0.0681       0.0593        0.1567
# 2      -0.1296        0.0307      -0.0672       0.1048        0.1919
# 3      -0.1381        0.0668      -0.0057      -0.1332        0.0098
# 4      -0.0380       -0.0169      -0.0712       0.0382       -0.1413
#
#    home_winning_percentage  visitor_winning_percentage
# ...

# %%
# mean_grouped_visitor_df.columns
# more_precise_df.columns

# notes

# %%
# date = group_by_date_for_ml.loc[0]['DATE']
# home_abbr = group_by_date_for_ml.loc[0]['HOME_ABBR']
# visitor_abbr = group_by_date_for_ml.loc[0]['VISITOR_ABBR']
# diff = group_by_date_for_ml.loc[0]['diff_%']
# home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
# home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# home_df = home_df.round({"diff_%":1})
# mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()

# in case there is an error while looping

# %%
# date = group_by_date_for_ml.loc[4]['DATE']
# home_abbr = group_by_date_for_ml.loc[4]['HOME_ABBR']
# visitor_abbr = group_by_date_for_ml.loc[4]['VISITOR_ABBR']
# diff = group_by_date_for_ml.loc[4]['diff_%']
# home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
# home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# home_df = home_df.round({"diff_%":1})
# mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
# list_ = mean_grouped_home_df['diff_%'].tolist()
# arr = np.asarray(list_)
# input_val = (np.abs(arr - 0)).argmin()
# return_ = arr[input_val]
# if (diff )
#     mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
# except:
#     mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]

# in case there is an error looping

# %%
#if (diff in list_):
 #   print('yes')
#else:
 #   print('no')
# notes

# %%
group_by_date_for_ml
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-02-28       CLE          MIN     104.6     121.4   -16.8       0.4665
# 1  2022-02-28       ORL          IND     106.4     111.5    -5.1       0.4531
# 2  2022-02-28       BRK          TOR     108.2     110.2    -2.0       0.4527
# 3  2022-02-28       MIA          CHI     110.8     109.8     1.0       0.4628
# 4  2022-02-28       MEM          SAS     116.0     119.1    -3.1       0.4731
# 5  2022-02-28       MIL          CHO     113.9     119.3    -5.4       0.4555
# 6  2022-02-28       OKC          SAC     102.6     103.1    -0.5       0.4231
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.7188        0.3287       0.4683       0.7960        0.3742
# 1       0.8014        0.3272       0.4461       0.7268        0.3550
# 2       0.7891        0.3077       0.4559       0.7516        0.3611
# ...

# %%
group_by_date_for_ml
# Out:
#   HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0       WAS          DET     108.4     105.8     2.6       0.4593
# 1       BOS          ATL     111.2     109.1     2.1       0.4744
# 2       TOR          BRK     115.2     110.0     5.2       0.4632
# 3       HOU          LAC     108.2     106.9     1.3       0.4466
# 4       MIN          GSW     116.5     112.1     4.4       0.4590
# 5       LAL          DAL     109.8     110.7    -0.9       0.4570
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.8101        0.3108       0.4316       0.7623        0.3585
# 1       0.8166        0.3439       0.4426       0.8192        0.3360
# 2       0.7631        0.3968       0.4548       0.7845        0.3580
# 3       0.6704        0.3328       0.4685       0.7376        0.3567
# 4       0.7464        0.3482       0.4537       0.8063        0.3793
# 5       0.7187        0.3147       0.4809       0.7548        0.3760

# %%
date =  group_by_date_for_ml.loc[0]['DATE']
home_abbr = group_by_date_for_ml.loc[0]['HOME_ABBR']
visitor_abbr = group_by_date_for_ml.loc[0]['VISITOR_ABBR']
diff = group_by_date_for_ml.loc[0]['diff_%']
home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
home_df = home_df.round({"diff_%":1})
mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
list_ = mean_grouped_home_df['diff_%'].tolist()
arr = np.asarray(list_)
input_val = (np.abs(arr - diff)).argmin()
return_ = arr[input_val]
if (diff in list_):
    mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
else:
    mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
    print(f'{home_abbr} does not have the average correct so use closest diff')
    print(f'Ind:{ind}')
mean_grouped_home_df['HOME/VISITOR'] = 'HOME'
mean_grouped_home_df['ABBR'] = home_abbr
mean_grouped_home_df = mean_grouped_home_df.rename(columns={"home_winning_percentage":"winning_percentage"})
mean_grouped_home_df = mean_grouped_home_df.drop('visitor_winning_percentage',1)
mean_grouped_home_df = mean_grouped_home_df[['ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
   'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
   'FG3_PCT_away', 'winning_percentage','diff_%']]
visitor_df = calculated_df[calculated_df['VISITOR_ABBR'] == visitor_abbr]
visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']
visitor_df = visitor_df.round({"diff_%":1})
mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
# Out:
# <ipython-input-134-dc0be59ee784>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# <ipython-input-134-dc0be59ee784>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']

# %%
visitor_df.loc[visitor_df['diff_%'] == 0.2]
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 704 2022-02-27       CHO          DET      18.0      21.2    -3.2
#
#      FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 704       0.0716      -0.0565        0.1175       0.0234      -0.0403
#
#      FG3_PCT_away  home_winning_percentage  visitor_winning_percentage  diff_%
# 704       -0.0085                 0.483871                        0.25     0.2

# %%
mean_grouped_visitor_df
# Out:
#    diff_%   PTS_home  PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  \
# 0    -0.0   9.500000      -2.8  12.300000     0.031800     0.143300
# 1     0.1   5.850000       7.2  -1.350000    -0.006400    -0.026150
# 2     0.2  18.000000      21.2  -3.200000     0.071600    -0.056500
# 3     0.3   6.460000      -1.4   7.860000     0.041420    -0.005320
# 4     0.4  -1.933333      -5.3   3.366667    -0.005700     0.049167
# 5     0.5   1.233333     -18.8  20.033333    -0.011033    -0.066733
# 6     0.7  -5.100000      -2.8  -2.300000     0.036200    -0.029500
#
#    FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      0.145400    -0.063600     0.021700     -0.013500
# 1      0.068450     0.015400     0.129700      0.012000
# 2      0.117500     0.023400    -0.040300     -0.008500
# 3      0.035710     0.002300     0.015600     -0.019400
# 4     -0.000400    -0.019100    -0.005967     -0.037167
# 5      0.033833    -0.087267    -0.010633     -0.137500
# ...

# %%
# this is for an more in-depth view

more_precise_df_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'home_winning_percentage', 'diff_%']
more_precise_df = pd.DataFrame(columns=more_precise_df_columns)


import numpy as np

for ind in group_by_date_for_ml.index:
    date = group_by_date_for_ml.loc[ind]['DATE']
    home_abbr = group_by_date_for_ml.loc[ind]['HOME_ABBR']
    visitor_abbr = group_by_date_for_ml.loc[ind]['VISITOR_ABBR']
    diff = group_by_date_for_ml.loc[ind]['diff_%']
    home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
    home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
    home_df = home_df.round({"diff_%":1})
    mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
    list_ = mean_grouped_home_df['diff_%'].tolist()
    arr = np.asarray(list_)
    input_val = (np.abs(arr - diff)).argmin()
    return_ = arr[input_val]
    if (diff in list_):
        mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
    else:
        mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
        print(f'{home_abbr} does not have the average correct so use closest diff')
        print(f'Ind:{ind}')
    mean_grouped_home_df['HOME/VISITOR'] = 'HOME'
    mean_grouped_home_df['ABBR'] = home_abbr
    mean_grouped_home_df['DATE'] = date
    mean_grouped_home_df = mean_grouped_home_df.rename(columns={"home_winning_percentage":"winning_percentage"})
    mean_grouped_home_df = mean_grouped_home_df.drop('visitor_winning_percentage',1)
    mean_grouped_home_df = mean_grouped_home_df[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
       'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
       'FG3_PCT_away', 'winning_percentage','diff_%']]
    visitor_df = calculated_df[calculated_df['VISITOR_ABBR'] == visitor_abbr]
    visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']
    visitor_df = visitor_df.round({"diff_%":1})
    mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
    list_ = mean_grouped_visitor_df['diff_%'].tolist()
    arr = np.asarray(list_)
    input_val = (np.abs(arr - diff)).argmin()
    return_ = arr[input_val]
    if (diff in list_):
        mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == diff]
    else:
        mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == return_]
        print(f'{visitor_abbr} does not have average correct so use closest diff')
    mean_grouped_visitor_df['HOME/VISITOR'] = 'VISITOR'
    mean_grouped_visitor_df['ABBR'] = visitor_abbr
    mean_grouped_visitor_df['DATE'] = date
    mean_grouped_visitor_df = mean_grouped_visitor_df.rename(columns={"visitor_winning_percentage":"winning_percentage"})
    mean_grouped_visitor_df = mean_grouped_visitor_df.drop('home_winning_percentage',1)
    mean_grouped_visitor_df = mean_grouped_visitor_df[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
       'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
       'FG3_PCT_away', 'winning_percentage','diff_%']]
    length_of_df = len(more_precise_df)
    more_precise_df.loc[length_of_df] = mean_grouped_home_df.iloc[0].tolist()
    length_of_df = len(more_precise_df)
    more_precise_df.loc[length_of_df] = mean_grouped_visitor_df.iloc[0].tolist()
# Out:
# <ipython-input-52-93aca1c713c6>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# <ipython-input-52-93aca1c713c6>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']

# %%
more_precise_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR   PTS_home   PTS_away     MARGIN  \
# 0   2022-03-02       CLE         HOME   9.200000  -4.540000  13.740000
# 1   2022-03-02       CHO      VISITOR   7.650000  -3.550000  11.200000
# 2   2022-03-02       ORL         HOME   9.500000  -5.500000  15.000000
# 3   2022-03-02       IND      VISITOR   2.000000  -6.833333   8.833333
# 4   2022-03-02       PHI         HOME  13.000000  -9.350000  22.350000
# 5   2022-03-02       NYK      VISITOR  -1.525000  -0.950000  -0.575000
# 6   2022-03-02       HOU         HOME  20.400000  17.550000   2.850000
# 7   2022-03-02       UTA      VISITOR  -2.250000   9.100000 -11.350000
# 8   2022-03-02       MIL         HOME -11.133333   0.966667 -12.100000
# 9   2022-03-02       MIA      VISITOR  -3.525000  -8.850000   5.325000
# 10  2022-03-02       NOP         HOME   5.500000   5.400000   0.100000
# 11  2022-03-02       SAC      VISITOR  -6.550000 -14.900000   8.350000
# ...

# %%
group_by_date_for_ml
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-03-02       CLE          CHO     105.0     118.3   -13.3       0.4621
# 1  2022-03-02       ORL          IND     109.5     108.5     1.0       0.4622
# 2  2022-03-02       PHI          NYK     105.0     104.2     0.8       0.4454
# 3  2022-03-02       HOU          UTA     107.6     108.4    -0.8       0.4437
# 4  2022-03-02       MIL          MIA     117.3     109.6     7.7       0.4657
# 5  2022-03-02       NOP          SAC     110.0     107.4     2.6       0.4764
# 6  2022-03-02       DEN          OKC     122.2     104.4    17.8       0.5054
# 7  2022-03-02       PHO          POR     119.1     107.4    11.7       0.5078
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.7458        0.3372       0.4755       0.7112        0.3617
# 1       0.8187        0.3346       0.4432       0.7118        0.3573
# ...

# %%
# #copy and paste this
# #because ind 4 does not work work to replace it
#     date = group_by_date_for_ml.loc[ind]['DATE']
#     home_abbr = group_by_date_for_ml.loc[ind]['HOME_ABBR']
#     visitor_abbr = group_by_date_for_ml.loc[ind]['VISITOR_ABBR']
#     diff = group_by_date_for_ml.loc[ind]['diff_%']
#     home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
#     home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
#     home_df = home_df.round({"diff_%":1})
#     mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
#     list_ = mean_grouped_home_df['diff_%'].tolist()
#     arr = np.asarray(list_)
#     input_val = (np.abs(arr - 0)).argmin()
#     return_ = arr[input_val]
#     if (diff in list_):
#         mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
#     else:
#         mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
#         print(f'{home_abbr} does not have the average correct')
#         print(f'Ind:{ind}')
#     mean_grouped_home_df['HOME/VISITOR'] = 'HOME'
#     mean_grouped_home_df['ABBR'] = home_abbr
#     mean_grouped_home_df['DATE'] = date
#     mean_grouped_home_df = mean_grouped_home_df.rename(columns={"home_winning_percentage":"winning_percentage"})
#     mean_grouped_home_df = mean_grouped_home_df.drop('visitor_winning_percentage',1)
#     mean_grouped_home_df = mean_grouped_home_df[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
#        'FG3_PCT_away', 'winning_percentage','diff_%']]
#     visitor_df = calculated_df[calculated_df['VISITOR_ABBR'] == visitor_abbr]
#     visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']
#     visitor_df = visitor_df.round({"diff_%":1})
#     mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
#     list_ = mean_grouped_visitor_df['diff_%'].tolist()
#     arr = np.asarray(list_)
#     input_val = (np.abs(arr - 0)).argmin()
#     return_ = arr[input_val]
#     if (diff in list_):
#         mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == diff]
#     else:
#         mean_grouped_visitor_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
#         print(f'{visitor_abbr} does not have an average group')
#     mean_grouped_visitor_df['HOME/VISITOR'] = 'VISITOR'
#     mean_grouped_visitor_df['ABBR'] = visitor_abbr
#     mean_grouped_visitor_df['DATE'] = date
#     mean_grouped_visitor_df = mean_grouped_visitor_df.rename(columns={"visitor_winning_percentage":"winning_percentage"})
#     mean_grouped_visitor_df = mean_grouped_visitor_df.drop('home_winning_percentage',1)
#     mean_grouped_visitor_df = mean_grouped_visitor_df[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
#        'FG3_PCT_away', 'winning_percentage','diff_%']]
#     #mean_grouped_home_df
#     #mean_grouped_visitor_df
# Out:
#   File "<ipython-input-171-54ec2a60c1ab>", line 3
#     date = group_by_date_for_ml.loc[ind]['DATE']
#     ^
# IndentationError: unexpected indent

# %%
# #copy and paste this
# #because ind 4 does not work work to replace it
# date = group_by_date_for_ml.loc[4]['DATE']
# home_abbr = group_by_date_for_ml.loc[4]['HOME_ABBR']
# visitor_abbr = group_by_date_for_ml.loc[4]['VISITOR_ABBR']
# diff = group_by_date_for_ml.loc[4]['diff_%']
# home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
# home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# home_df = home_df.round({"diff_%":1})
# mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
# list_ = mean_grouped_home_df['diff_%'].tolist()
# arr = np.asarray(list_)
# input_val = (np.abs(arr - 0)).argmin()
# return_ = arr[input_val]
# if (diff in list_):
#     mean_grouped_home_df_1 = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
# else:
#     mean_grouped_home_df_1 = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
#     print(f'{home_abbr} does not have the average correct')
#     print(f'Ind:{ind}')
# mean_grouped_home_df_1['HOME/VISITOR'] = 'HOME'
# mean_grouped_home_df_1['ABBR'] = home_abbr
# mean_grouped_home_df_1['DATE'] = date
# mean_grouped_home_df_1 = mean_grouped_home_df_1.rename(columns={"home_winning_percentage":"winning_percentage"})
# mean_grouped_home_df_1 = mean_grouped_home_df_1.drop('visitor_winning_percentage',1)
# mean_grouped_home_df_1 = mean_grouped_home_df_1[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
#    'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
#    'FG3_PCT_away', 'winning_percentage','diff_%']]
# visitor_df = calculated_df[calculated_df['VISITOR_ABBR'] == visitor_abbr]
# visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']
# visitor_df = visitor_df.round({"diff_%":1})
# mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
# list_ = mean_grouped_visitor_df['diff_%'].tolist()
# arr = np.asarray(list_)
# input_val = (np.abs(arr - 0)).argmin()
# return_ = arr[input_val]
# if (diff in list_):
#     mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == diff]
# else:
#     mean_grouped_visitor_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
#     print(f'{visitor_abbr} does not have an average group')
# mean_grouped_visitor_df['HOME/VISITOR'] = 'VISITOR'
# mean_grouped_visitor_df['ABBR'] = visitor_abbr
# mean_grouped_visitor_df['DATE'] = date
# mean_grouped_visitor_df = mean_grouped_visitor_df.rename(columns={"visitor_winning_percentage":"winning_percentage"})
# mean_grouped_visitor_df = mean_grouped_visitor_df.drop('home_winning_percentage',1)
# mean_grouped_visitor_df = mean_grouped_visitor_df[['DATE','ABBR','HOME/VISITOR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home',
#    'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away',
#    'FG3_PCT_away', 'winning_percentage','diff_%']]
# #mean_grouped_home_df
#     #mean_grouped_visitor_df
# Out:
# MIA does not have the average correct
# Ind:6
# <ipython-input-176-f3b050ecbf88>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# <ipython-input-176-f3b050ecbf88>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_grouped_home_df_1['HOME/VISITOR'] = 'HOME'
# <ipython-input-176-f3b050ecbf88>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
mean_grouped_home_df
# Out:
#          DATE ABBR HOME/VISITOR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 3  2022-02-27  LAL         HOME     6.625    5.3625  1.2625      0.01745
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 3     0.040675         0.016      -0.0136    -0.026687     -0.005312
#
#    winning_percentage  diff_%
# 3            0.494376     0.1

# %%
more_precise_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR   PTS_home   PTS_away     MARGIN  \
# 0   2022-02-27       NYK         HOME  -0.900000   2.050000  -2.950000
# 1   2022-02-27       PHI      VISITOR -13.850000  -4.700000  -9.150000
# 2   2022-02-27       PHO         HOME  -0.600000  -4.060000   3.460000
# 3   2022-02-27       UTA      VISITOR  -4.000000   1.600000  -5.600000
# 4   2022-02-27       IND         HOME  -1.766667   9.100000 -10.866667
# 5   2022-02-27       BOS      VISITOR -16.400000 -26.100000   9.700000
# 6   2022-02-27       CHO         HOME  18.833333   3.400000  15.433333
# 7   2022-02-27       DET      VISITOR   6.720000   2.600000   4.120000
# 8   2022-02-27       HOU         HOME  13.500000  21.950000  -8.450000
# 9   2022-02-27       LAC      VISITOR   1.400000  -5.600000   7.000000
# 10  2022-02-27       GSW         HOME  -8.633333  -6.200000  -2.433333
# 11  2022-02-27       DAL      VISITOR -19.200000  -4.250000 -14.950000
# ...

# %%
more_precise_df_1 = more_precise_df.copy()

# %%
# more_precise_df_1.loc[8] = ['2/26/22', 'MIA', 'HOME', '-0.8', '-6.33', '-6', '0', '-0.02', '0.01', '0', '0', '0', '0.62', '0.3']
# adjustment needed?

# %%
user_input = input('adjustment needed?')
# Out:
# adjustment needed?

# %%
more_precise_df_1
# Out:
#           DATE HOME_ABBR VISITOR_ABBR PTS_home  PTS_away    MARGIN  \
# 0   2022-02-26       DET         HOME -3.73333      -3.9  0.166667
# 1   2022-02-26       BOS      VISITOR    -18.9      -5.1     -13.8
# 2   2022-02-26       ATL         HOME      1.2       3.8      -2.6
# 3   2022-02-26       TOR      VISITOR     -4.4      -9.7       5.3
# 4   2022-02-26       CHI         HOME    -11.6      10.4       -22
# 5   2022-02-26       MEM      VISITOR -2.66667      -5.7   3.03333
# 6   2022-02-26       CLE         HOME      1.4      -7.8       9.2
# 7   2022-02-26       WAS      VISITOR     -0.5 -0.633333  0.133333
# 8      2/26/22       MIA         HOME     -0.8     -6.33        -6
# 9   2022-02-26       SAS      VISITOR    6.425      -7.1    13.525
# 10  2022-02-26       MIL         HOME    -2.15   -2.6875    0.5375
# 11  2022-02-26       BRK      VISITOR    -0.55      -1.5      0.95
# 12  2022-02-26       DEN         HOME    -17.2       7.2     -24.4
# ...

# %%
    #length_of_df = len(more_precise_df)
    #more_precise_df.loc[length_of_df] = mean_grouped_home_df.iloc[0].tolist()
    #length_of_df = len(more_precise_df)
    #more_precise_df.loc[length_of_df] = mean_grouped_visitor_df.iloc[0].tolist()

# %%
#based on the group_by_date_for_ml you want to see what is the differences that come up
# based on winning percentage differential

diff_df_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away']
diff_df = pd.DataFrame(columns=diff_df_columns)

for ind in group_by_date_for_ml.index:
    empty_ = []
    home_abbr = group_by_date_for_ml.loc[ind]['HOME_ABBR']
    visitor_abbr = group_by_date_for_ml.loc[ind]['VISITOR_ABBR']
    diff = group_by_date_for_ml.loc[ind]['diff_%']
    home_df = calculated_df[calculated_df['HOME_ABBR'] == home_abbr]
    home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
    home_df = home_df.round({"diff_%":1})
    mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
    list_ = mean_grouped_home_df['diff_%'].tolist()
    arr = np.asarray(list_)
    input_val = (np.abs(arr - diff)).argmin()
    return_ = arr[input_val]
    if (diff in list_):
        mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
    else:
        mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
        print(f'{home_abbr} does not have the average correct')
        print(f'Ind:{ind}')
    mean_grouped_home_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == diff]
    visitor_df = calculated_df[calculated_df['VISITOR_ABBR'] == visitor_abbr]
    visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']
    visitor_df = visitor_df.round({"diff_%":1})
    mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
    list_ = mean_grouped_visitor_df['diff_%'].tolist()
    arr = np.asarray(list_)
    input_val = (np.abs(arr - diff)).argmin()
    return_ = arr[input_val]
    if (diff in list_):
        mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == diff]
    else:
        mean_grouped_visitor_df = mean_grouped_home_df.loc[mean_grouped_home_df['diff_%'] == return_]
        print(f'{visitor_abbr} does not have an average group')
    mean_grouped_visitor_df = mean_grouped_visitor_df.loc[mean_grouped_visitor_df['diff_%'] == diff]
    grouped_df = pd.concat((mean_grouped_home_df, mean_grouped_visitor_df))
    empty_.append(group_by_date_for_ml.loc[ind]['DATE'])
    empty_.append(home_abbr)
    empty_.append(visitor_abbr)
    empty_.append(grouped_df.mean()['PTS_home'])
    empty_.append(grouped_df.mean()['PTS_away'])
    empty_.append(grouped_df.mean()['MARGIN'])
    empty_.append(grouped_df.mean()['FG_PCT_home'])
    empty_.append(grouped_df.mean()['FT_PCT_home'])
    empty_.append(grouped_df.mean()['FG3_PCT_home'])
    empty_.append(grouped_df.mean()['FG_PCT_away'])
    empty_.append(grouped_df.mean()['FT_PCT_away'])
    empty_.append(grouped_df.mean()['FG3_PCT_away'])
    length_of_df = len(diff_df)
    diff_df.loc[length_of_df] = empty_
# Out:
# <ipython-input-56-4a6e1ee22edf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_df['diff_%'] = home_df['home_winning_percentage'] - home_df['visitor_winning_percentage']
# <ipython-input-56-4a6e1ee22edf>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visitor_df['diff_%'] = visitor_df['home_winning_percentage'] - visitor_df['visitor_winning_percentage']

# %%
diff_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR   PTS_home   PTS_away     MARGIN  \
# 0  2022-03-01       WAS          DET  13.050000  15.050000  -2.000000
# 1  2022-03-01       BOS          ATL  -1.007143  -7.357143   6.350000
# 2  2022-03-01       TOR          BRK   2.025000  -1.050000   3.075000
# 3  2022-03-01       HOU          LAC   7.850000   8.650000  -0.800000
# 4  2022-03-01       MIN          GSW   1.216667  -9.266667  10.483333
# 5  2022-03-01       LAL          DAL -12.120000  -5.500000  -6.620000
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.051150    -0.046550      0.050600     0.032375     0.022550
# 1    -0.002964     0.031986      0.002864    -0.029393     0.057486
# 2     0.003325     0.002675     -0.006275    -0.014170    -0.046300
# 3     0.046600    -0.090450      0.070950     0.008700    -0.031525
# 4     0.028733    -0.104417      0.016200    -0.031700    -0.041133
# ...

# %%
# in case adjustment needed
# diff_df.loc[4] = ['2/26/22', 'MIA', 'SAS', '6.425', '-6.33', '12', '0', '-0.02', '0.01', '0', '0', '0']

# %%
user_input = input('adjustment needed?')
# Out:
# adjustment needed?

# %%
diff_df["DATE"]= pd.to_datetime(diff_df["DATE"])
diff_df['PTS_home'] = pd.to_numeric(diff_df['PTS_home'])
diff_df['PTS_away'] = pd.to_numeric(diff_df['PTS_away'])
diff_df['MARGIN'] = pd.to_numeric(diff_df['MARGIN'])
diff_df['FG_PCT_home'] = pd.to_numeric(diff_df['FG_PCT_home'])
diff_df['FT_PCT_home'] = pd.to_numeric(diff_df['FT_PCT_home'])
diff_df['FG3_PCT_home'] = pd.to_numeric(diff_df['FG3_PCT_home'])
diff_df['FG_PCT_away'] = pd.to_numeric(diff_df['FG_PCT_away'])
diff_df['FT_PCT_away'] = pd.to_numeric(diff_df['FT_PCT_away'])
diff_df['FG3_PCT_away'] = pd.to_numeric(diff_df['FG3_PCT_away'])

# %%
diff_df
# Out:
#         DATE HOME_ABBR VISITOR_ABBR  PTS_home   PTS_away     MARGIN  \
# 0 2022-03-02       CLE          CHO  8.425000  -4.045000  12.470000
# 1 2022-03-02       ORL          IND  5.750000  -6.166667  11.916667
# 2 2022-03-02       PHI          NYK  5.737500  -5.150000  10.887500
# 3 2022-03-02       HOU          UTA  9.075000  13.325000  -4.250000
# 4 2022-03-02       MIL          MIA -7.329167  -3.941667  -3.387500
# 5 2022-03-02       NOP          SAC -0.525000  -4.750000   4.225000
# 6 2022-03-02       DEN          OKC -8.830000   5.000000 -13.830000
# 7 2022-03-02       PHO          POR -5.300000  -7.900000   2.600000
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.013150    -0.026100      0.039450    -0.012610    -0.007325
# 1     0.006233    -0.069983     -0.009067     0.022467    -0.005467
# 2     0.012150     0.061250     -0.011525    -0.011150     0.022275
# 3     0.001050    -0.017450      0.036525     0.019500     0.014925
# ...

# %%
group_by_date_for_ml 
# at this point is the grouped box score
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-03-01       WAS          DET     108.4     105.8     2.6       0.4593
# 1  2022-03-01       BOS          ATL     111.2     109.1     2.1       0.4744
# 2  2022-03-01       TOR          BRK     115.2     110.0     5.2       0.4632
# 3  2022-03-01       HOU          LAC     108.2     106.9     1.3       0.4466
# 4  2022-03-01       MIN          GSW     116.5     112.1     4.4       0.4590
# 5  2022-03-01       LAL          DAL     109.8     110.7    -0.9       0.4570
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.8101        0.3108       0.4316       0.7623        0.3585
# 1       0.8166        0.3439       0.4426       0.8192        0.3360
# 2       0.7631        0.3968       0.4548       0.7845        0.3580
# 3       0.6704        0.3328       0.4685       0.7376        0.3567
# 4       0.7464        0.3482       0.4537       0.8063        0.3793
# ...

# %%
#previously
#diff_df.to_csv('diff_df_feb_24.csv', index=False)
#group_by_date_for_ml.to_csv('grouped_feb_24.csv', index=False)

# %%
diff_df.head()
# Out:
#         DATE HOME_ABBR VISITOR_ABBR   PTS_home   PTS_away     MARGIN  \
# 0 2022-03-01       WAS          DET  13.050000  15.050000  -2.000000
# 1 2022-03-01       BOS          ATL  -1.007143  -7.357143   6.350000
# 2 2022-03-01       TOR          BRK   2.025000  -1.050000   3.075000
# 3 2022-03-01       HOU          LAC   7.850000   8.650000  -0.800000
# 4 2022-03-01       MIN          GSW   1.216667  -9.266667  10.483333
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.051150    -0.046550      0.050600     0.032375     0.022550
# 1    -0.002964     0.031986      0.002864    -0.029393     0.057486
# 2     0.003325     0.002675     -0.006275    -0.014170    -0.046300
# 3     0.046600    -0.090450      0.070950     0.008700    -0.031525
# 4     0.028733    -0.104417      0.016200    -0.031700    -0.041133
#
#    FG3_PCT_away
# 0     -0.010800
# 1     -0.012164
# 2      0.012500
# 3      0.032225
# 4     -0.053467

# %%
group_by_date_for_ml.head()
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-03-01       WAS          DET     108.4     105.8     2.6       0.4593
# 1  2022-03-01       BOS          ATL     111.2     109.1     2.1       0.4744
# 2  2022-03-01       TOR          BRK     115.2     110.0     5.2       0.4632
# 3  2022-03-01       HOU          LAC     108.2     106.9     1.3       0.4466
# 4  2022-03-01       MIN          GSW     116.5     112.1     4.4       0.4590
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.8101        0.3108       0.4316       0.7623        0.3585
# 1       0.8166        0.3439       0.4426       0.8192        0.3360
# 2       0.7631        0.3968       0.4548       0.7845        0.3580
# 3       0.6704        0.3328       0.4685       0.7376        0.3567
# 4       0.7464        0.3482       0.4537       0.8063        0.3793
#
#    home_winning_percentage  visitor_winning_percentage  diff_%
# ...

# %%
date1 = group_by_date_for_ml['DATE']
home_abbr1 = group_by_date_for_ml['HOME_ABBR']
visitor_abbr1 = group_by_date_for_ml['VISITOR_ABBR']
home_winning_percentage = group_by_date_for_ml['home_winning_percentage']
visitor_winning_percentage = group_by_date_for_ml['visitor_winning_percentage']
diff = group_by_date_for_ml['diff_%']

# %%
group_by_date_for_ml = group_by_date_for_ml.drop('DATE', 1)
group_by_date_for_ml = group_by_date_for_ml.drop('HOME_ABBR', 1)
group_by_date_for_ml = group_by_date_for_ml.drop('VISITOR_ABBR', 1)
group_by_date_for_ml = group_by_date_for_ml.drop('home_winning_percentage', 1)
group_by_date_for_ml = group_by_date_for_ml.drop('visitor_winning_percentage', 1)
group_by_date_for_ml = group_by_date_for_ml.drop('diff_%', 1)

# %%
diff_df = diff_df.drop('DATE', 1)
diff_df = diff_df.drop('HOME_ABBR', 1)
diff_df = diff_df.drop('VISITOR_ABBR', 1)
diff_df
# Out:
#    PTS_home   PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  8.425000  -4.045000  12.470000     0.013150    -0.026100      0.039450
# 1  5.750000  -6.166667  11.916667     0.006233    -0.069983     -0.009067
# 2  5.737500  -5.150000  10.887500     0.012150     0.061250     -0.011525
# 3  9.075000  13.325000  -4.250000     0.001050    -0.017450      0.036525
# 4 -7.329167  -3.941667  -3.387500    -0.023100     0.009467     -0.004500
# 5 -0.525000  -4.750000   4.225000     0.005850     0.058775      0.002450
# 6 -8.830000   5.000000 -13.830000    -0.037690     0.053200      0.032770
# 7 -5.300000  -7.900000   2.600000    -0.026350     0.033500     -0.044650
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0    -0.012610    -0.007325      0.031675
# 1     0.022467    -0.005467      0.016700
# 2    -0.011150     0.022275     -0.009675
# 3     0.019500     0.014925      0.031475
# 4    -0.023233    -0.028942     -0.021358
# 5    -0.037100     0.001000     -0.017725
# ...

# %%
diff_df['PTS_home'] = pd.to_numeric(diff_df['PTS_home'])
diff_df['PTS_away'] = pd.to_numeric(diff_df['PTS_away'])
diff_df['MARGIN'] = pd.to_numeric(diff_df['MARGIN'])
diff_df['FG_PCT_home'] = pd.to_numeric(diff_df['FG_PCT_home'])
diff_df['FT_PCT_home'] = pd.to_numeric(diff_df['FT_PCT_home'])
diff_df['FG3_PCT_home'] = pd.to_numeric(diff_df['FG3_PCT_home'])
diff_df['FG_PCT_away'] = pd.to_numeric(diff_df['FG_PCT_away'])
diff_df['FT_PCT_away'] = pd.to_numeric(diff_df['FT_PCT_away'])
diff_df['FG3_PCT_away'] = pd.to_numeric(diff_df['FG3_PCT_away'])

# %%
diff_df
# Out:
#     PTS_home   PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  13.050000  15.050000  -2.000000     0.051150    -0.046550      0.050600
# 1  -1.007143  -7.357143   6.350000    -0.002964     0.031986      0.002864
# 2   2.025000  -1.050000   3.075000     0.003325     0.002675     -0.006275
# 3   7.850000   8.650000  -0.800000     0.046600    -0.090450      0.070950
# 4   1.216667  -9.266667  10.483333     0.028733    -0.104417      0.016200
# 5 -12.120000  -5.500000  -6.620000    -0.023620     0.050620     -0.002160
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0     0.032375     0.022550     -0.010800
# 1    -0.029393     0.057486     -0.012164
# 2    -0.014170    -0.046300      0.012500
# 3     0.008700    -0.031525      0.032225
# 4    -0.031700    -0.041133     -0.053467
# 5     0.013100     0.028000     -0.047000

# %%
#compare and contrast with _____________ more_precise_df_1

# %%
more_precise_df
# Out:
# Empty DataFrame
# Columns: [DATE, HOME_ABBR, VISITOR_ABBR, PTS_home, PTS_away, MARGIN, FG_PCT_home, FT_PCT_home, FG3_PCT_home, FG_PCT_away, FT_PCT_away, FG3_PCT_away, home_winning_percentage, diff_%]
# Index: []

# %%
more_precise_df_1
# Out:
#       DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN FG_PCT_home  \
# 8  2/26/22       MIA         HOME     -0.8    -6.33     -6           0
#
#   FT_PCT_home FG3_PCT_home FG_PCT_away FT_PCT_away FG3_PCT_away  \
# 8       -0.02         0.01           0           0            0
#
#   home_winning_percentage diff_%
# 8                    0.62    0.3

# %%
group_by_date_for_ml
# Out:
#   PTS_home PTS_away MARGIN FG_PCT_home FT_PCT_home FG3_PCT_home FG_PCT_away  \
# 0    107.4    114.1   -6.7      0.4386      0.7811       0.3202      0.4868
# 1    120.4    110.2   10.2      0.5212      0.7941       0.4002      0.4559
# 2    119.6    119.7   -0.1      0.5166      0.8492       0.3555      0.4662
# 3    104.6    109.3   -4.7      0.4665      0.7188       0.3287      0.4716
# 4      110      113     -3        0.46        0.83         0.36        0.47
# 5    113.9      110    3.9      0.4555      0.8219       0.3308      0.4548
# 6    122.2    103.1   19.1      0.5054      0.8361       0.4008      0.4454
#
#   FT_PCT_away FG3_PCT_away
# 0      0.7988       0.3766
# 1      0.7516       0.3611
# 2      0.6793       0.3271
# 3      0.7919       0.3854
# 4         0.8         0.34
# 5      0.7845        0.358
# 6      0.7534       0.3186

# %%
group_by_date_for_ml['PTS_home'] = pd.to_numeric(group_by_date_for_ml['PTS_home'])
group_by_date_for_ml['PTS_away'] = pd.to_numeric(group_by_date_for_ml['PTS_away'])
group_by_date_for_ml['MARGIN'] = pd.to_numeric(group_by_date_for_ml['MARGIN'])
group_by_date_for_ml['FG_PCT_home'] = pd.to_numeric(group_by_date_for_ml['FG_PCT_home'])
group_by_date_for_ml['FT_PCT_home'] = pd.to_numeric(group_by_date_for_ml['FT_PCT_home'])
group_by_date_for_ml['FG3_PCT_home'] = pd.to_numeric(group_by_date_for_ml['FG3_PCT_home'])
group_by_date_for_ml['FG_PCT_away'] = pd.to_numeric(group_by_date_for_ml['FG_PCT_away'])
group_by_date_for_ml['FT_PCT_away'] = pd.to_numeric(group_by_date_for_ml['FT_PCT_away'])
group_by_date_for_ml['FG3_PCT_away'] = pd.to_numeric(group_by_date_for_ml['FG3_PCT_away'])

# %%
combined_df = diff_df + group_by_date_for_ml
combined_df['DATE'] = date1
combined_df['HOME_ABBR'] = home_abbr1
combined_df['VISITOR_ABBR'] = visitor_abbr1
combined_df['home_winning_percentage'] = home_winning_percentage
combined_df['visitor_winning_percentage'] = visitor_winning_percentage
combined_df['diff_%'] = diff
combined_df = combined_df[['DATE','HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away','home_winning_percentage',
       'visitor_winning_percentage', 'diff_%']]

# %%
combined_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR    PTS_home    PTS_away     MARGIN  \
# 0  2022-03-01       WAS          DET  121.450000  120.850000   0.600000
# 1  2022-03-01       BOS          ATL  110.192857  101.742857   8.450000
# 2  2022-03-01       TOR          BRK  117.225000  108.950000   8.275000
# 3  2022-03-01       HOU          LAC  116.050000  115.550000   0.500000
# 4  2022-03-01       MIN          GSW  117.716667  102.833333  14.883333
# 5  2022-03-01       LAL          DAL   97.680000  105.200000  -7.520000
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.510450     0.763550      0.361400     0.463975     0.784850
# 1     0.471436     0.848586      0.346764     0.413207     0.876686
# 2     0.466525     0.765775      0.390525     0.440630     0.738200
# 3     0.493200     0.579950      0.403750     0.477200     0.706075
# 4     0.487733     0.641983      0.364400     0.422000     0.765167
# ...

# %%
group_by_date_for_ml['HOME_ABBR'] = home_abbr1
group_by_date_for_ml['VISITOR_ABBR'] = visitor_abbr1
group_by_date_for_ml = group_by_date_for_ml[['HOME_ABBR', 'VISITOR_ABBR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away']]

# %%
diff_df['HOME_ABBR'] = home_abbr1
diff_df['VISITOR_ABBR'] = visitor_abbr1
diff_df = diff_df[['HOME_ABBR', 'VISITOR_ABBR','PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home',
       'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away']]

# %%
combined_df.to_csv('../3-data_analysis/prediction/for_ml_data/03_02_for_ml.csv', index=False)

# %%
combined_df

# %%
group_by_date_for_ml
# Out:
#   HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0       WAS          DET     108.4     105.8     2.6       0.4593
# 1       BOS          ATL     111.2     109.1     2.1       0.4744
# 2       TOR          BRK     115.2     110.0     5.2       0.4632
# 3       HOU          LAC     108.2     106.9     1.3       0.4466
# 4       MIN          GSW     116.5     112.1     4.4       0.4590
# 5       LAL          DAL     109.8     110.7    -0.9       0.4570
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.8101        0.3108       0.4316       0.7623        0.3585
# 1       0.8166        0.3439       0.4426       0.8192        0.3360
# 2       0.7631        0.3968       0.4548       0.7845        0.3580
# 3       0.6704        0.3328       0.4685       0.7376        0.3567
# 4       0.7464        0.3482       0.4537       0.8063        0.3793
# 5       0.7187        0.3147       0.4809       0.7548        0.3760

# %%
group_by_date_for_ml.to_csv('results/03_02_grouped.csv', index=False)

# %%
diff_df.to_csv('results/03_02_diff.csv', index=False)

# %%
more_precise_df.to_csv('results/03_02_more_precise.csv', index=False)

# %%
pwd
# Out:
# '/Users/stanleytan/Documents/ucb/ucb_/33-prev_projects/stack/4-Project/inclass/3rd_project_tied_4th/first_step/machine_learning_nba/1-webscraper'

# %%
combined_df
#this is the dataset for machine learning
# Out:
#          DATE HOME_ABBR VISITOR_ABBR    PTS_home    PTS_away     MARGIN  \
# 0  2022-02-25       CHO          TOR   88.700000  106.110000 -17.410000
# 1  2022-02-25       IND          OKC  112.650000   97.500000  15.150000
# 2  2022-02-25       ORL          HOU  115.450000  113.350000   2.100000
# 3  2022-02-25       WAS          SAS  104.506250  112.862500  -8.356250
# 4  2022-02-25       NYK          MIA  102.820833  112.416667  -9.595833
# 5  2022-02-25       MIN          PHI  119.494444  107.816667  11.677778
# 6  2022-02-25       PHO          NOP  116.350000   98.362500  17.987500
# 7  2022-02-25       UTA          DAL  110.362500   98.975000  11.387500
# 8  2022-02-25       LAL          LAC  115.730000  111.716667   4.013333
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.357550     0.663900      0.222700     0.434320     0.818640
# 1     0.471250     0.738950      0.337650     0.410900     0.713000
# ...

# %%
combined_df.to_csv('feb_25_for_ml.csv', index=False)

# %%
den_df = den_df.round({"diff_%":1})

# %%
mean_grouped_den_df = den_df.groupby("diff_%").mean().reset_index()

# %%
mean_grouped_den_df = mean_grouped_den_df.loc[mean_grouped_den_df['diff_%'] == diff]

# %%
grouped_ = pd.concat((mean_grouped_sac_df, mean_grouped_den_df))

# %%
grouped_
# Out:
#    diff_%  PTS_home  PTS_away     MARGIN  FG_PCT_home  FT_PCT_home  \
# 1    -0.2 -7.600000  3.040000 -10.640000    -0.024500     0.016300
# 1    -0.2 -2.266667 -0.233333  -2.033333    -0.008933     0.010567
#
#    FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 1       -0.0365    -0.002480     0.053060     -0.004700
# 1       -0.0470     0.002467    -0.023233     -0.015567
#
#    home_winning_percentage  visitor_winning_percentage
# 1                 0.372494                    0.564071
# 1                 0.322531                    0.529605

# %%
grouped_.mean()
# Out:
# diff_%                       -0.200000
# PTS_home                     -4.933333
# PTS_away                      1.403333
# MARGIN                       -6.336667
# FG_PCT_home                  -0.016717
# FT_PCT_home                   0.013433
# FG3_PCT_home                 -0.041750
# FG_PCT_away                  -0.000007
# FT_PCT_away                   0.014913
# FG3_PCT_away                 -0.010133
# home_winning_percentage       0.347513
# visitor_winning_percentage    0.546838
# dtype: float64

# %%
grouped_df = lac_df.groupby("diff_%")

# %%
mean_df = grouped_df.mean().reset_index()

# %%
mean_df.loc[mean_df['diff_%'] == 0.0]
# Out:
#    diff_%   PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  \
# 3     0.0 -11.271429 -7.171429    -4.1    -0.012914    -0.021029
#
#    FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 3     -0.033771    -0.028129     0.074386     -0.072886
#
#    home_winning_percentage  visitor_winning_percentage
# 3                 0.528201                     0.51353

# %%
mean_df = grouped_df.mean().reset_index

# %%
mean_df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-116590b223b9> in <module>
# ----> 1 mean_df.info()
#
# AttributeError: 'function' object has no attribute 'info'

# %%
mean_df.loc[mean_df['diff_%'] == '0.0']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-96f84a44e81b> in <module>
# ----> 1 mean_df.loc[mean_df['diff_%'] == '0.0']
#
# AttributeError: 'function' object has no attribute 'loc'

# %%
lac_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 13  2021-11-16       LAC          SAS      -7.7     -21.4    13.7
# 49  2021-11-21       LAC          DAL     -16.7     -18.8     2.1
# 67  2021-11-23       LAC          DAL      -9.7       2.2   -11.9
# 81  2021-11-26       LAC          DET      -6.7      -5.8    -0.9
# 101 2021-11-28       LAC          GSW     -23.7      -3.5   -20.2
# 114 2021-11-29       LAC          NOP      -9.7      17.6   -27.3
# 128 2021-12-01       LAC          SAC       1.3      20.9   -19.6
# 179 2021-12-08       LAC          BOS       0.3      -0.7     1.0
# 192 2021-12-11       LAC          ORL      -7.7      -4.6    -3.1
# 213 2021-12-13       LAC          PHO      -2.7     -18.2    15.5
# 258 2021-12-20       LAC          SAS     -21.7       2.6   -24.3
# 292 2021-12-26       LAC          DEN     -13.7      -8.9    -4.8
# 299 2021-12-27       LAC          BRK      -5.7      14.0   -19.7
# ...

# %%
date1 = group_by_date_df['DATE']
home_abbr1 = group_by_date_df['HOME_ABBR']
visitor_abbr1 = group_by_date_df['VISITOR_ABBR']
home_winning_percentage = group_by_date_df['home_winning_percentage']
visitor_winning_percentage = group_by_date_df['visitor_winning_percentage']

# %%
calculated_df
# Out:
#      PTS_home  PTS_away  MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0       -12.6     -13.7     1.1      -0.0805       0.0312        0.0713
# 1        -2.4      25.9   -28.3      -0.0435       0.1575       -0.0622
# 2         0.2      -5.4     5.6       0.0110      -0.1259        0.0583
# 3         8.6       2.4     6.2       0.0318      -0.1381        0.0668
# 4       -15.0     -27.5    12.5      -0.0108      -0.0579       -0.0336
# ..        ...       ...     ...          ...          ...           ...
# 680       2.9       0.6     2.3      -0.0131      -0.0386       -0.0299
# 681      -5.0       7.7   -12.7      -0.0523      -0.0869        0.0554
# 682       8.0      15.2    -7.2       0.0236      -0.1743        0.1432
# 683       6.1      11.7    -5.6      -0.0135      -0.0359       -0.0128
# 684      28.3      -0.5    28.8       0.0768       0.0674        0.1168
#
#      FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0        -0.0182      -0.0170       -0.0289
# ...

# %%
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-11-15       CLE          BOS        92        98      -6
# 1   2021-11-15       DET          SAC       107       129     -22
# 2   2021-11-15       WAS          NOP       105       100       5
# 3   2021-11-15       ATL          ORL       129       111      18
# 4   2021-11-15       NYK          IND        92        84       8
# ..         ...       ...          ...       ...       ...     ...
# 680 2022-02-17       CHO          MIA       107       111      -4
# 681 2022-02-17       BRK          WAS       103       117     -14
# 682 2022-02-17       NOP          DAL       118       125      -7
# 683 2022-02-17       MIL          PHI       120       123      -3
# 684 2022-02-17       LAC          HOU       142       111      31
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 0        0.386        0.750         0.400        18
# ...

# %%
group_by_date_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0  2022-02-16       ORL          ATL     104.5     111.4    -6.9       0.4425
# 1  2022-02-16       BOS          DET     111.2     101.8     9.4       0.4744
# 2  2022-02-16       IND          WAS     114.6     109.3     5.3       0.4804
# 3  2022-02-16       NYK          BRK     107.0     110.0    -3.0       0.4408
# 4  2022-02-16       CHI          SAC     120.1     103.1    17.0       0.5225
# 5  2022-02-16       MEM          POR     116.0     107.4     8.6       0.4731
# 6  2022-02-16       MIN          TOR     114.0     110.7     3.3       0.4553
# 7  2022-02-16       OKC          SAS     100.8     113.4   -12.6       0.4170
# 8  2022-02-16       PHO          HOU     118.8     111.5     7.3       0.4997
# 9  2022-02-16       GSW          DEN     115.3     111.9     3.4       0.4823
# 10 2022-02-16       LAL          UTA     113.1     107.4     5.7       0.4709
# ...

# %%
for ind in obtain_ten_df_2.index:
    empty_ = []
    date_1 = obtain_ten_df_2.loc[ind]['DATE']
    home_1 = obtain_ten_df_2.loc[ind]['HOME_ABBR']
    visitor_1 = obtain_ten_df_2.loc[ind]['VISITOR_ABBR']
    empty_.append(date_1)
    empty_.append(home_1)
    empty_.append(visitor_1)
    home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] == home_1].tail(10).mean().reset_index()
    home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
    visitor_df_group_by = box_score_df.loc[box_score_df['VISITOR_ABBR'] == visitor_1].tail(10).mean().reset_index()
    visitor_df_dict = dict(zip(visitor_df_group_by.iloc[:,0].tolist(), visitor_df_group_by.iloc[:,1].tolist()))
    empty_.append(home_df_dict['PTS_home'])
    empty_.append(visitor_df_dict['PTS_away'])
    margin = home_df_dict['PTS_home'] - visitor_df_dict['PTS_away']
    empty_.append(margin)
    empty_.append(home_df_dict['FG_PCT_home'])
    empty_.append(home_df_dict['FT_PCT_home'])
    empty_.append(home_df_dict['FG3_PCT_home'])
    empty_.append(visitor_df_dict['FG_PCT_away'])
    empty_.append(visitor_df_dict['FT_PCT_away'])
    empty_.append(visitor_df_dict['FG3_PCT_away'])
    empty_.append(obtain_ten_df_2.loc[ind]['home_winning_percentage'])
    empty_.append(obtain_ten_df_2.loc[ind]['visitor_winning_percentage'])
    length_of_df = len(group_by_date_df)
    group_by_date_df.loc[length_of_df] = empty_

# %%
for ind in obtain_ten_df_2.index:
    print(ind)
    print(obtain_ten_df_2.loc[ind]['HOME_ABBR'])
#logically thinking why do I see LAC, because it gets to that last
# Out:
# 878
# CHO
# 879
# BRK
# 880
# NOP
# 881
# MIL
# 882
# LAC

# %%
len(empty_)
# Out:
# 14

# %%
home_1
# Out:
# 'LAC'

# %%
empty_
# Out:
# [Timestamp('2022-02-17 00:00:00'),
#  'LAC',
#  'HOU',
#  113.7,
#  111.5,
#  2.200000000000003,
#  0.4772,
#  0.7786,
#  0.39719999999999994,
#  0.45010000000000006,
#  0.7601,
#  0.3534,
#  0.4918032786885246,
#  0.25862068965517243]

# %%
obtain_ten_df_2 = schedule_df_1[schedule_df_1['DATE'] == '2022-02-24']
obtain

# %%
box_score_df_feb_14 = box_score_df.loc[box_score_df['DATE'] == '2022-02-14']

# %%
box_score_df_feb_14.to_csv('box_score_feb_14_only.csv', index=False)

# %%
test_df = box_score_df.loc[box_score_df['HOME_ABBR'] == 'DEN']

# %%
pip install basketball-reference-scraper
# Out:
# ...
#   Using cached basketball_reference_scraper-1.0.26-py3-none-any.whl (46 kB)
# ...
#      |████████████████████████████████| 10.3 MB 14.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.6 MB 40.6 MB/s eta 0:00:01
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# ...
#   Using cached soupsieve-1.9.5-py2.py3-none-any.whl (33 kB)
# ...
#      |████████████████████████████████| 15.2 MB 35.5 MB/s eta 0:00:01
# ...
#   Using cached pytz-2019.3-py2.py3-none-any.whl (509 kB)
# ...
#   Using cached beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
# ...
#   Using cached six-1.13.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# ...
#   Created wheel for lxml: filename=lxml-4.4.2-cp38-cp38-macosx_10_9_x86_64.whl size=1787706 sha256=f37d00d5c1681cc6c554151f54eb613c40b7330f2107c9bc7348719f5408ec50
#   Stored in directory: /Users/stanleytan/Library/Caches/pip/wheels/f0/48/b1/afbc9466bd44895c9ce63c8f43745399f5e8f6783c21f429de
# ...

# %%
pip install Unidecode
# Out:
# ...
#   Using cached Unidecode-1.1.2-py2.py3-none-any.whl (239 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from basketball_reference_scraper.seasons import get_schedule, get_standings

df = get_schedule(2022, playoffs=False)

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

# %%
schedule_df_1 = df.dropna()

# %%
schedule_df_1 = schedule_df_1.drop_duplicates(subset=['DATE'])

# %%
schedule_df_1.to_csv('schedule_df_dropped_duplicates.csv', index=False)

# %%
schedule_df = df.copy()

# %%
schedule_df = schedule_df.fillna(0)

# %%
schedule_df.to_csv('schedule_2022.csv', index=False)

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0    2021-10-19          Brooklyn Nets        104.0      Milwaukee Bucks
# 1    2021-10-19  Golden State Warriors        121.0   Los Angeles Lakers
# 2    2021-10-20         Indiana Pacers        122.0    Charlotte Hornets
# 3    2021-10-20          Chicago Bulls         94.0      Detroit Pistons
# 4    2021-10-20         Boston Celtics        134.0      New York Knicks
# ...         ...                    ...          ...                  ...
# 1225 2022-04-10     Los Angeles Lakers          NaN       Denver Nuggets
# 1226 2022-04-10      San Antonio Spurs          NaN     Dallas Mavericks
# 1227 2022-04-10        Milwaukee Bucks          NaN  Cleveland Cavaliers
# 1228 2022-04-10     Washington Wizards          NaN    Charlotte Hornets
# 1229 2022-04-10         Indiana Pacers          NaN        Brooklyn Nets
#
#       HOME_PTS
# 0        127.0
# 1        114.0
# 2        123.0
# 3         88.0
# ...

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0    2021-10-19          Brooklyn Nets        104.0      Milwaukee Bucks
# 1    2021-10-19  Golden State Warriors        121.0   Los Angeles Lakers
# 2    2021-10-20         Indiana Pacers        122.0    Charlotte Hornets
# 3    2021-10-20          Chicago Bulls         94.0      Detroit Pistons
# 4    2021-10-20         Boston Celtics        134.0      New York Knicks
# ...         ...                    ...          ...                  ...
# 1225 2022-04-10     Los Angeles Lakers          NaN       Denver Nuggets
# 1226 2022-04-10      San Antonio Spurs          NaN     Dallas Mavericks
# 1227 2022-04-10        Milwaukee Bucks          NaN  Cleveland Cavaliers
# 1228 2022-04-10     Washington Wizards          NaN    Charlotte Hornets
# 1229 2022-04-10         Indiana Pacers          NaN        Brooklyn Nets
#
#       HOME_PTS
# 0        127.0
# 1        114.0
# 2        123.0
# 3         88.0
# ...

# %%
schedule_df_1 = schedule_df.copy()

# %%
schedule_df_1['HOME_ABBR'] = 0
schedule_df_1['VISITOR_ABBR'] = 0
schedule_df_1 = schedule_df.fillna(0)

# %%
schedule_df_1
# Out:
#            DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0    2021-10-19          Brooklyn Nets        104.0      Milwaukee Bucks
# 1    2021-10-19  Golden State Warriors        121.0   Los Angeles Lakers
# 2    2021-10-20         Indiana Pacers        122.0    Charlotte Hornets
# 3    2021-10-20          Chicago Bulls         94.0      Detroit Pistons
# 4    2021-10-20         Boston Celtics        134.0      New York Knicks
# ...         ...                    ...          ...                  ...
# 1225 2022-04-10     Los Angeles Lakers          0.0       Denver Nuggets
# 1226 2022-04-10      San Antonio Spurs          0.0     Dallas Mavericks
# 1227 2022-04-10        Milwaukee Bucks          0.0  Cleveland Cavaliers
# 1228 2022-04-10     Washington Wizards          0.0    Charlotte Hornets
# 1229 2022-04-10         Indiana Pacers          0.0        Brooklyn Nets
#
#       HOME_PTS
# 0        127.0
# 1        114.0
# 2        123.0
# 3         88.0
# ...

# %%
schedule_df['MARGIN'] = 0
schedule_df['HOME_ABBR'] = 0
schedule_df['VISITOR_ABBR'] = 0
schedule_df['HOME_TEAM_WINS'] = 0 
schedule_df = schedule_df.fillna(0)

# %%
for ind in schedule_df.index: 
    schedule_df['MARGIN'][ind] = schedule_df['HOME_PTS'][ind] - schedule_df['VISITOR_PTS'][ind]
    schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
    schedule_df['HOME'][ind] = schedule_df['HOME'][ind].upper()
    schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df['HOME'][ind]]
    schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df['VISITOR'][ind]]
    if schedule_df['MARGIN'][ind] > 0: 
        schedule_df['HOME_TEAM_WINS'][ind] = 1
    else:
        schedule_df['HOME_TEAM_WINS'][ind] = 0
# Out:
# <ipython-input-6-554545badcb2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['MARGIN'][ind] = schedule_df['HOME_PTS'][ind] - schedule_df['VISITOR_PTS'][ind]
# <ipython-input-6-554545badcb2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
# <ipython-input-6-554545badcb2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
schedule_df = schedule_df.tail(16)

# %%
schedule_df.columns
# Out:
# Index(['DATE', 'VISITOR', 'VISITOR_PTS', 'HOME', 'HOME_PTS', 'MARGIN',
#        'HOME_ABBR', 'VISITOR_ABBR', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
schedule_df.iloc[849,1]
# Out:
# 'ATLANTA HAWKS'

# %%
schedule_df.iloc[849,1]
# Out:
# 'ATLANTA HAWKS'

# %%
schedule_df = schedule_df.head(883)

# %%
#test
#from basketball_reference_scraper.box_scores import get_box_scores
#dict_ = get_box_scores(schedule_df.iloc[849,0], schedule_df.iloc[849,7], schedule_df.iloc[849,6], period='GAME', stat_type='BASIC')
#import pandas as pd
#test_ = pd.DataFrame.from_dict(dict_.items())
#from basketball_reference_scraper.box_scores import get_box_scores
#dict_ = get_box_scores(schedule_df.iloc[849,0], schedule_df.iloc[849,7], schedule_df.iloc[849,6], period='GAME', stat_type='BASIC')

# %%
schedule_df = schedule_df.tail(16)

# %%
schedule_df_0 = schedule_df.copy()

# %%
schedule_df
# Out:
#           DATE                 VISITOR  VISITOR_PTS                    HOME  \
# 867 2022-02-16           ATLANTA HAWKS        130.0           ORLANDO MAGIC
# 868 2022-02-16         Detroit Pistons        112.0          Boston Celtics
# 869 2022-02-16      Washington Wizards        108.0          Indiana Pacers
# 870 2022-02-16           Brooklyn Nets        111.0         New York Knicks
# 871 2022-02-16        Sacramento Kings        118.0           Chicago Bulls
# 872 2022-02-16  Portland Trail Blazers        123.0       Memphis Grizzlies
# 873 2022-02-16         Toronto Raptors        103.0  Minnesota Timberwolves
# 874 2022-02-16       San Antonio Spurs        114.0   Oklahoma City Thunder
# 875 2022-02-16         Houston Rockets        121.0            Phoenix Suns
# 876 2022-02-16          Denver Nuggets        117.0   Golden State Warriors
# 877 2022-02-16               Utah Jazz        101.0      Los Angeles Lakers
# ...

# %%
import pandas as pd

# %%
box_score_columns = box_score_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']
box_score_df = pd.DataFrame(columns=box_score_columns)

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

schedule_df_0['HOME_ABBR'] = 0
schedule_df_0['VISITOR_ABBR'] = 0
schedule_df['HOME_ABBR'] = 0
schedule_df['VISITOR_ABBR'] = 0

for ind in schedule_df_0.index: 
    schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
    schedule_df['HOME'][ind] =schedule_df['HOME'][ind].upper()
    schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df['HOME'][ind]]
    schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df['VISITOR'][ind]]
# Out:
# <ipython-input-100-346e401bf7d5>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
# <ipython-input-100-346e401bf7d5>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['HOME'][ind] =schedule_df['HOME'][ind].upper()
# <ipython-input-100-346e401bf7d5>:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import pandas as pd
schedule_df = pd.read_csv('full_schedule_2021_V2.csv')

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                    HOME  \
# 0    2020-12-22  GOLDEN STATE WARRIORS         99.0           BROOKLYN NETS
# 1    2020-12-22   LOS ANGELES CLIPPERS        116.0      LOS ANGELES LAKERS
# 2    2020-12-23      CHARLOTTE HORNETS        114.0     CLEVELAND CAVALIERS
# 3    2020-12-23        NEW YORK KNICKS        107.0          INDIANA PACERS
# 4    2020-12-23             MIAMI HEAT        107.0           ORLANDO MAGIC
# ..          ...                    ...          ...                     ...
# 535  2021-03-04        MILWAUKEE BUCKS          0.0       MEMPHIS GRIZZLIES
# 536  2021-03-04  OKLAHOMA CITY THUNDER          0.0       SAN ANTONIO SPURS
# 537  2021-03-04             MIAMI HEAT          0.0    NEW ORLEANS PELICANS
# 538  2021-03-04  GOLDEN STATE WARRIORS          0.0            PHOENIX SUNS
# 539  2021-03-04       SACRAMENTO KINGS          0.0  PORTLAND TRAIL BLAZERS
#
# ...

# %%
from basketball_reference_scraper.box_scores import get_box_scores

import time
for ind in schedule_df.index:
    date_1 = schedule_df.loc[ind]['DATE']
    home_1 = schedule_df.loc[ind]['HOME_ABBR']
    visitor_1 = schedule_df.loc[ind]['VISITOR_ABBR']
    dict_ = get_box_scores(date_1, visitor_1, home_1, period='GAME', stat_type='BASIC')
    home_df = dict_[home_1]
    visitor_df = dict_[visitor_1]
    #id_ = schedule_df.loc[ind]['ID']
    #unsure why the ID is required
    home_pts = home_df.loc[home_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    visitor_pts = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    margin_ = int(home_pts) - int(visitor_pts)
    if margin_ > 0:
        home_team_wins = 1
    else:
        home_team_wins = 0
    home_fg_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    home_ft_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    home_fg3_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    home_ast = home_df.loc[home_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    home_reb = home_df.loc[home_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    visitor_fg_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    visitor_ft_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    visitor_fg3_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    visitor_ast = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    visitor_reb = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    empty_ = []
    #empty_.append(id_)
#ID unsure why that is required
    empty_.append(date_1)
#DATE
    empty_.append(home_1)
#home abbr
    empty_.append(visitor_1)
#visito abbr
    empty_.append(home_pts)
#home pints
    empty_.append(visitor_pts)
#away points
    empty_.append(margin_)
#margin
    empty_.append(home_team_wins)
#HOME_TEAM_WINS
    empty_.append(home_fg_pct)
#FG_PCT
    empty_.append(home_ft_pct)
#FT_PCT
    empty_.append(home_fg3_pct)
#FG3_PCT
    empty_.append(home_ast)
#AST
    empty_.append(home_reb)
#REBOUNDS
    empty_.append(visitor_fg_pct)
#FG_PCT
    empty_.append(visitor_ft_pct)
#FT_PCT
    empty_.append(visitor_fg3_pct)
#FG3
    empty_.append(visitor_ast)
#AST
    empty_.append(visitor_reb)
#REBOUNDS
    length_of_df = len(box_score_df)
    box_score_df.loc[length_of_df] = empty_
    print(empty_)
# Out:
# [Timestamp('2022-02-16 00:00:00'), 'ORL', 'ATL', '109', '130', -21, 0, '.429', '.923', '.317', '23', '45', '.500', '.786', '.545', '23', '47']
# [Timestamp('2022-02-16 00:00:00'), 'BOS', 'DET', '111', '112', -1, 0, '.545', '.778', '.406', '29', '30', '.462', '.769', '.533', '28', '47']
# [Timestamp('2022-02-16 00:00:00'), 'IND', 'WAS', '113', '108', 5, 1, '.542', '.655', '.200', '30', '40', '.429', '.813', '.459', '25', '44']
# [Timestamp('2022-02-16 00:00:00'), 'NYK', 'BRK', '106', '111', -5, 0, '.435', '.889', '.372', '22', '44', '.439', '.609', '.324', '21', '51']
# [Timestamp('2022-02-16 00:00:00'), 'CHI', 'SAC', '125', '118', 7, 1, '.500', '.950', '.414', '25', '47', '.512', '.909', '.400', '24', '36']
# [Timestamp('2022-02-16 00:00:00'), 'MEM', 'POR', '119', '123', -4, 0, '.435', '.810', '.367', '20', '39', '.506', '.750', '.406', '23', '43']
# ...

# %%
box_score_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN HOME_TEAM_WINS  \
# 0  2022-02-16       ORL          ATL      109      130    -21              0
# 1  2022-02-16       BOS          DET      111      112     -1              0
# 2  2022-02-16       IND          WAS      113      108      5              1
# 3  2022-02-16       NYK          BRK      106      111     -5              0
# 4  2022-02-16       CHI          SAC      125      118      7              1
# 5  2022-02-16       MEM          POR      119      123     -4              0
# 6  2022-02-16       MIN          TOR       91      103    -12              0
# 7  2022-02-16       OKC          SAS      106      114     -8              0
# 8  2022-02-16       PHO          HOU      124      121      3              1
# 9  2022-02-16       GSW          DEN      116      117     -1              0
# 10 2022-02-16       LAL          UTA      106      101      5              1
# ...

# %%
box_score_df_3
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0    2021-10-19       MIL          BRK       127       104      23
# 1    2021-10-19       LAL          GSW       114       121      -7
# 2    2021-10-20       CHO          IND       123       122       1
# 3    2021-10-20       DET          CHI        88        94      -6
# 4    2021-10-20       NYK          BOS       138       134       4
# ..          ...       ...          ...       ...       ...     ...
# 862  2022-02-15       PHI          BOS        87       135     -48
# 863  2022-02-15       MIL          IND       128       119       9
# 864  2022-02-15       MIN          CHO       126       120       6
# 865  2022-02-15       NOP          MEM       109       121     -12
# 866  2022-02-15       PHO          LAC       103        96       7
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
result = pd.concat([df1, df4], axis=1)

# %%
result = pd.concat([box_score_df_3, box_score_df], axis=0)

# %%
box_score_df = result.copy()

# %%
box_score_df.to_csv('box_score_df_feb_21.csv', index=False)

# %%
import pandas as pd
box_score_df_3 = pd.read_csv('box_score_df_feb_21.csv')

# %%
box_score_df_3.tail()
# Out:
#                     DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 878  2022-02-17 00:00:00       CHO          MIA       107       111      -4
# 879  2022-02-17 00:00:00       BRK          WAS       103       117     -14
# 880  2022-02-17 00:00:00       NOP          DAL       118       125      -7
# 881  2022-02-17 00:00:00       MIL          PHI       120       123      -3
# 882  2022-02-17 00:00:00       LAC          HOU       142       111      31
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 878               0        0.400        0.700         0.238        27
# 879               0        0.404        0.708         0.368        19
# 880               0        0.500        0.667         0.429        22
# 881               0        0.442        0.786         0.318        20
# 882               1        0.554        0.846         0.514        34
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# ...

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0)

# %%
# adding winning percentage for another
# df = pd.read_csv('old_data/abbr_games.csv')

# %%
box_score_df["DATE"]= pd.to_datetime(box_score_df["DATE"])
box_score_df['PTS_home'] = pd.to_numeric(box_score_df['PTS_home'])
box_score_df['PTS_away'] = pd.to_numeric(box_score_df['PTS_away'])
box_score_df['MARGIN'] = pd.to_numeric(box_score_df['MARGIN'])
box_score_df['HOME_TEAM_WINS'] = pd.to_numeric(box_score_df['HOME_TEAM_WINS'])
box_score_df['FG_PCT_home'] = pd.to_numeric(box_score_df['FG_PCT_home'])
box_score_df['FT_PCT_home'] = pd.to_numeric(box_score_df['FT_PCT_home'])
box_score_df['FG3_PCT_home'] = pd.to_numeric(box_score_df['FG3_PCT_home'])
box_score_df['AST_home'] = pd.to_numeric(box_score_df['AST_home'])
box_score_df['REB_home'] = pd.to_numeric(box_score_df['REB_home'])
box_score_df['FG_PCT_away'] = pd.to_numeric(box_score_df['FG_PCT_away'])
box_score_df['FT_PCT_away'] = pd.to_numeric(box_score_df['FT_PCT_away'])
box_score_df['FG3_PCT_away'] = pd.to_numeric(box_score_df['FG3_PCT_away'])
box_score_df['AST_away'] = pd.to_numeric(box_score_df['AST_away'])
box_score_df['REB_away'] = pd.to_numeric(box_score_df['REB_away'])

# %%
box_score_df = box_score_df.reset_index(drop=True)

# %%
home_winning_percentage_list = []
visitor_winning_percentage_list = []
for ind in box_score_df.index:
    home_abbr = box_score_df.loc[ind]['HOME_ABBR']
    visitor_abbr = box_score_df.loc[ind]['VISITOR_ABBR']
    home_team_wins = box_score_df.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)
box_score_df['home_winning_percentage'] = home_winning_percentage_list
box_score_df['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
box_score_df.tail(10)
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 873 2022-02-16       MIN          TOR        91       103     -12
# 874 2022-02-16       OKC          SAS       106       114      -8
# 875 2022-02-16       PHO          HOU       124       121       3
# 876 2022-02-16       GSW          DEN       116       117      -1
# 877 2022-02-16       LAL          UTA       106       101       5
# 878 2022-02-17       CHO          MIA       107       111      -4
# 879 2022-02-17       BRK          WAS       103       117     -14
# 880 2022-02-17       NOP          DAL       118       125      -7
# 881 2022-02-17       MIL          PHI       120       123      -3
# 882 2022-02-17       LAC          HOU       142       111      31
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 873               0        0.390        0.724         0.238        23
# 874               0        0.390        0.684         0.344        25
# ...

# %%
box_score_df["DATE"]= pd.to_datetime(box_score_df["DATE"])
box_score_df['PTS_home'] = pd.to_numeric(box_score_df['PTS_home'])
box_score_df['PTS_away'] = pd.to_numeric(box_score_df['PTS_away'])
box_score_df['MARGIN'] = pd.to_numeric(box_score_df['MARGIN'])
box_score_df['HOME_TEAM_WINS'] = pd.to_numeric(box_score_df['HOME_TEAM_WINS'])
box_score_df['FG_PCT_home'] = pd.to_numeric(box_score_df['FG_PCT_home'])
box_score_df['FT_PCT_home'] = pd.to_numeric(box_score_df['FT_PCT_home'])
box_score_df['FG3_PCT_home'] = pd.to_numeric(box_score_df['FG3_PCT_home'])
box_score_df['AST_home'] = pd.to_numeric(box_score_df['AST_home'])
box_score_df['REB_home'] = pd.to_numeric(box_score_df['REB_home'])
box_score_df['FG_PCT_away'] = pd.to_numeric(box_score_df['FG_PCT_away'])
box_score_df['FT_PCT_away'] = pd.to_numeric(box_score_df['FT_PCT_away'])
box_score_df['FG3_PCT_away'] = pd.to_numeric(box_score_df['FG3_PCT_away'])
box_score_df['AST_away'] = pd.to_numeric(box_score_df['AST_away'])
box_score_df['REB_away'] = pd.to_numeric(box_score_df['REB_away'])
box_score_df['home_winning_percentage'] = pd.to_numeric(box_score_df['home_winning_percentage'])
box_score_df['visitor_winning_percentage'] = pd.to_numeric(box_score_df['visitor_winning_percentage'])

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 878 2022-02-17       CHO          MIA       107       111      -4
# 879 2022-02-17       BRK          WAS       103       117     -14
# 880 2022-02-17       NOP          DAL       118       125      -7
# 881 2022-02-17       MIL          PHI       120       123      -3
# 882 2022-02-17       LAC          HOU       142       111      31
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
test_df = box_score_df.loc[box_score_df['HOME_ABBR'] == 'DEN'].tail(10).mean().reset_index()

# %%
test_df
# Out:
#                          index           0
# 0                     PTS_home  122.200000
# 1                     PTS_away  113.300000
# 2                       MARGIN    8.900000
# 3               HOME_TEAM_WINS    0.700000
# 4                  FG_PCT_home    0.505400
# 5                  FT_PCT_home    0.836100
# 6                 FG3_PCT_home    0.400800
# 7                     AST_home   31.200000
# 8                     REB_home   43.500000
# 9                  FG_PCT_away    0.489600
# 10                 FT_PCT_away    0.766300
# 11                FG3_PCT_away    0.358800
# 12                    AST_away   25.700000
# 13                    REB_away   41.200000
# 14     home_winning_percentage    0.537893
# 15  visitor_winning_percentage    0.452558

# %%
res = dict(zip(test_df.iloc[:,0].tolist(), test_df.iloc[:,1].tolist()))

# %%
from basketball_reference_scraper.seasons import get_schedule, get_standings

df = get_schedule(2022, playoffs=False)

team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

schedule_df_1 = df.copy()
schedule_df_1['HOME_ABBR'] = 0
schedule_df_1['VISITOR_ABBR'] = 0
schedule_df_1 = schedule_df_1.fillna(0)

for ind in schedule_df_1.index: 
    schedule_df_1['VISITOR'][ind] = schedule_df_1['VISITOR'][ind].upper()
    schedule_df_1['HOME'][ind] = schedule_df_1['HOME'][ind].upper()
    schedule_df_1['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df_1['HOME'][ind]]
    schedule_df_1['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df_1['VISITOR'][ind]]
# Out:
# <ipython-input-123-9b83a9a0fa83>:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df_1['VISITOR'][ind] = schedule_df_1['VISITOR'][ind].upper()
# <ipython-input-123-9b83a9a0fa83>:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df_1['HOME'][ind] = schedule_df_1['HOME'][ind].upper()
# <ipython-input-123-9b83a9a0fa83>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
schedule_df_1
# Out:
#            DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0    2021-10-19          BROOKLYN NETS        104.0      MILWAUKEE BUCKS
# 1    2021-10-19  GOLDEN STATE WARRIORS        121.0   LOS ANGELES LAKERS
# 2    2021-10-20         INDIANA PACERS        122.0    CHARLOTTE HORNETS
# 3    2021-10-20          CHICAGO BULLS         94.0      DETROIT PISTONS
# 4    2021-10-20         BOSTON CELTICS        134.0      NEW YORK KNICKS
# ...         ...                    ...          ...                  ...
# 1225 2022-04-10     LOS ANGELES LAKERS          0.0       DENVER NUGGETS
# 1226 2022-04-10      SAN ANTONIO SPURS          0.0     DALLAS MAVERICKS
# 1227 2022-04-10        MILWAUKEE BUCKS          0.0  CLEVELAND CAVALIERS
# 1228 2022-04-10     WASHINGTON WIZARDS          0.0    CHARLOTTE HORNETS
# 1229 2022-04-10         INDIANA PACERS          0.0        BROOKLYN NETS
#
#       HOME_PTS HOME_ABBR VISITOR_ABBR
# 0        127.0       MIL          BRK
# ...

# %%
obtain_ten_df_2 = schedule_df_1[schedule_df_1['DATE'] == '2022-02-24']

# %%
group_by_date_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away']
group_by_date_df = pd.DataFrame(columns=group_by_date_columns)

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 846 2022-02-12       DAL          LAC        97        99      -2
# 847 2022-02-12       GSW          LAL       117       115       2
# 848 2022-02-12       PHO          ORL       132       105      27
# 849 2022-02-13       BOS          ATL       105        95      10
# 850 2022-02-13       IND          MIN       120       129      -9
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
obtain_ten_df.tail(1)
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 866  2022-02-15       PHO          LAC       103        96       7
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 866               1        0.489          0.7          0.32        30
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 866        52        0.412        0.667         0.286        26        46
#
#      home_winning_percentage  visitor_winning_percentage
# 866                 0.824561                    0.483333

# %%
#test
#visitor_df_group_by = box_score_df.loc[box_score_df['VISITOR_ABBR'] =='LAC'].tail(10).mean().reset_index()
#home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] =='PHO'].tail(10).mean().reset_index()

# %%
group_by_date_df.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'FG_PCT_away',
#        'FT_PCT_away', 'FG3_PCT_away'],
#       dtype='object')

# %%
# Out:
# <ipython-input-53-42e16680cb81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obtain_ten_df_2['HOME_ABBR'] = 0
# <ipython-input-53-42e16680cb81>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obtain_ten_df_2['VISITOR_ABBR'] = 0

# %%
obtain_ten_df_2
# Out:
#           DATE                VISITOR  VISITOR_PTS                    HOME  \
# 883 2022-02-24    CLEVELAND CAVALIERS          0.0         DETROIT PISTONS
# 884 2022-02-24         BOSTON CELTICS          0.0           BROOKLYN NETS
# 885 2022-02-24          ATLANTA HAWKS          0.0           CHICAGO BULLS
# 886 2022-02-24      MEMPHIS GRIZZLIES          0.0  MINNESOTA TIMBERWOLVES
# 887 2022-02-24           PHOENIX SUNS          0.0   OKLAHOMA CITY THUNDER
# 888 2022-02-24  GOLDEN STATE WARRIORS          0.0  PORTLAND TRAIL BLAZERS
# 889 2022-02-24         DENVER NUGGETS          0.0        SACRAMENTO KINGS
#
#      HOME_PTS HOME_ABBR VISITOR_ABBR
# 883       0.0       DET          CLE
# 884       0.0       BRK          BOS
# 885       0.0       CHI          ATL
# 886       0.0       MIN          MEM
# 887       0.0       OKC          PHO
# 888       0.0       POR          GSW
# 889       0.0       SAC          DEN

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

obtain_ten_df_2['HOME_ABBR'] = 0
obtain_ten_df_2['VISITOR_ABBR'] = 0

for ind in obtain_ten_df_2.index: 
    obtain_ten_df_2['VISITOR'][ind] = obtain_ten_df_2['VISITOR'][ind].upper()
    obtain_ten_df_2['HOME'][ind] = obtain_ten_df_2['HOME'][ind].upper()
    obtain_ten_df_2['HOME_ABBR'][ind] = team_to_abbreviation[obtain_ten_df_2['HOME'][ind]]
    obtain_ten_df_2['VISITOR_ABBR'][ind] = team_to_abbreviation[obtain_ten_df_2['VISITOR'][ind]]
# Out:
# <ipython-input-65-817f9a0eb305>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obtain_ten_df_2['HOME_ABBR'] = 0
# <ipython-input-65-817f9a0eb305>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obtain_ten_df_2['VISITOR_ABBR'] = 0
# <ipython-input-65-817f9a0eb305>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
obtain_ten_df_2
# Out:
#           DATE                 VISITOR  VISITOR_PTS                  HOME  \
# 851 2022-02-14         DETROIT PISTONS         94.0    WASHINGTON WIZARDS
# 852 2022-02-14        SACRAMENTO KINGS         85.0         BROOKLYN NETS
# 853 2022-02-14   OKLAHOMA CITY THUNDER        127.0       NEW YORK KNICKS
# 854 2022-02-14       SAN ANTONIO SPURS        109.0         CHICAGO BULLS
# 855 2022-02-14  PORTLAND TRAIL BLAZERS        122.0       MILWAUKEE BUCKS
# 856 2022-02-14         TORONTO RAPTORS         90.0  NEW ORLEANS PELICANS
# 857 2022-02-14           ORLANDO MAGIC        111.0        DENVER NUGGETS
# 858 2022-02-14         HOUSTON ROCKETS        101.0             UTAH JAZZ
# 859 2022-02-14   GOLDEN STATE WARRIORS        104.0  LOS ANGELES CLIPPERS
#
#      HOME_PTS HOME_ABBR VISITOR_ABBR
# 851     103.0       WAS          DET
# 852     109.0       BRK          SAC
# 853     123.0       NYK          OKC
# 854     120.0       CHI          SAS
# 855     107.0       MIL          POR
# ...

# %%
group_by_date_df
# Out:
# Empty DataFrame
# Columns: [DATE, HOME_ABBR, VISITOR_ABBR, PTS_home, PTS_away, MARGIN, FG_PCT_home, FT_PCT_home, FG3_PCT_home, FG_PCT_away, FT_PCT_away, FG3_PCT_away]
# Index: []

# %%
# set a new pandas dataframe
for ind in obtain_ten_df_2.index:
    empty_ = []
    date_1 = obtain_ten_df_2.loc[ind]['DATE']
    home_1 = obtain_ten_df_2.loc[ind]['HOME_ABBR']
    visitor_1 = obtain_ten_df_2.loc[ind]['VISITOR_ABBR']
    empty_.append(date_1)
    empty_.append(home_1)
    empty_.append(visitor_1)
    home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] == home_1].tail(10).mean().reset_index()
    home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
    visitor_df_group_by = box_score_df.loc[box_score_df['VISITOR_ABBR'] == visitor_1].tail(10).mean().reset_index()
    visitor_df_dict = dict(zip(visitor_df_group_by.iloc[:,0].tolist(), visitor_df_group_by.iloc[:,1].tolist()))
    empty_.append(home_df_dict['PTS_home'])
    empty_.append(visitor_df_dict['PTS_away'])
    margin = home_df_dict['PTS_home'] - visitor_df_dict['PTS_away']
    empty_.append(margin)
    empty_.append(home_df_dict['FG_PCT_home'])
    empty_.append(home_df_dict['FT_PCT_home'])
    empty_.append(home_df_dict['FG3_PCT_home'])
    empty_.append(visitor_df_dict['FG_PCT_away'])
    empty_.append(visitor_df_dict['FT_PCT_away'])
    empty_.append(visitor_df_dict['FG3_PCT_away'])
    length_of_df = len(group_by_date_df)
    group_by_date_df.loc[length_of_df] = empty_

# %%
group_by_date_df
# Out:
#         DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0 2022-02-24       DET          CLE     109.4     107.6     1.8       0.4495
# 1 2022-02-24       BRK          BOS     108.0     111.7    -3.7       0.4563
# 2 2022-02-24       CHI          ATL     120.1     111.4     8.7       0.5225
# 3 2022-02-24       MIN          MEM     114.0     119.7    -5.7       0.4553
# 4 2022-02-24       OKC          PHO     100.8     113.2   -12.4       0.4170
# 5 2022-02-24       POR          GSW     105.2     108.5    -3.3       0.4371
# 6 2022-02-24       SAC          DEN     117.5     111.9     5.6       0.4846
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0       0.7835        0.3392       0.4880       0.7338        0.3570
# 1       0.7949        0.3126       0.4802       0.8170        0.3739
# 2       0.8399        0.3714       0.4548       0.8400        0.3415
# 3       0.7331        0.3466       0.4689       0.6748        0.3206
# ...

# %%
group_by_date_df.to_csv('feb_16_2022.csv', index=False)

# %%
#how to 
#home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] == 'PHO'].tail(10).mean().reset_index()
#home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
winning_percentage_dict = dict.fromkeys(list_, 0)

# %%
box_score_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 878 2022-02-17       CHO          MIA       107       111      -4
# 879 2022-02-17       BRK          WAS       103       117     -14
# 880 2022-02-17       NOP          DAL       118       125      -7
# 881 2022-02-17       MIL          PHI       120       123      -3
# 882 2022-02-17       LAC          HOU       142       111      31
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# ...

# %%
for _, row in box_score_df.iterrows():
    home_team = row['HOME_ABBR']
    visitor_team = row['VISITOR_ABBR']
    home_winning_percentage = row['home_winning_percentage']
    visitor_winning_percentage = row['visitor_winning_percentage']
    
    if home_team in winning_percentage_dict:
            winning_percentage_dict[home_team] = home_winning_percentage
    elif visitor_team in winning_percentage_dict:
            winning_percentage_dict[visitor_team] = visitor_winning_percentage

# %%
home_winning_percentage_list = []
visitor_winning_percentage_list = []
for ind in group_by_date_df.index:
    home_abbr = group_by_date_df.loc[ind]['HOME_ABBR']
    visitor_abbr = group_by_date_df.loc[ind]['VISITOR_ABBR']
    home_winning_percentage_list.append(winning_percentage_dict[home_abbr])
    visitor_winning_percentage_list.append(winning_percentage_dict[visitor_abbr])
group_by_date_df['home_winning_percentage'] = home_winning_percentage_list
group_by_date_df['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
group_by_date_df
# Out:
#         DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  FG_PCT_home  \
# 0 2022-02-24       DET          CLE     109.4     107.6     1.8       0.4495
# 1 2022-02-24       BRK          BOS     108.0     111.7    -3.7       0.4563
# 2 2022-02-24       CHI          ATL     120.1     111.4     8.7       0.5225
# 3 2022-02-24       MIN          MEM     114.0     119.7    -5.7       0.4553
# 4 2022-02-24       OKC          PHO     100.8     113.2   -12.4       0.4170
# 5 2022-02-24       POR          GSW     105.2     108.5    -3.3       0.4371
# 6 2022-02-24       SAC          DEN     117.5     111.9     5.6       0.4846
#
#    FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0       0.7835        0.3392       0.4880       0.7338        0.3570
# 1       0.7949        0.3126       0.4802       0.8170        0.3739
# 2       0.8399        0.3714       0.4548       0.8400        0.3415
# 3       0.7331        0.3466       0.4689       0.6748        0.3206
# ...

# %%
group_by_date_df.to_csv('grouped_feb_24_2022.csv', index=False)

# %%
group_by_date_df_2 = group_by_date_df.copy()

# %%
group_by_date_df_2 = group_by_date_df_2.rename(columns={"home_winning_percentage": "home", "visitor_winning_percentage": "visitor"})

# %%
df['DataFrame Column'] = df['DataFrame Column'].astype(str)

# %%
group_by_date_df_2['home'] = group_by_date_df_2['home'].astype(str)
group_by_date_df_2['visitor'] = group_by_date_df_2['visitor'].astype(str)

# %%
group_by_date_df_2['home'] = group_by_date_df_2['home'].str[0:4]
group_by_date_df_2['visitor'] = group_by_date_df_2['visitor'].str[0:4]

# %%
group_by_date_df_2.to_csv('grouped_feb_24.csv')

# %%
 = df['Identifier'].str[3:8]

# %%
empty_2 = []

# %%
home_df_dict['PTS_home']
# Out:
# 117.0

# %%
empty_2.append(date)
empty_2.append(home_abbr)
empty_2.append(visitor_abbr)
empty_2.append(home_df_dict['PTS_home'])
empty_2.append()

# %%
home_df_dict
# Out:
# {'PTS_home': 117.0,
#  'PTS_away': 107.7,
#  'MARGIN': 9.3,
#  'HOME_TEAM_WINS': 0.9,
#  'FG_PCT_home': 0.4896,
#  'FT_PCT_home': 0.7440000000000001,
#  'FG3_PCT_home': 0.36489999999999995,
#  'AST_home': 30.6,
#  'REB_home': 47.9,
#  'FG_PCT_away': 0.4519,
#  'FT_PCT_away': 0.7510999999999999,
#  'FG3_PCT_away': 0.3536,
#  'AST_away': 22.9,
#  'REB_away': 42.3,
#  'home_winning_percentage': 0.8076050603259659,
#  'visitor_winning_percentage': 0.4862732904901367}

# %%
# set a new pandas dataframe
for ind in obtain_ten_df.index:
    empty_ = []
    date_1 = obtain_ten_df.loc[ind]['DATE']
    home_1 = obtain_ten_df.loc[ind]['HOME_ABBR']
    visitor_1 = obtain_ten_df.loc[ind]['VISITOR_ABBR']
    empty_.append(date_1)
    empty_.append(home_1)
    empty_.append(visitor_1)
    home_df_group_by = box_score_df.loc[box_score_df['HOME_ABBR'] == home_1].tail(10).mean().reset_index()

    home_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
    visitor_df_group_by = box_score_df.loc[box_score_df['VISITOR_ABBR'] == visitor_1].tail(10).mean().reset_index()
    visitor_df_dict = dict(zip(home_df_group_by.iloc[:,0].tolist(), home_df_group_by.iloc[:,1].tolist()))
    
    
     home_df[]
    
    length_of_df = len(group_by_date_df)
    group_by_date_df.loc[length_of_df] = empty_

# %%
obtain_ten_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 860 2022-02-15       ATL          CLE       124       116       8
# 861 2022-02-15       MIA          DAL        99       107      -8
# 862 2022-02-15       PHI          BOS        87       135     -48
# 863 2022-02-15       MIL          IND       128       119       9
# 864 2022-02-15       MIN          CHO       126       120       6
# 865 2022-02-15       NOP          MEM       109       121     -12
# 866 2022-02-15       PHO          LAC       103        96       7
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 860               1        0.538        0.889         0.424        25
# 861               0        0.417        0.815         0.259        19
# 862               0        0.288        0.846         0.250        17
# 863               1        0.558        0.733         0.345        28
# 864               1        0.394        0.628         0.236        29
# ...
