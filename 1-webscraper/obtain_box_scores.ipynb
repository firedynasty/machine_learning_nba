# %%
pwd
# Out:
# '/Users/stanleytan/Documents/ucb/ucb_/33-prev_projects/stack/4-Project/inclass/3rd_project_tied_4th/first_step/machine_learning_nba/1-webscraper'

# %%
import pandas as pd
box_score_prev = pd.read_csv('scraped_box_scores/03_01_box_score.csv')

# %%
box_score_prev
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0    2021-10-19       MIL          BRK       127       104      23
# 1    2021-10-19       LAL          GSW       114       121      -7
# 2    2021-10-20       CHO          IND       123       122       1
# 3    2021-10-20       DET          CHI        88        94      -6
# 4    2021-10-20       NYK          BOS       138       134       4
# ..          ...       ...          ...       ...       ...     ...
# 915  2022-03-01       BOS          ATL       107        98       9
# 916  2022-03-01       TOR          BRK       109       108       1
# 917  2022-03-01       HOU          LAC       100       113     -13
# 918  2022-03-01       MIN          GSW       129       114      15
# 919  2022-03-01       LAL          DAL       104       109      -5
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# 1                 0        0.474        0.474         0.357        21
# 2                 1        0.430        0.667         0.419        29
# 3                 0        0.400        0.769         0.214        17
# 4                 1        0.486        0.704         0.378        27
# ..              ...          ...          ...           ...       ...
# 915               1        0.470        0.947         0.314        27
# 916               1        0.456        0.870         0.304        27
# 917               0        0.396        0.647         0.333        21
# 918               1        0.528        0.826         0.400        27
# 919               0        0.451        0.800         0.412        22
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# 0          54        0.440        0.565         0.531        19        44
# 1          45        0.441        0.833         0.359        30        50
# 2          46        0.467        0.875         0.362        29        51
# 3          47        0.430        0.867         0.304        18        48
# 4          55        0.410        0.739         0.368        34        56
# ..        ...          ...          ...           ...       ...       ...
# 915        47        0.434        0.792         0.226        15        37
# 916        48        0.500        0.737         0.400        21        37
# 917        45        0.438        0.941         0.419        24        55
# 918        42        0.456        0.864         0.289        26        40
# 919        37        0.500        0.630         0.286        24        45
#
# [920 rows x 17 columns]

# %%
user_input = input("Using the previous box_scores to get the next set of boxscores: \
see NBA schedule in the binder")
# Out:
# Using the previous box_scores to get the next set of boxscores: see NBA schedule in the binder

# %%
# # adding winning_percentage which is unnecessary

# team_to_abbreviation = {
#     "ATLANTA HAWKS" : "ATL",
#     "ST. LOUIS HAWKS" : "SLH",
#     "MILWAUKEE HAWKS" : "MIL",
#     "TRI-CITIES BLACKHAWKS" : "TCB",
#     "BOSTON CELTICS" : "BOS",
#     "BROOKLYN NETS" : "BRK",
#     "NEW JERSEY NETS" : "NJN",
#     "CHICAGO BULLS" : "CHI",
#     "CHARLOTTE HORNETS": "CHO",
#     "CHARLOTTE BOBCATS" : "CHA",
#     "CLEVELAND CAVALIERS": "CLE",
#     "DALLAS MAVERICKS" : "DAL",
#     "DENVER NUGGETS" : "DEN",
#     "DETROIT PISTONS" : "DET",
#     "FORT WAYNE PISTONS" : "FWP",
#     "GOLDEN STATE WARRIORS" : "GSW",
#     "SAN FRANCISCO WARRIORS" : "SFW",
#     "PHILADELPHIA WARRIORS" : "PHI",
#     "HOUSTON ROCKETS" : "HOU",
#     "INDIANA PACERS" : "IND",
#     "LOS ANGELES CLIPPERS" : "LAC",
#     "SAN DIEGO CLIPPERS" : "SDC",
#     "BUFFALO BRAVES" : "BUF",
#     "LOS ANGELES LAKERS" : "LAL",
#     "MINNEAPOLIS LAKERS" : "MIN",
#     "MEMPHIS GRIZZLIES" : "MEM",
#     "VANCOUVER GRIZZLIES" : 'VAN',
#     "MIAMI HEAT" : "MIA",
#     "MILWAUKEE BUCKS" : "MIL",
#     "MINNESOTA TIMBERWOLVES" : "MIN",
#     "NEW ORLEANS PELICANS" : "NOP",
#     "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
#     "NEW ORLEANS HORNETS" : "NOH",
#     "NEW YORK KNICKS" : "NYK",
#     "OKLAHOMA CITY THUNDER" : "OKC",
#     "SEATTLE SUPERSONICS" : "SEA",
#     "ORLANDO MAGIC" : "ORL",
#     "PHILADELPHIA 76ERS" : "PHI",
#     "SYRACUSE NATIONALS" : "SYR",
#     "PHOENIX SUNS" : "PHO",
#     "PORTLAND TRAIL BLAZERS" : "POR",
#     "SACRAMENTO KINGS" : "SAC",
#     "KANSAS CITY KINGS" : "KCK",
#     "KANSAS CITY-OMAHA KINGS" : "KCK",
#     "CINCINNATI ROYALS" : "CIN",
#     "ROCHESTER ROYALS" : "ROR",
#     "SAN ANTONIO SPURS" : "SAS",
#     "TORONTO RAPTORS" : "TOR",
#     "UTAH JAZZ" : "UTA",
#     "NEW ORLEANS JAZZ" : "NOJ",
#     "WASHINGTON WIZARDS" : "WAS",
#     "WASHINGTON BULLETS" : "WAS",
#     "CAPITAL BULLETS" : "CAP",
#     "BALTIMORE BULLETS" : "BAL",
#     "CHICAGO ZEPHYRS" : "CHI",
#     "CHICAGO PACKERS" : "CHI",
#     "ANDERSON PACKERS" : "AND",
#     "CHICAGO STAGS" : "CHI",
#     "INDIANAPOLIS OLYMPIANS" : "IND",
#     "SHEBOYGAN RED SKINS" : "SRS",
#     "ST. LOUIS BOMBERS" : "SLB",
#     "WASHINGTON CAPITOLS" : "WAS",
#     "WATERLOO HAWKS" : "WAT"
# }
# test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
# list_ = test_[1].tolist()
# wins_ = dict.fromkeys(list_, 0)
# lost_ = dict.fromkeys(list_, 0)

# # adding winning percentage for another
# # df = pd.read_csv('old_data/abbr_games.csv')

# box_score_prev["DATE"]= pd.to_datetime(box_score_prev["DATE"])
# box_score_prev['PTS_home'] = pd.to_numeric(box_score_prev['PTS_home'])
# box_score_prev['PTS_away'] = pd.to_numeric(box_score_prev['PTS_away'])
# box_score_prev['MARGIN'] = pd.to_numeric(box_score_prev['MARGIN'])
# box_score_prev['HOME_TEAM_WINS'] = pd.to_numeric(box_score_prev['HOME_TEAM_WINS'])
# box_score_prev['FG_PCT_home'] = pd.to_numeric(box_score_prev['FG_PCT_home'])
# box_score_prev['FT_PCT_home'] = pd.to_numeric(box_score_prev['FT_PCT_home'])
# box_score_prev['FG3_PCT_home'] = pd.to_numeric(box_score_prev['FG3_PCT_home'])
# box_score_prev['AST_home'] = pd.to_numeric(box_score_prev['AST_home'])
# box_score_prev['REB_home'] = pd.to_numeric(box_score_prev['REB_home'])
# box_score_prev['FG_PCT_away'] = pd.to_numeric(box_score_prev['FG_PCT_away'])
# box_score_prev['FT_PCT_away'] = pd.to_numeric(box_score_prev['FT_PCT_away'])
# box_score_prev['FG3_PCT_away'] = pd.to_numeric(box_score_prev['FG3_PCT_away'])
# box_score_prev['AST_away'] = pd.to_numeric(box_score_prev['AST_away'])
# box_score_prev['REB_away'] = pd.to_numeric(box_score_prev['REB_away'])

# box_score_prev = box_score_prev.reset_index(drop=True)

# home_winning_percentage_list = []
# visitor_winning_percentage_list = []
# for ind in box_score_prev.index:
#     home_abbr = box_score_prev.loc[ind]['HOME_ABBR']
#     visitor_abbr = box_score_prev.loc[ind]['VISITOR_ABBR']
#     home_team_wins = box_score_prev.loc[ind]['HOME_TEAM_WINS']
#     if home_team_wins > 0:
#         wins_[home_abbr] += 1
#         lost_[visitor_abbr] += 1
#     else:
#         lost_[home_abbr] += 1
#         wins_[visitor_abbr] += 1
#     total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
#     total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
#     home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
#     visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
#     home_winning_percentage_list.append(home_winning_percentage)
#     visitor_winning_percentage_list.append(visitor_winning_percentage)
# box_score_prev['home_winning_percentage'] = home_winning_percentage_list
# box_score_prev['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
box_score_prev
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0    2021-10-19       MIL          BRK       127       104      23
# 1    2021-10-19       LAL          GSW       114       121      -7
# 2    2021-10-20       CHO          IND       123       122       1
# 3    2021-10-20       DET          CHI        88        94      -6
# 4    2021-10-20       NYK          BOS       138       134       4
# ..          ...       ...          ...       ...       ...     ...
# 885  2022-02-24       CHI          ATL       112       108       4
# 886  2022-02-24       MIN          MEM       119       114       5
# 887  2022-02-24       OKC          PHO       104       124     -20
# 888  2022-02-24       POR          GSW        95       132     -37
# 889  2022-02-24       SAC          DEN       110       128     -18
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# 1                 0        0.474        0.474         0.357        21
# 2                 1        0.430        0.667         0.419        29
# 3                 0        0.400        0.769         0.214        17
# 4                 1        0.486        0.704         0.378        27
# ..              ...          ...          ...           ...       ...
# 885               1        0.488        0.815         0.296        16
# 886               1        0.462        0.680         0.381        26
# 887               0        0.473        0.909         0.194        22
# 888               0        0.397        0.828         0.257        16
# 889               0        0.500        0.833         0.310        25
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# 0          54        0.440        0.565         0.531        19        44
# 1          45        0.441        0.833         0.359        30        50
# 2          46        0.467        0.875         0.362        29        51
# 3          47        0.430        0.867         0.304        18        48
# 4          55        0.410        0.739         0.368        34        56
# ..        ...          ...          ...           ...       ...       ...
# 885        43        0.423        0.667         0.286        20        45
# 886        42        0.388        0.725         0.290        25        59
# 887        42        0.535        0.905         0.382        32        43
# 888        31        0.511        0.844         0.366        36        46
# 889        34        0.558        0.850         0.429        30        39
#
# [890 rows x 17 columns]

# %%
box_score_prev["DATE"]= pd.to_datetime(box_score_prev["DATE"])
box_score_prev['PTS_home'] = pd.to_numeric(box_score_prev['PTS_home'])
box_score_prev['PTS_away'] = pd.to_numeric(box_score_prev['PTS_away'])
box_score_prev['MARGIN'] = pd.to_numeric(box_score_prev['MARGIN'])
box_score_prev['HOME_TEAM_WINS'] = pd.to_numeric(box_score_prev['HOME_TEAM_WINS'])
box_score_prev['FG_PCT_home'] = pd.to_numeric(box_score_prev['FG_PCT_home'])
box_score_prev['FT_PCT_home'] = pd.to_numeric(box_score_prev['FT_PCT_home'])
box_score_prev['FG3_PCT_home'] = pd.to_numeric(box_score_prev['FG3_PCT_home'])
box_score_prev['AST_home'] = pd.to_numeric(box_score_prev['AST_home'])
box_score_prev['REB_home'] = pd.to_numeric(box_score_prev['REB_home'])
box_score_prev['FG_PCT_away'] = pd.to_numeric(box_score_prev['FG_PCT_away'])
box_score_prev['FT_PCT_away'] = pd.to_numeric(box_score_prev['FT_PCT_away'])
box_score_prev['FG3_PCT_away'] = pd.to_numeric(box_score_prev['FG3_PCT_away'])
box_score_prev['AST_away'] = pd.to_numeric(box_score_prev['AST_away'])
box_score_prev['REB_away'] = pd.to_numeric(box_score_prev['REB_away'])

# %%
box_score_prev
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 902 2022-02-27       CHO          DET       126       127      -1
# 903 2022-02-27       HOU          LAC        98        99      -1
# 904 2022-02-27       GSW          DAL       101       107      -6
# 905 2022-02-27       POR          DEN        92       124     -32
# 906 2022-02-27       LAL          NOP        95       123     -28
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# 1                 0        0.474        0.474         0.357        21
# 2                 1        0.430        0.667         0.419        29
# 3                 0        0.400        0.769         0.214        17
# 4                 1        0.486        0.704         0.378        27
# ..              ...          ...          ...           ...       ...
# 902               0        0.506        0.676         0.419        25
# 903               0        0.380        0.611         0.405        26
# 904               0        0.429        0.600         0.282        27
# 905               0        0.374        0.692         0.167        22
# 906               0        0.417        0.900         0.206        15
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# 0          54        0.440        0.565         0.531        19        44
# 1          45        0.441        0.833         0.359        30        50
# 2          46        0.467        0.875         0.362        29        51
# 3          47        0.430        0.867         0.304        18        48
# 4          55        0.410        0.739         0.368        34        56
# ..        ...          ...          ...           ...       ...       ...
# 902        46        0.455        0.722         0.350        30        54
# 903        37        0.442        0.714         0.324        18        59
# 904        44        0.500        0.800         0.382        16        45
# 905        42        0.512        0.774         0.324        28        55
# 906        38        0.511        0.640         0.433        29        51
#
# [907 rows x 17 columns]

# %%
schedule_df = pd.read_csv('schedule_2022.csv')

# %%
schedule_df
# Out:
#             DATE                VISITOR  VISITOR_PTS                 HOME  \
# 0     2021-10-19          Brooklyn Nets        104.0      Milwaukee Bucks
# 1     2021-10-19  Golden State Warriors        121.0   Los Angeles Lakers
# 2     2021-10-20         Indiana Pacers        122.0    Charlotte Hornets
# 3     2021-10-20          Chicago Bulls         94.0      Detroit Pistons
# 4     2021-10-20         Boston Celtics        134.0      New York Knicks
# ...          ...                    ...          ...                  ...
# 1225  2022-04-10     Los Angeles Lakers          0.0       Denver Nuggets
# 1226  2022-04-10      San Antonio Spurs          0.0     Dallas Mavericks
# 1227  2022-04-10        Milwaukee Bucks          0.0  Cleveland Cavaliers
# 1228  2022-04-10     Washington Wizards          0.0    Charlotte Hornets
# 1229  2022-04-10         Indiana Pacers          0.0        Brooklyn Nets
#
#       HOME_PTS
# 0        127.0
# 1        114.0
# 2        123.0
# 3         88.0
# 4        138.0
# ...        ...
# 1225       0.0
# 1226       0.0
# 1227       0.0
# 1228       0.0
# 1229       0.0
#
# [1230 rows x 5 columns]

# %%
user_input = input('required to get the dates to add to the box_scores')
# Out:
# required to get the dates to add to the box_scores

# %%
schedule_df = schedule_df.loc[schedule_df['DATE'] == '2022-03-02']

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}

schedule_df['HOME_ABBR'] = 0
schedule_df['VISITOR_ABBR'] = 0

for ind in schedule_df.index: 
    schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
    schedule_df['HOME'][ind] =schedule_df['HOME'][ind].upper()
    schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df['HOME'][ind]]
    schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df['VISITOR'][ind]]
# Out:
# <ipython-input-10-378933caafdb>:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
# <ipython-input-10-378933caafdb>:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['HOME'][ind] =schedule_df['HOME'][ind].upper()
# <ipython-input-10-378933caafdb>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df['HOME'][ind]]
# /Users/stanleytan/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-10-378933caafdb>:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df['VISITOR'][ind]]

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                    HOME  \
# 921  2022-03-01        DETROIT PISTONS          0.0      WASHINGTON WIZARDS
# 922  2022-03-01          ATLANTA HAWKS          0.0          BOSTON CELTICS
# 923  2022-03-01          BROOKLYN NETS          0.0         TORONTO RAPTORS
# 924  2022-03-01   LOS ANGELES CLIPPERS          0.0         HOUSTON ROCKETS
# 925  2022-03-01  GOLDEN STATE WARRIORS          0.0  MINNESOTA TIMBERWOLVES
# 926  2022-03-01       DALLAS MAVERICKS          0.0      LOS ANGELES LAKERS
#
#      HOME_PTS HOME_ABBR VISITOR_ABBR
# 921       0.0       WAS          DET
# 922       0.0       BOS          ATL
# 923       0.0       TOR          BRK
# 924       0.0       HOU          LAC
# 925       0.0       MIN          GSW
# 926       0.0       LAL          DAL

# %%
box_score_columns = box_score_columns = [ 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']
box_score_df = pd.DataFrame(columns=box_score_columns)


from basketball_reference_scraper.box_scores import get_box_scores

import time
for ind in schedule_df.index:
    date_1 = schedule_df.loc[ind]['DATE']
    home_1 = schedule_df.loc[ind]['HOME_ABBR']
    visitor_1 = schedule_df.loc[ind]['VISITOR_ABBR']
    dict_ = get_box_scores(date_1, visitor_1, home_1, period='GAME', stat_type='BASIC')
    home_df = dict_[home_1]
    visitor_df = dict_[visitor_1]
    #id_ = schedule_df.loc[ind]['ID']
    #unsure why the ID is required
    home_pts = home_df.loc[home_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    visitor_pts = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    margin_ = int(home_pts) - int(visitor_pts)
    if margin_ > 0:
        home_team_wins = 1
    else:
        home_team_wins = 0
    home_fg_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    home_ft_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    home_fg3_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    home_ast = home_df.loc[home_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    home_reb = home_df.loc[home_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    visitor_fg_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    visitor_ft_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    visitor_fg3_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    visitor_ast = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    visitor_reb = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    empty_ = []
    #empty_.append(id_)
#ID unsure why that is required
    empty_.append(date_1)
#DATE
    empty_.append(home_1)
#home abbr
    empty_.append(visitor_1)
#visito abbr
    empty_.append(home_pts)
#home pints
    empty_.append(visitor_pts)
#away points
    empty_.append(margin_)
#margin
    empty_.append(home_team_wins)
#HOME_TEAM_WINS
    empty_.append(home_fg_pct)
#FG_PCT
    empty_.append(home_ft_pct)
#FT_PCT
    empty_.append(home_fg3_pct)
#FG3_PCT
    empty_.append(home_ast)
#AST
    empty_.append(home_reb)
#REBOUNDS
    empty_.append(visitor_fg_pct)
#FG_PCT
    empty_.append(visitor_ft_pct)
#FT_PCT
    empty_.append(visitor_fg3_pct)
#FG3
    empty_.append(visitor_ast)
#AST
    empty_.append(visitor_reb)
#REBOUNDS
    length_of_df = len(box_score_df)
    box_score_df.loc[length_of_df] = empty_
    print(empty_)
# Out:
# ['2022-03-02', 'CLE', 'CHO', '98', '119', -21, 0, '.468', '.667', '.323', '21', '37', '.506', '.727', '.447', '32', '45']
# ['2022-03-02', 'ORL', 'IND', '114', '122', -8, 0, '.454', '.800', '.313', '22', '52', '.436', '.800', '.324', '23', '54']
# ['2022-03-02', 'PHI', 'NYK', '123', '108', 15, 1, '.520', '.848', '.472', '24', '43', '.429', '.688', '.286', '20', '40']
# ['2022-03-02', 'HOU', 'UTA', '127', '132', -5, 0, '.500', '.667', '.412', '27', '35', '.543', '.708', '.357', '32', '49']
# ['2022-03-02', 'MIL', 'MIA', '120', '119', 1, 1, '.451', '.889', '.389', '22', '52', '.454', '.833', '.477', '28', '48']
# ['2022-03-02', 'NOP', 'SAC', '125', '95', 30, 1, '.591', '.833', '.379', '30', '50', '.393', '.680', '.229', '20', '38']
# ['2022-03-02', 'DEN', 'OKC', '107', '119', -12, 0, '.444', '.882', '.261', '25', '47', '.506', '.714', '.552', '24', '50']
# ['2022-03-02', 'PHO', 'POR', '120', '90', 30, 1, '.500', '.839', '.389', '32', '46', '.385', '.760', '.355', '22', '35']

# %%
box_score_combined = pd.concat([box_score_prev, box_score_df])

# %%
box_score_combined["DATE"]= pd.to_datetime(box_score_combined["DATE"])

# %%
box_score_combined.to_csv('scraped_box_scores/03_02_box_score.csv', index=False)

# %%
box_score_combined
# Out:
#          DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN HOME_TEAM_WINS  \
# 0  2021-10-19       MIL          BRK      127      104     23              1
# 1  2021-10-19       LAL          GSW      114      121     -7              0
# 2  2021-10-20       CHO          IND      123      122      1              1
# 3  2021-10-20       DET          CHI       88       94     -6              0
# 4  2021-10-20       NYK          BOS      138      134      4              1
# ..        ...       ...          ...      ...      ...    ...            ...
# 3  2022-03-02       HOU          UTA      127      132     -5              0
# 4  2022-03-02       MIL          MIA      120      119      1              1
# 5  2022-03-02       NOP          SAC      125       95     30              1
# 6  2022-03-02       DEN          OKC      107      119    -12              0
# 7  2022-03-02       PHO          POR      120       90     30              1
#
#    FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home FG_PCT_away  \
# 0        0.457       0.778        0.378       25       54        0.44
# 1        0.474       0.474        0.357       21       45       0.441
# 2         0.43       0.667        0.419       29       46       0.467
# 3          0.4       0.769        0.214       17       47        0.43
# 4        0.486       0.704        0.378       27       55        0.41
# ..         ...         ...          ...      ...      ...         ...
# 3         .500        .667         .412       27       35        .543
# 4         .451        .889         .389       22       52        .454
# 5         .591        .833         .379       30       50        .393
# 6         .444        .882         .261       25       47        .506
# 7         .500        .839         .389       32       46        .385
#
#    FT_PCT_away FG3_PCT_away AST_away REB_away
# 0        0.565        0.531       19       44
# 1        0.833        0.359       30       50
# 2        0.875        0.362       29       51
# 3        0.867        0.304       18       48
# 4        0.739        0.368       34       56
# ..         ...          ...      ...      ...
# 3         .708         .357       32       49
# 4         .833         .477       28       48
# 5         .680         .229       20       38
# 6         .714         .552       24       50
# 7         .760         .355       22       35
#
# [928 rows x 17 columns]

# %%
pwd
# Out:
# '/Users/stanleytan/Documents/ucb/ucb_/33-prev_projects/stack/4-Project/inclass/3rd_project_tied_4th/first_step/machine_learning_nba/1-webscraper'

# %%
box_score_combined
# Out:
#          DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN HOME_TEAM_WINS  \
# 0  2021-10-19       MIL          BRK      127      104     23              1
# 1  2021-10-19       LAL          GSW      114      121     -7              0
# 2  2021-10-20       CHO          IND      123      122      1              1
# 3  2021-10-20       DET          CHI       88       94     -6              0
# 4  2021-10-20       NYK          BOS      138      134      4              1
# ..        ...       ...          ...      ...      ...    ...            ...
# 1  2022-03-01       BOS          ATL      107       98      9              1
# 2  2022-03-01       TOR          BRK      109      108      1              1
# 3  2022-03-01       HOU          LAC      100      113    -13              0
# 4  2022-03-01       MIN          GSW      129      114     15              1
# 5  2022-03-01       LAL          DAL      104      109     -5              0
#
#    FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home FG_PCT_away  \
# 0        0.457       0.778        0.378       25       54        0.44
# 1        0.474       0.474        0.357       21       45       0.441
# 2         0.43       0.667        0.419       29       46       0.467
# 3          0.4       0.769        0.214       17       47        0.43
# 4        0.486       0.704        0.378       27       55        0.41
# ..         ...         ...          ...      ...      ...         ...
# 1         .470        .947         .314       27       47        .434
# 2         .456        .870         .304       27       48        .500
# 3         .396        .647         .333       21       45        .438
# 4         .528        .826         .400       27       42        .456
# 5         .451        .800         .412       22       37        .500
#
#    FT_PCT_away FG3_PCT_away AST_away REB_away
# 0        0.565        0.531       19       44
# 1        0.833        0.359       30       50
# 2        0.875        0.362       29       51
# 3        0.867        0.304       18       48
# 4        0.739        0.368       34       56
# ..         ...          ...      ...      ...
# 1         .792         .226       15       37
# 2         .737         .400       21       37
# 3         .941         .419       24       55
# 4         .864         .289       26       40
# 5         .630         .286       24       45
#
# [920 rows x 17 columns]

# %%
box_score_combined.loc[box_score_combined['HOME_ABBR'] == 'DET'].tail(10)
# Out:
#           DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN HOME_TEAM_WINS  \
# 623 2022-01-14       DET          TOR      103       87     16              1
# 641 2022-01-16       DET          PHO      108      135    -27              0
# 704 2022-01-25       DET          DEN      105      110     -5              0
# 745 2022-01-30       DET          CLE      115      105     10              1
# 758 2022-02-01       DET          NOP      101      111    -10              0
# 774 2022-02-03       DET          MIN      117      128    -11              0
# 781 2022-02-04       DET          BOS       93      102     -9              0
# 824 2022-02-10       DET          MEM      107      132    -25              0
# 831 2022-02-11       DET          CHO      119      141    -22              0
# 883 2022-02-24       DET          CLE      106      103      3              1
#
#     FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home FG_PCT_away  \
# 623       0.469       0.826        0.296       22       43       0.322
# 641       0.463       0.676         0.36       25       32       0.586
# 704       0.423       0.786        0.333       25       36       0.429
# 745       0.462        0.84        0.385       26       48       0.463
# 758       0.488       0.786         0.25       21       35       0.438
# 774        0.44       0.786        0.326       27       45       0.506
# 781       0.327        0.75        0.385       18       56       0.451
# 824       0.436       0.857          0.2       27       40       0.478
# 831       0.471       0.611        0.343       32       45       0.557
# 883       0.407       0.893        0.324       23       49       0.442
#
#     FT_PCT_away FG3_PCT_away AST_away REB_away
# 623       0.769        0.289       18       46
# 641       0.733        0.407       30       51
# 704       0.871        0.344       25       56
# 745        0.64        0.382       25       41
# 758       0.893        0.286       24       46
# 774       0.893        0.441       29       42
# 781        0.76        0.321       23       55
# 824        0.69          0.5       32       60
# 831       0.652        0.429       36       51
# 883       0.676        0.343       20       42

# %%
 box_score_combined.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home',
#        'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away'],
#       dtype='object')

# %%
# winning percentage

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0)

# adding winning percentage for another
# df = pd.read_csv('old_data/abbr_games.csv')

box_score_combined["DATE"]= pd.to_datetime(box_score_combined["DATE"])
box_score_combined['PTS_home'] = pd.to_numeric(box_score_combined['PTS_home'])
box_score_combined['PTS_away'] = pd.to_numeric(box_score_combined['PTS_away'])
box_score_combined['MARGIN'] = pd.to_numeric(box_score_combined['MARGIN'])
box_score_combined['HOME_TEAM_WINS'] = pd.to_numeric(box_score_combined['HOME_TEAM_WINS'])
box_score_combined['FG_PCT_home'] = pd.to_numeric(box_score_combined['FG_PCT_home'])
box_score_combined['FT_PCT_home'] = pd.to_numeric(box_score_combined['FT_PCT_home'])
box_score_combined['FG3_PCT_home'] = pd.to_numeric(box_score_combined['FG3_PCT_home'])
box_score_combined['AST_home'] = pd.to_numeric(box_score_combined['AST_home'])
box_score_combined['REB_home'] = pd.to_numeric(box_score_combined['REB_home'])
box_score_combined['FG_PCT_away'] = pd.to_numeric(box_score_combined['FG_PCT_away'])
box_score_combined['FT_PCT_away'] = pd.to_numeric(box_score_combined['FT_PCT_away'])
box_score_combined['FG3_PCT_away'] = pd.to_numeric(box_score_combined['FG3_PCT_away'])
box_score_combined['AST_away'] = pd.to_numeric(box_score_combined['AST_away'])
box_score_combined['REB_away'] = pd.to_numeric(box_score_combined['REB_away'])

box_score_combined = box_score_combined.reset_index(drop=True)

home_winning_percentage_list = []
visitor_winning_percentage_list = []
for ind in box_score_combined.index:
    home_abbr = box_score_combined.loc[ind]['HOME_ABBR']
    visitor_abbr = box_score_combined.loc[ind]['VISITOR_ABBR']
    home_team_wins = box_score_combined.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)
box_score_combined['home_winning_percentage'] = home_winning_percentage_list
box_score_combined['visitor_winning_percentage'] = visitor_winning_percentage_list

# adding the winning_percentages to the boxscore

# %%
box_score_combined
# Out:
#           DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 0   2021-10-19       MIL          BRK       127       104      23
# 1   2021-10-19       LAL          GSW       114       121      -7
# 2   2021-10-20       CHO          IND       123       122       1
# 3   2021-10-20       DET          CHI        88        94      -6
# 4   2021-10-20       NYK          BOS       138       134       4
# ..         ...       ...          ...       ...       ...     ...
# 923 2022-03-02       HOU          UTA       127       132      -5
# 924 2022-03-02       MIL          MIA       120       119       1
# 925 2022-03-02       NOP          SAC       125        95      30
# 926 2022-03-02       DEN          OKC       107       119     -12
# 927 2022-03-02       PHO          POR       120        90      30
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 0                 1        0.457        0.778         0.378        25
# 1                 0        0.474        0.474         0.357        21
# 2                 1        0.430        0.667         0.419        29
# 3                 0        0.400        0.769         0.214        17
# 4                 1        0.486        0.704         0.378        27
# ..              ...          ...          ...           ...       ...
# 923               0        0.500        0.667         0.412        27
# 924               1        0.451        0.889         0.389        22
# 925               1        0.591        0.833         0.379        30
# 926               0        0.444        0.882         0.261        25
# 927               1        0.500        0.839         0.389        32
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 0          54        0.440        0.565         0.531        19        44
# 1          45        0.441        0.833         0.359        30        50
# 2          46        0.467        0.875         0.362        29        51
# 3          47        0.430        0.867         0.304        18        48
# 4          55        0.410        0.739         0.368        34        56
# ..        ...          ...          ...           ...       ...       ...
# 923        35        0.543        0.708         0.357        32        49
# 924        52        0.454        0.833         0.477        28        48
# 925        50        0.393        0.680         0.229        20        38
# 926        47        0.506        0.714         0.552        24        50
# 927        46        0.385        0.760         0.355        22        35
#
#      home_winning_percentage  visitor_winning_percentage
# 0                   1.000000                    0.000000
# 1                   0.000000                    1.000000
# 2                   1.000000                    0.000000
# 3                   0.000000                    1.000000
# 4                   1.000000                    0.000000
# ..                       ...                         ...
# 923                 0.241935                    0.639344
# 924                 0.612903                    0.645161
# 925                 0.419355                    0.365079
# 926                 0.573770                    0.322581
# 927                 0.806452                    0.403226
#
# [928 rows x 19 columns]

# %%
box_score_combined.to_csv('../3-further_analysis/03_03box_score_combined.csv', index=False)
