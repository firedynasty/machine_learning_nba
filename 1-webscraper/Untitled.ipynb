# %%
import pandas as pd
schedule_df_dropped_dup = pd.read_csv('schedule_df_dropped_duplicates.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
schedule_df_dropped_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
# DATE           120 non-null object
# VISITOR        120 non-null object
# VISITOR_PTS    120 non-null float64
# HOME           120 non-null object
# HOME_PTS       120 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 4.8+ KB

# %%
schedule_df_dropped_dup = schedule_df_dropped_dup.tail(93)

# %%
schedule_df_dropped_dup.to_csv('adjusted_schedule_df.csv', index=False)

# %%
date_list = schedule_df_dropped_dup['DATE'].tolist()

# %%
schedule_df_dropped_dup.head(100)
# Out:
#           DATE                 VISITOR  VISITOR_PTS                  HOME  \
# 0   2021-10-19           Brooklyn Nets        104.0       Milwaukee Bucks
# 1   2021-10-20          Indiana Pacers        122.0     Charlotte Hornets
# 2   2021-10-21        Dallas Mavericks         87.0         Atlanta Hawks
# 3   2021-10-22         New York Knicks        121.0         Orlando Magic
# 4   2021-10-23           Atlanta Hawks         95.0   Cleveland Cavaliers
# 5   2021-10-24       Charlotte Hornets        111.0         Brooklyn Nets
# 6   2021-10-25          Boston Celtics        140.0     Charlotte Hornets
# 7   2021-10-26      Philadelphia 76ers         99.0       New York Knicks
# 8   2021-10-27       Charlotte Hornets        120.0         Orlando Magic
# 9   2021-10-28           Atlanta Hawks        111.0    Washington Wizards
# 10  2021-10-29           Orlando Magic        109.0       Toronto Raptors
# 11  2021-10-30          Boston Celtics        112.0    Washington Wizards
# ...

# %%
import pandas as pd
box_score_df = pd.read_csv('scraped_box_scores/box_score_df_feb_21_up_until.csv')

# %%
box_score_df = box_score_df.tail(683)

# %%
box_score_df.head()
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 200  2021-11-15       WAS          NOP       105       100       5
# 201  2021-11-15       ATL          ORL       129       111      18
# 202  2021-11-15       NYK          IND        92        84       8
# 203  2021-11-15       DAL          DEN       111       101      10
# 204  2021-11-15       MEM          HOU       136       102      34
#
#      HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  \
# 200               1        0.464        0.680         0.357        23
# 201               1        0.553        0.656         0.467        32
# 202               1        0.430        0.700         0.324        22
# 203               1        0.500        0.700         0.389        30
# 204               1        0.542        0.800         0.390        33
#
#      REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# ...
