# %%
import pandas as pd

# %% [markdown]
# ## <font color='green'>Loading CSVs </font>

# %%
df = pd.read_csv('old_data/abbr_games_dup.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(16, 6))

mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))


heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7ff25459533> in <module>
#       4 plt.figure(figsize=(16, 6))
#       5
# ----> 6 mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
#       7
#       8
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# TUTORIAL
# ```python
# df['MARGIN'] = 0
# for ind in df.index:
#     df['MARGIN'][ind] = df['PTS_home'][ind] - df['PTS_away'][ind]
# ```

# %%
df_2019 = df.loc[df['SEASON'] == 2019]
df_2018 = df.loc[df['SEASON'] == 2018]
df_2017 = df.loc[df['SEASON'] == 2017]
df_2016 = df.loc[df['SEASON'] == 2016]
df_2015 = df.loc[df['SEASON'] == 2015]
df_2014 = df.loc[df['SEASON'] == 2014]

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2014 = df_2014.sort_values(by='GAME_DATE_EST')
for ind in df_2014.index:
    home_abbr = df_2014.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2014.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2014.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2014['home_winning_percentage'] = home_winning_percentage_list
df_2014['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2015 = df_2015.sort_values(by='GAME_DATE_EST')
for ind in df_2015.index:
    home_abbr = df_2015.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2015.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2015.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2015['home_winning_percentage'] = home_winning_percentage_list
df_2015['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2016 = df_2016.sort_values(by='GAME_DATE_EST')
for ind in df_2016.index:
    home_abbr = df_2016.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2016.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2016.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2016['home_winning_percentage'] = home_winning_percentage_list
df_2016['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2017 = df_2017.sort_values(by='GAME_DATE_EST')
for ind in df_2017.index:
    home_abbr = df_2017.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2017.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2017.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2017['home_winning_percentage'] = home_winning_percentage_list
df_2017['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2018 = df_2018.sort_values(by='GAME_DATE_EST')
for ind in df_2018.index:
    home_abbr = df_2018.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2018.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2018.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2018['home_winning_percentage'] = home_winning_percentage_list
df_2018['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BKN",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHX",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
test_ = pd.DataFrame.from_dict(team_to_abbreviation.items())
list_ = test_[1].tolist()
wins_ = dict.fromkeys(list_, 0)
lost_ = dict.fromkeys(list_, 0) 

home_winning_percentage_list = []
visitor_winning_percentage_list = []

df_2019 = df_2019.sort_values(by='GAME_DATE_EST')
for ind in df_2019.index:
    home_abbr = df_2019.loc[ind]['HOME_ABBR']
    visitor_abbr = df_2019.loc[ind]['VISITOR_ABBR']
    home_team_wins = df_2019.loc[ind]['HOME_TEAM_WINS']
    if home_team_wins > 0:
        wins_[home_abbr] += 1
        lost_[visitor_abbr] += 1
    else:
        lost_[home_abbr] += 1
        wins_[visitor_abbr] += 1
    total_games_home_abbr = wins_[home_abbr] + lost_[home_abbr]
    total_games_visitor_abbr = wins_[visitor_abbr] + lost_[visitor_abbr]
    home_winning_percentage = wins_[home_abbr] / total_games_home_abbr
    visitor_winning_percentage = wins_[visitor_abbr] / total_games_visitor_abbr
    home_winning_percentage_list.append(home_winning_percentage)
    visitor_winning_percentage_list.append(visitor_winning_percentage)

df_2019['home_winning_percentage'] = home_winning_percentage_list
df_2019['visitor_winning_percentage'] = visitor_winning_percentage_list

# %%
df_2019 = df_2019.tail(1000)

# %%
df_2018 = df_2018.tail(1178)

# %%
df_2017 = df_2017.tail(1178)

# %%
df_2016 = df_2016.tail(1200)

# %%
df_2015 = df_2015.tail(1200)

# %%
df_2014 = df_2015.tail(1200)

# %%
# make sure that the winning percentage is done in order
merged_df = pd.concat([df_2019, df_2018, df_2017, df_2016, df_2015, df_2014])

# %%
merged_df.to_csv('training_data/nba_seasons.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('training_data/nba_seasons.csv')

# %%
df
# Out:
#      GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0       2019-11-16  21900180            Final    1610612742       1610612761
# 1       2019-11-16  21900179            Final    1610612750       1610612745
# 2       2019-11-16  21900178            Final    1610612748       1610612740
# 3       2019-11-16  21900177            Final    1610612752       1610612766
# 4       2019-11-16  21900176            Final    1610612754       1610612749
# ...            ...       ...              ...           ...              ...
# 6951    2016-06-08  41500403            Final    1610612739       1610612744
# 6952    2016-06-10  41500404            Final    1610612739       1610612744
# 6953    2016-06-13  41500405            Final    1610612744       1610612739
# 6954    2016-06-16  41500406            Final    1610612739       1610612744
# 6955    2016-06-19  41500407            Final    1610612744       1610612739
#
# ...

# %%
training_columns = ['PTS_home', 'FG_PCT_home', 'FG3_PCT_home', 'PTS_away', 'FG_PCT_away', 'FG3_PCT_away', 'MARGIN', 'home_winning_percentage', 'visitor_winning_percentage']

# %% [markdown]
# ### Grabbing training data

# %%
df2 = df[['PTS_home', 'FG_PCT_home', 'FG3_PCT_home', 'PTS_away', 'FG_PCT_away', 'FG3_PCT_away', 'MARGIN', 'home_winning_percentage', 'visitor_winning_percentage']]

# %%
df2
# Out:
#       PTS_home  FG_PCT_home  FG3_PCT_home  PTS_away  FG_PCT_away  \
# 0        110.0        0.420         0.231     102.0        0.416
# 1        105.0        0.452         0.316     125.0        0.457
# 2        109.0        0.543         0.375      94.0        0.451
# 3        102.0        0.453         0.300     103.0        0.414
# 4         83.0        0.320         0.353     102.0        0.448
# ...        ...          ...           ...       ...          ...
# 6951     120.0        0.527         0.480      90.0        0.421
# 6952      97.0        0.469         0.240     108.0        0.407
# 6953      97.0        0.364         0.326     112.0        0.530
# 6954     115.0        0.519         0.370     101.0        0.402
# 6955      89.0        0.386         0.366      93.0        0.402
#
#       FG3_PCT_away  MARGIN  home_winning_percentage  \
# 0            0.415     8.0                 0.529412
# 1            0.388   -20.0                 0.470588
# ...

# %%
import scipy.stats as st

# %%
#required to load dependencies
X = df2.drop('MARGIN', axis=1)
y = df2['MARGIN'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
X_scaled = X_scaler.transform(X)

# %%
#X_scaled[0]

# %%
#len(X_train_scaled)

# %%
from sklearn.linear_model import LinearRegression
classifier = LinearRegression()

# %%
classifier.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
classifier.score(X_train_scaled, y_train_scaled)
# Out:
# 1.0

# %%
classifier.score(X_test_scaled, y_test_scaled)
# Out:
# 1.0

# %%
predictions = classifier.predict(X_test_scaled)

# %%
predicted_df = pd.DataFrame({"Prediction": predictions.flatten(), "Actual": y_test.flatten()})[['Prediction', 'Actual']].reset_index(drop=True)

# %%
predicted_df
# Out:
#       Prediction  Actual
# 0       0.590410    11.0
# 1       0.446534     9.0
# 2       0.590410    11.0
# 3      -1.495792   -18.0
# 4      -1.351916   -16.0
# ...          ...     ...
# 1734   -0.416722    -3.0
# 1735   -1.208040   -14.0
# 1736   -0.344784    -2.0
# 1737   -0.632536    -6.0
# 1738    0.230720     6.0
#
# [1739 rows x 2 columns]

# %%
predicted_df_1 = predicted_df.copy()

# %%
predicted_df_1 = predicted_df_1.round({"Prediction":1})

# %%
predicted_df_1.head()
# Out:
#    Prediction  Actual
# 0         0.6    11.0
# 1         0.4     9.0
# 2         0.6    11.0
# 3        -1.5   -18.0
# 4        -1.4   -16.0

# %%
values_ = predicted_df_1.groupby("Prediction").mean().reset_index()

# %%
values_.to_csv('prediction_values.csv', index=False)

# %%
    mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()

# %%
visitor_df = visitor_df.round({"diff_%":1})

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# It is python as type
#
# ```python
# df.Weight = df.Weight.astype('int64')
# ```

# %%
```python
>>> from sklearn.metrics import accuracy_score
>>> y_pred = [0, 2, 1, 3]
>>> y_true = [0, 1, 2, 3]
>>> accuracy_score(y_true, y_pred)
0.5
# Out:
#   File "<ipython-input-36-f66dd5415b5e>", line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %%
from sklearn.metrics import accuracy_score
predicted_values = predicted_df['Prediction'].tolist()
actual_values = predicted_df['Actual'].tolist()
accuracy_score(predicted_values, actual_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d05c1fc44bd5> in <module>
#       2 predicted_values = predicted_df['Prediction'].tolist()
#       3 actual_values = predicted_df['Actual'].tolist()
# ----> 4 accuracy_score(predicted_values, actual_values)
#
# ~/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# ...

# %%
# Out:
# 0.975

# %%
import pandas as pd

# %% [markdown]
# Running a prediction, copied and pasted from Excel.
#
# ```python
# df = pd.read_csv('example1.csv')
# df['margin'] = 0
# df['margin'] = df['PTS_home'] - df['PTS_away']
# X_train_scaled_2 = X_scaler.transform(df)
# classifier.predict(X_train_scaled_2)
# ```
#
# Training had margin, so need to add that in

# %% [markdown]
# LOADING IN CSV
# ```python
# import pandas as pd
# imported_predicted_df = pd.read_csv('predict_feb3_playoffs.csv')
# imported_predicted_df = imported_predicted_df['PTS_home', 'FG_PCT_home', 'FG3_PCT_home', 'PTS_away', 'FG_PCT_away', 'FG3_PCT_away', 'MARGIN']
# X_train_scaled_2 = X_scaler.transform(imported_predicted_df)
# classifier.predict(X_train_scaled_2)
# ```

# %%
imported_predicted_df = pd.read_csv('for_ml_data/02_28_for_ml.csv')

# %%
imported_predicted_df2 = imported_predicted_df[['PTS_home', 'FG_PCT_home', 'FG3_PCT_home', 'PTS_away', 'FG_PCT_away', 'FG3_PCT_away', 'home_winning_percentage', 'visitor_winning_percentage']]

# %%
X_train_scaled_2 = X_scaler.transform(imported_predicted_df2)
predictions2 = classifier.predict(X_train_scaled_2)

# %%
predictions2 = predictions2.flatten()
predictions2 = predictions2.tolist()

# %%
imported_predicted_df['predicted'] = predictions2

# %%
imported_predicted_df.to_csv('02_28_predicted.csv', index=False)

# %%
imported_predicted_df
# Out:
#          DATE HOME_ABBR VISITOR_ABBR    PTS_home    PTS_away     MARGIN  \
# 0  2022-02-28       CLE          MIN  113.950000  113.400000   0.550000
# 1  2022-02-28       ORL          IND  104.900000  101.000000   3.900000
# 2  2022-02-28       BRK          TOR  102.032143  111.962500  -9.930357
# 3  2022-02-28       MIA          CHI  105.370833   99.691667   5.679167
# 4  2022-02-28       MEM          SAS  125.212500  113.283333  11.929167
# 5  2022-02-28       MIL          CHO  116.341667  117.214583  -0.872917
# 6  2022-02-28       OKC          SAC  101.142857   91.685714   9.457143
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  FG_PCT_away  FT_PCT_away  \
# 0     0.509962     0.700838      0.399162     0.453600     0.776400
# 1     0.461250     0.678900      0.319850     0.425000     0.679000
# 2     0.444093     0.778296      0.278957     0.467034     0.734709
# 3     0.454554     0.797779      0.363433     0.435792     0.773658
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
imported_predicted_df.to_csv('predicted_values.csv', index=False)

# %%
imported_predicted_df.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'MARGIN', 'PTS_home', 'PTS_away',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS', 'predicted'],
#       dtype='object')

# %%
imported_predicted_df['converted_predicted'] = 0

# %%
for ind in imported_predicted_df.index:
    if imported_predicted_df['predicted'][ind] > 0.1:
        imported_predicted_df['converted_predicted'][ind] = 1
    else:
        imported_predicted_df['converted_predicted'][ind] = 0
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imported_predicted_df['margin_over'] = 0
imported_predicted_df['fg_over'] = 0

# %%
imported_predicted_df.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'MARGIN', 'PTS_home', 'PTS_away',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS', 'predicted', 'converted_predicted', 'margin_over',
#        'fg_over'],
#       dtype='object')

# %%
for ind in imported_predicted_df.index:
    if imported_predicted_df['MARGIN'][ind] > 0:
        imported_predicted_df['margin_over'][ind] = 1
    else:
        imported_predicted_df['margin_over'][ind] = 0
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for ind in imported_predicted_df.index:
    if imported_predicted_df['FG_PCT_home'][ind] > imported_predicted_df['FG_PCT_away'][ind]:
        imported_predicted_df['fg_over'][ind] = 1
    else:
        imported_predicted_df['fg_over'][ind] = 0
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imported_predicted_df['converted_predicted'] = imported_predicted_df['converted_predicted'].astype(float)
imported_predicted_df['margin_over'] = imported_predicted_df['margin_over'].astype(float)
imported_predicted_df['fg_over'] = imported_predicted_df['fg_over'].astype(float)

# %%
imported_predicted_df['total'] = 0.0

# %%
for ind in imported_predicted_df.index:
    imported_predicted_df['total'][ind] = imported_predicted_df['predicted'][ind] + \
    imported_predicted_df['margin_over'][ind] + imported_predicted_df['fg_over'][ind]
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imported_predicted_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 0   2021-01-22       CHO          CHI -14.487500  105.312500  119.800000
# 1   2021-01-22       DET          HOU  -7.196429  107.392857  114.589286
# 2   2021-01-22       IND          ORL   1.958333  112.916667  110.958333
# 3   2021-01-22       CLE          BRK  -9.485065  105.428571  114.913636
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 5   2021-01-22       TOR          MIA  -4.678571  109.714286  114.392857
# 6   2021-01-22       MIN          ATL  -4.880952  106.940476  111.821429
# 7   2021-01-22       SAS          DAL   1.402778  108.777778  107.375000
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 9   2021-01-22       PHO          DEN   0.640278  111.062500  110.422222
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# ...

# %%
mask3 = (imported_predicted_df['MARGIN'] > 2)

# %%
for ind in imported_predicted_df.index:
    if imported_predicted_df['margin_over'][ind] == 1:
        imported_predicted_df['total'][ind] = imported_predicted_df['predicted'][ind] + imported_predicted_df['margin_over'][ind] + imported_predicted_df['fg_over'][ind]
    else:
        imported_predicted_df['total'][ind] = imported_predicted_df['predicted'][ind]
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imported_predicted_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 0   2021-01-22       CHO          CHI -14.487500  105.312500  119.800000
# 1   2021-01-22       DET          HOU  -7.196429  107.392857  114.589286
# 2   2021-01-22       IND          ORL   1.958333  112.916667  110.958333
# 3   2021-01-22       CLE          BRK  -9.485065  105.428571  114.913636
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 5   2021-01-22       TOR          MIA  -4.678571  109.714286  114.392857
# 6   2021-01-22       MIN          ATL  -4.880952  106.940476  111.821429
# 7   2021-01-22       SAS          DAL   1.402778  108.777778  107.375000
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 9   2021-01-22       PHO          DEN   0.640278  111.062500  110.422222
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# ...

# %%
# mask3 = (imported_predicted_df['] == 1)

# %%
mask4 = (imported_predicted_df['total'] > 2)

# %%
configured_df2 = imported_predicted_df.loc[mask4]

# %%
len(configured_df2)
# Out:
# 26

# %% [markdown]
# ## <font color='green'> Metrics </font>

# %%
from sklearn.metrics import accuracy_score
predicted_values = imported_predicted_df['converted_predicted'].tolist()
actual_values = imported_predicted_df['HOME_TEAM_WINS'].tolist()
accuracy_score(predicted_values, actual_values)
# Out:
# 0.5697674418604651

# %%
from sklearn.metrics import accuracy_score
predicted_values = configured_df2['converted_predicted'].tolist()
actual_values = configured_df2['HOME_TEAM_WINS'].tolist()
accuracy_score(predicted_values, actual_values)
# Out:
# 0.6923076923076923

# %% [markdown]
# SUMMARY
#
# Very easy to predict strong teams vs bad teams

# %%
configured_df2['converted_predicted'] = configured_df2['converted_predicted'].astype(int)
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
configured_df2.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'MARGIN', 'PTS_home', 'PTS_away',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS', 'predicted', 'converted_predicted', 'margin_over',
#        'fg_over', 'total'],
#       dtype='object')

# %%
empty_2 = []

# %%
for ind in configured_df2.index:
    if configured_df2['converted_predicted'][ind] == configured_df2['HOME_TEAM_WINS'][ind]:
        empty_2.append(configured_df2['VISITOR_ABBR'][ind])

# %% [markdown]
# ## <font color='green'> Teams that are predicted from the dataframe </font>

# %%
empty_2
# Out:
# ['BOS',
#  'OKC',
#  'NYK',
#  'MIA',
#  'TOR',
#  'OKC',
#  'CLE',
#  'ATL',
#  'NYK',
#  'MIA',
#  'NYK',
#  'LAL',
#  'DAL',
#  'DAL',
#  'HOU',
#  'UTA',
#  'NYK',
#  'POR']

# %%
configured_df2.loc[configured_df2['HOME_ABBR'] == 'UTA']
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 36  2021-01-26       UTA          NYK  10.696609  113.956349  103.259740
# 47  2021-01-27       UTA          DAL   3.635732  113.340278  109.704545
# 62  2021-01-29       UTA          DAL   3.402778  113.527778  110.125000
#
#     FG_PCT_home  FT_PCT_home  FG3_PCT_home   AST_home   REB_home  FG_PCT_away  \
# 36     0.463056     0.724929      0.394313  23.996032  49.908730     0.428289
# 47     0.457712     0.736219      0.386934  23.982639  50.163194     0.454356
# 62     0.458556     0.736500      0.387611  23.638889  50.111111     0.455333
#
#     FT_PCT_away  FG3_PCT_away   AST_away   REB_away  HOME_TEAM_WINS  \
# 36     0.760744      0.310458  22.607143  45.100649               1
# 47     0.752932      0.340970  22.560606  46.522727               1
# 62     0.760437      0.343833  22.458333  46.750000               1
#
#     predicted  converted_predicted  margin_over  fg_over     total
# ...

# %%
for ind in predicted_df.index: 
    if predicted_df['Prediction'][ind] > 0.1:
        predicted_df['Prediction'][ind] = 1
    else:
        predicted_df['Prediction'][ind] = 0

# %%
count_df= pd.DataFrame(columns=['empty'])

# %%
count_df['home_abbr'] = configured_df2['HOME_ABBR']

# %%
imported_predicted_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 0   2021-01-22       CHO          CHI -14.487500  105.312500  119.800000
# 1   2021-01-22       DET          HOU  -7.196429  107.392857  114.589286
# 2   2021-01-22       IND          ORL   1.958333  112.916667  110.958333
# 3   2021-01-22       CLE          BRK  -9.485065  105.428571  114.913636
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 5   2021-01-22       TOR          MIA  -4.678571  109.714286  114.392857
# 6   2021-01-22       MIN          ATL  -4.880952  106.940476  111.821429
# 7   2021-01-22       SAS          DAL   1.402778  108.777778  107.375000
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 9   2021-01-22       PHO          DEN   0.640278  111.062500  110.422222
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# ...

# %%
vertical_stack.head()
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# 14  2021-01-23       CHI          LAL  14.018750  116.800000  102.781250
#
#     FG_PCT_home  FT_PCT_home  FG3_PCT_home   AST_home  ...  FG3_PCT_away  \
# 4      0.482875     0.754708      0.367333  26.125000  ...      0.353988
# 8      0.483741     0.835406      0.439179  25.593750  ...      0.337917
# 10     0.479850     0.718025      0.373825  25.625000  ...      0.300738
# 11     0.495390     0.809508      0.399663  26.174242  ...      0.372750
# 14     0.458600     0.840950      0.372175  23.350000  ...      0.338531
#
#      AST_away   REB_away  HOME_TEAM_WINS  predicted  converted_predicted  \
# ...

# %%
len(configured_df2)
# Out:
# 42

# %%
len(configured_df)
# Out:
# 24

# %%
imported_predicted_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 0   2021-01-22       CHO          CHI -14.487500  105.312500  119.800000
# 1   2021-01-22       DET          HOU  -7.196429  107.392857  114.589286
# 2   2021-01-22       IND          ORL   1.958333  112.916667  110.958333
# 3   2021-01-22       CLE          BRK  -9.485065  105.428571  114.913636
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 5   2021-01-22       TOR          MIA  -4.678571  109.714286  114.392857
# 6   2021-01-22       MIN          ATL  -4.880952  106.940476  111.821429
# 7   2021-01-22       SAS          DAL   1.402778  108.777778  107.375000
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 9   2021-01-22       PHO          DEN   0.640278  111.062500  110.422222
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# ...

# %%
mask1 = (imported_predicted_df['total'] > 2)
second_high_prob = imported_predicted_df.loc[mask1]

# %%
second_high_prob
# Out:
# Empty DataFrame
# Columns: [DATE, HOME_ABBR, VISITOR_ABBR, MARGIN, PTS_home, PTS_away, FG_PCT_home, FT_PCT_home, FG3_PCT_home, AST_home, REB_home, FG_PCT_away, FT_PCT_away, FG3_PCT_away, AST_away, REB_away, HOME_TEAM_WINS, predicted, converted_predicted, margin_over, fg_over, margin_over_3, total]
# Index: []
#
# [0 rows x 23 columns]

# %%
from sklearn.metrics import accuracy_score
predicted_values = second_high_prob['converted_predicted'].tolist()
actual_values = second_high_prob['HOME_TEAM_WINS'].tolist()
accuracy_score(predicted_values, actual_values)
# Out:
# 0.6923076923076923

# %%
len(high_prob_wins)
# Out:
# 26

# %%
vertical_prob = pd.concat([high_prob_wins, second_high_prob], axis=0)
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
vertical_prob.columns
# Out:
# Index(['AST_away', 'AST_home', 'DATE', 'FG3_PCT_away', 'FG3_PCT_home',
#        'FG_PCT_away', 'FG_PCT_home', 'FT_PCT_away', 'FT_PCT_home', 'HOME_ABBR',
#        'HOME_TEAM_WINS', 'MARGIN', 'PTS_away', 'PTS_home', 'REB_away',
#        'REB_home', 'VISITOR_ABBR', 'accuracy', 'converted_predicted',
#        'fg_over', 'margin_over', 'margin_over_3', 'predicted', 'total'],
#       dtype='object')

# %% [markdown]
# TUTORIAL
# ```python
#
# df.drop_duplicates(subset=['brand'])
# ```

# %%
vertical_proba
# Out:
#      AST_away   AST_home        DATE  FG3_PCT_away  FG3_PCT_home  FG_PCT_away  \
# 4   22.630952  26.125000  2021-01-22      0.353988      0.367333     0.460887
# 8   25.404762  25.593750  2021-01-22      0.337917      0.439179     0.455726
# 10  23.107143  25.625000  2021-01-22      0.300738      0.373825     0.424607
# 11  24.928571  26.174242  2021-01-23      0.372750      0.399663     0.455786
# 14  24.062500  23.350000  2021-01-23      0.338531      0.372175     0.440687
# 18  27.263393  25.708333  2021-01-24      0.368964      0.356542     0.454036
# 19  24.989583  25.166667  2021-01-24      0.335760      0.428012     0.461833
# 20  24.468750  22.468750  2021-01-24      0.385629      0.359031     0.450746
# 22  23.441964  26.138393  2021-01-24      0.327339      0.398308     0.440853
# 24  22.907143  21.520833  2021-01-24      0.305446      0.366000     0.424682
# 26  26.781250  25.591667  2021-01-25      0.365094      0.354242     0.449000
# ...

# %%
len(vertical_prob)
# Out:
# 52

# %% [markdown]
# TUTORIAL
# ```python
# vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)
# ```

# %%
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
imported_predicted_df
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 0   2021-01-22       CHO          CHI -14.487500  105.312500  119.800000
# 1   2021-01-22       DET          HOU  -7.196429  107.392857  114.589286
# 2   2021-01-22       IND          ORL   1.958333  112.916667  110.958333
# 3   2021-01-22       CLE          BRK  -9.485065  105.428571  114.913636
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 5   2021-01-22       TOR          MIA  -4.678571  109.714286  114.392857
# 6   2021-01-22       MIN          ATL  -4.880952  106.940476  111.821429
# 7   2021-01-22       SAS          DAL   1.402778  108.777778  107.375000
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 9   2021-01-22       PHO          DEN   0.640278  111.062500  110.422222
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# ...

# %%
mask = (imported_predicted_df['total'] > 2)

# %%
high_prob_wins = imported_predicted_df.loc[mask]

# %%
high_prob_wins['accuracy'] = 1
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(high_prob_wins)
# Out:
# 26

# %%
from sklearn.metrics import accuracy_score
predicted_values = high_prob_wins['accuracy'].tolist()
actual_values = high_prob_wins['HOME_TEAM_WINS'].tolist()
accuracy_score(predicted_values, actual_values)
# Out:
# 0.6538461538461539

# %%
high_prob_wins
# Out:
#           DATE HOME_ABBR VISITOR_ABBR     MARGIN    PTS_home    PTS_away  \
# 4   2021-01-22       PHI          BOS   6.059524  116.166667  110.107143
# 8   2021-01-22       LAC          OKC   4.471726  115.102679  110.630952
# 10  2021-01-22       SAC          NYK  11.594048  113.725000  102.130952
# 11  2021-01-23       BRK          MIA   7.477814  120.299242  112.821429
# 14  2021-01-23       CHI          LAL  14.018750  116.800000  102.781250
# 18  2021-01-24       IND          TOR   1.589286  113.500000  111.910714
# 19  2021-01-24       LAC          OKC   3.758929  115.488095  111.729167
# 20  2021-01-24       BOS          CLE   4.919643  110.062500  105.142857
# 22  2021-01-24       MIL          ATL   9.102679  119.424107  110.321429
# 24  2021-01-24       POR          NYK  10.881548  113.145833  102.264286
# 26  2021-01-25       IND          TOR   1.897917  112.616667  110.718750
# 28  2021-01-25       BRK          MIA   6.534226  120.708333  114.174107
# ...

# %%
high_prob_wins.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'MARGIN', 'PTS_home', 'PTS_away',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS', 'predicted', 'converted_predicted', 'margin_over',
#        'fg_over', 'total', 'accuracy'],
#       dtype='object')

# %% [markdown]
# ##### from sklearn.metrics import accuracy_score
# predicted_values = imported_predicted_df['converted_predicted'].tolist()
# actual_values = imported_predicted_df['HOME_TEAM_WINS'].tolist()
# accuracy_var = accuracy_score(predicted_values, actual_values)
# print(f'The accuracy is 56% from accuracy_var')

# %% [markdown]
# Tutorial <br>
#
# Prediction
# ```python
#
#
#
# predictions_check_df = imported_predicted_df[['HOME_TEAM_WINS']]
#
#
# imported_predicted_df = imported_predicted_df.drop(columns=['HOME_TEAM_WINS'])
# imported_predicted_df
#
# imported_predicted_df = imported_predicted_df[['PTS_home', 'PTS_away', 'margin', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']]
#
# X_train_scaled_2 = X_scaler.transform(imported_predicted_df)
# classifier.predict(X_train_scaled_2)
#
# ```
#
# Convert the products into a dataframe
# ```python
# np_list = classifier.predict(X_train_scaled_2)
# np_list = np_list.flatten()
# np_list = np_list.tolist()
# df_list = pd.DataFrame(np_list)
# df_list
# ```

# %%
np_list = classifier.predict(X_train_scaled_2)
np_list = np_list.flatten()
np_list = np_list.tolist()
df_list = pd.DataFrame(np_list)
df_list
# Out:
#           0
# 0 -0.083454
# 1 -0.073903
# 2  0.232044
# 3  0.101831
# 4  0.472685
# 5  0.008517
# 6  0.506038
# 7 -0.259883

# %%
imported_predicted_df
# Out:
#      PTS_home    PTS_away    MARGIN  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 0  112.236271  112.685516 -0.449245     0.456124     0.798223      0.368931
# 1  112.216954  110.723214  1.493740     0.484690     0.774672      0.354885
# 2  114.676129  111.210648  3.465481     0.471092     0.791029      0.373330
# 3  116.363103  111.824138  4.538966     0.466802     0.788983      0.383328
# 4  118.564484  110.569063  7.995422     0.476249     0.748294      0.363407
# 5  109.886015  110.565625 -0.679610     0.479650     0.773618      0.362572
# 6  116.766284  107.410714  9.355569     0.449648     0.789205      0.342413
# 7  114.697115  116.643369 -1.946254     0.481343     0.726190      0.349268
#
#     AST_home   REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away   AST_away  \
# 0  24.955619  45.819604     0.451198     0.754610      0.351897  22.785714
# 1  27.129598  43.432184     0.464827     0.783936      0.352328  22.449176
# ...

# %%
df.head(100)
# Out:
#    GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0     2020-12-19  12000047            Final    1610612753       1610612766
# 1     2020-12-19  12000048            Final    1610612764       1610612765
# 2     2020-12-19  12000049            Final    1610612763       1610612737
# 3     2020-12-18  12000039            Final    1610612754       1610612755
# 4     2020-12-18  12000040            Final    1610612761       1610612748
# ..           ...       ...              ...           ...              ...
# 95    2020-08-29  41900105            Final    1610612749       1610612753
# 96    2020-08-29  41900175            Final    1610612745       1610612760
# 97    2020-08-29  41900145            Final    1610612747       1610612757
# 98    2020-08-25  41900165            Final    1610612743       1610612762
# 99    2020-08-25  41900155            Final    1610612746       1610612742
#
# ...

# %%
df2 = df.loc[df['GAME_DATE_EST'] < '2020-08-16']

# %%
df2 = df2.head(800)

# %%
len(df2)
# Out:
# 800

# %%
df2.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
df2.head()
# Out:
#     GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 132    2020-08-15  51900111            Final    1610612757       1610612763
# 133    2020-08-14  21901318            Final    1610612761       1610612743
# 134    2020-08-14  21901316            Final    1610612754       1610612748
# 135    2020-08-14  21901317            Final    1610612746       1610612760
# 136    2020-08-14  21901315            Final    1610612745       1610612755
#
#      SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 132    2019    1610612757     126.0        0.452        0.854  ...      20.0
# 133    2019    1610612761     117.0        0.500        0.643  ...      27.0
# 134    2019    1610612754     109.0        0.483        0.727  ...      32.0
# 135    2019    1610612746     107.0        0.400        0.692  ...      23.0
# 136    2019    1610612745      96.0        0.438        0.875  ...      25.0
#
# ...

# %%
df2 = df2[['PTS_home', 'FG_PCT_home',
       'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
       'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
       'REB_away', 'HOME_TEAM_WINS']]

# %%
df2.head()
# Out:
#      PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  REB_home  \
# 132     126.0        0.452        0.854         0.375      20.0      39.0
# 133     117.0        0.500        0.643         0.514      27.0      51.0
# 134     109.0        0.483        0.727         0.395      32.0      51.0
# 135     107.0        0.400        0.692         0.324      23.0      61.0
# 136      96.0        0.438        0.875         0.250      25.0      27.0
#
#      PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 132     122.0        0.489        0.818         0.560      30.0      49.0
# 133     109.0        0.414        0.913         0.421      27.0      41.0
# 134      92.0        0.356        0.741         0.263      14.0      48.0
# 135     103.0        0.358        0.591         0.318      18.0      48.0
# 136     134.0        0.563        0.818         0.474      31.0      51.0
#
#      HOME_TEAM_WINS
# 132               1
# 133               1
# ...

# %%
df2.columns
# Out:
# Index(['PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home',
#        'REB_home', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
df2.head(10)
# Out:
#      PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  REB_home  \
# 132     126.0        0.452        0.854         0.375      20.0      39.0
# 133     117.0        0.500        0.643         0.514      27.0      51.0
# 134     109.0        0.483        0.727         0.395      32.0      51.0
# 135     107.0        0.400        0.692         0.324      23.0      61.0
# 136      96.0        0.438        0.875         0.250      25.0      27.0
# 137      90.0        0.398        0.857         0.229      22.0      51.0
# 138     122.0        0.490        0.733         0.429      29.0      47.0
# 139     119.0        0.500        0.696         0.394      36.0      55.0
# 140     128.0        0.551        0.762         0.412      34.0      45.0
# 141     118.0        0.465        0.900         0.326      25.0      43.0
#
#      PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  \
# 132     122.0        0.489        0.818         0.560      30.0      49.0
# ...

# %%
df2.columns
# Out:
# Index(['PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home',
#        'REB_home', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
df2 = df2[['PTS_home', 'PTS_away', 'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home',
       'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
       'AST_away', 'REB_away']]

# %%
df2.head(10)
# Out:
#      PTS_home  PTS_away  HOME_TEAM_WINS  FG_PCT_home  FT_PCT_home  \
# 132     126.0     122.0               1        0.452        0.854
# 133     117.0     109.0               1        0.500        0.643
# 134     109.0      92.0               1        0.483        0.727
# 135     107.0     103.0               1        0.400        0.692
# 136      96.0     134.0               0        0.438        0.875
# 137      90.0      96.0               0        0.398        0.857
# 138     122.0     136.0               0        0.490        0.733
# 139     119.0     106.0               1        0.500        0.696
# 140     128.0     102.0               1        0.551        0.762
# 141     118.0     112.0               1        0.465        0.900
#
#      FG3_PCT_home  AST_home  REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 132         0.375      20.0      39.0        0.489        0.818         0.560
# 133         0.514      27.0      51.0        0.414        0.913         0.421
# ...

# %%
df2['margin'] = 0
for ind in df2.index: 
    df2['margin'][ind] = df2['PTS_home'][ind] - df2['PTS_away'][ind]
# Out:
# /Users/stanleytan/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2 = df2[['PTS_home', 'PTS_away', 'HOME_TEAM_WINS', 'margin', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home',
       'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
       'AST_away', 'REB_away']]

# %%
df2.head(10)
# Out:
#      PTS_home  PTS_away  HOME_TEAM_WINS  margin  FG_PCT_home  FT_PCT_home  \
# 132     126.0     122.0               1       4        0.452        0.854
# 133     117.0     109.0               1       8        0.500        0.643
# 134     109.0      92.0               1      17        0.483        0.727
# 135     107.0     103.0               1       4        0.400        0.692
# 136      96.0     134.0               0     -38        0.438        0.875
# 137      90.0      96.0               0      -6        0.398        0.857
# 138     122.0     136.0               0     -14        0.490        0.733
# 139     119.0     106.0               1      13        0.500        0.696
# 140     128.0     102.0               1      26        0.551        0.762
# 141     118.0     112.0               1       6        0.465        0.900
#
#      FG3_PCT_home  AST_home  REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# ...

# %%
df2.corr()
# Out:
#                 PTS_home  PTS_away  HOME_TEAM_WINS    margin  FG_PCT_home  \
# PTS_home        1.000000  0.352853        0.482424  0.589209     0.688864
# PTS_away        0.352853  1.000000       -0.439480 -0.548106     0.077917
# HOME_TEAM_WINS  0.482424 -0.439480        1.000000  0.810743     0.470448
# margin          0.589209 -0.548106        0.810743  1.000000     0.548496
# FG_PCT_home     0.688864  0.077917        0.470448  0.548496     1.000000
# FT_PCT_home     0.150141  0.046135        0.068287  0.094373    -0.023353
# FG3_PCT_home    0.545087  0.037220        0.382643  0.455116     0.557631
# AST_home        0.512208  0.103699        0.261852  0.368319     0.486068
# REB_home        0.147057 -0.283237        0.291604  0.376037    -0.147660
# FG_PCT_away     0.037244  0.662337       -0.444391 -0.538652     0.032305
# FT_PCT_away     0.050046  0.238196       -0.143653 -0.160952     0.021616
# FG3_PCT_away    0.036229  0.550597       -0.354871 -0.443069     0.042618
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(16, 6))

mask = np.triu(np.ones_like(df2.corr(), dtype=np.bool))


heatmap = sns.heatmap(df2.corr(), mask=mask, vmin=-1, vmax=1, annot=False, cmap='BrBG')

# %%
df2.head(1)
# Out:
#      PTS_home  PTS_away  HOME_TEAM_WINS  margin  FG_PCT_home  FT_PCT_home  \
# 132     126.0     122.0               1       4        0.452        0.854
#
#      FG3_PCT_home  AST_home  REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 132         0.375      20.0      39.0        0.489        0.818          0.56
#
#      AST_away  REB_away
# 132      30.0      49.0

# %%
plt.figure(figsize=(16, 6))

mask = np.triu(np.ones_like(df2.corr(), dtype=np.bool))


heatmap = sns.heatmap(df2.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %%
len(df2)
# Out:
# 800

# %%
import scipy.stats as st
fg_pct_home = df2['FG_PCT_home']
reb_away = df2['REB_away']
cor=round(st.pearsonr(fg_pct_home, reb_away)[0], 2)
print(f'Correlation between fg_pct_home and reb_away is {cor}')
model = st.linregress(fg_pct_home, reb_away)

y_values = fg_pct_home*model[0]+ model[1]

plt.scatter(fg_pct_home, reb_away)
plt.plot(fg_pct_home, y_values, color='red')
plt.xlabel('fg_pct_home')
plt.ylabel('reb_away')
plt.show()
# Out:
# Correlation between fg_pct_home and reb_away is -0.61

# %%
import scipy.stats as st
fg_pct_home = df2['FG_PCT_home']
margin = df2['margin']
cor=round(st.pearsonr(fg_pct_home, margin)[0], 2)
print(f'Correlation between fg_pct_home and reb_away is {cor}')
model = st.linregress(fg_pct_home, margin)

y_values = fg_pct_home*model[0]+ model[1]

plt.scatter(fg_pct_home, margin)
plt.plot(fg_pct_home, y_values, color='red')
plt.xlabel('fg_pct_home')
plt.ylabel('margin')
plt.show()
# Out:
# Correlation between fg_pct_home and reb_away is 0.55

# %%
df2.head()
# Out:
#      PTS_home  PTS_away  HOME_TEAM_WINS  margin  FG_PCT_home  FT_PCT_home  \
# 132     126.0     122.0               1       4        0.452        0.854
# 133     117.0     109.0               1       8        0.500        0.643
# 134     109.0      92.0               1      17        0.483        0.727
# 135     107.0     103.0               1       4        0.400        0.692
# 136      96.0     134.0               0     -38        0.438        0.875
#
#      FG3_PCT_home  AST_home  REB_home  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 132         0.375      20.0      39.0        0.489        0.818         0.560
# 133         0.514      27.0      51.0        0.414        0.913         0.421
# 134         0.395      32.0      51.0        0.356        0.741         0.263
# 135         0.324      23.0      61.0        0.358        0.591         0.318
# 136         0.250      25.0      27.0        0.563        0.818         0.474
#
#      AST_away  REB_away
# 132      30.0      49.0
# ...

# %% [markdown]
# TUTORIAL
#
# ```
# for i in range(0,10):
#     print(i)
#     ```

# %%
predicted_df['Random_Generator'] = empty_l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-d85ab76e6d2d> in <module>
# ----> 1 predicted_df['Random_Generator'] = empty_l
#
# NameError: name 'empty_l' is not defined

# %%
empty_2 = []

# %%
empty_l = []

# %%
from sklearn.metrics import accuracy_score

empty_l = []

for i in range(0,200):
    empty_l.append(round(random.uniform(0,1)))
predicted_df['Random_Generator'] = empty_l
predicted_values = predicted_df['Random_Generator'].tolist()
actual_values = predicted_df['Actual'].tolist()
empty_2.append(accuracy_score(predicted_values, actual_values))

# %%
len(empty_2)
# Out:
# 49

# %%
import statistics 

print(statistics.mean(empty_2))
# list of positive integer numbers
# Out:
# 0.5084693877551021

# %% [markdown]
# ### Summarize
#
# Summarize this and what does this mean
# If you were to grab the average prediction of NBA teams a random number generator would be 51% accurate after 49 tries

# %%
len(predicted_df)
# Out:
# 200

# %%
from sklearn.metrics import accuracy_score
import random

    
empty_2 = []    
for i in range(5):
    for i in range(0,200):
        empty_1 = []
        empty_1.append(round(random.uniform(0, 1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-c4ce5b8aa087> in <module>
#       8         empty_1 = []
#       9         empty_1.append(round(random.uniform(0, 1)))
# ---> 10         predicted_df['Random_Generator'] = empty_1
#      11         predicted_values = predicted_df['Random_Generator'].tolist()
#      12         actual_values = predicted_df['Actual'].tolist()
#
# ~/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# ~/anaconda3/envs/MachineLearning/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3562
#    3563         self._ensure_valid_index(value)
# ...

# %%
empty_2
# Out:
# [0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55,
#  0.55]

# %%
# make a histogram
# of randomly selected numbers:
