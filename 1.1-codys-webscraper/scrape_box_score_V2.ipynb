# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import numpy as np
from time import sleep
#1 import dependencies

# %%
df_2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5b36777b37c4> in <module>
# ----> 1 df_2.columns
#
# NameError: name 'df_2' is not defined

# %% [markdown]
# CREATE_TABLE
#
# CREATE TABLE full_schedule (
#     "ID" INT PRIMARY KEY,
#     "DATE" DATE,
#     "VISITOR" VARCHAR,
#     "VISITOR_PTS" INT,
#     "HOME" VARCHAR,
#     "HOME_PTS" INT,
#     "MARGIN" INT,
#     "HOME_ABBR" VARCHAR,
#     "VISITOR_ABBR" VARCHAR,
#     "HOME_TEAM_WINS" INT
# );

# %%
#import dependencies
import sqlalchemy
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine

# N.B. external config.py file should be formatted like:
# login = 'postgres:password' where password is set to whatever your database password is. Default username is 
# postgres, but change this if you use a different username.
import psycopg2
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
# postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
#                 .format(username='postgres',
#                         password='postgres',
#                         ipaddress='localhost',
#                         port=5432,
#                         dbname='flask_deploy'))

postgres_str = 'postgres://umydthrhevlwbv:a166611fc4fda747769900bb51cfb8cbd633cebe3ec13fdfc2180772a9d3bc8d@ec2-18-204-101-137.compute-1.amazonaws.com:5432/d9ugm948kmolua'



# Create the connection
engine = create_engine(postgres_str)
cnx = engine.connect()

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

Base.prepare(engine, reflect=True)

print(Base.classes.keys())
# Out:
# ['presidents', 'pets', 'box_score_2021', 'historic', 'all_for_ml_test', 'for_import_ml', 'full_schedule', 'predicted_values', 'training_model']

# %%
postgres_box_score = pd.read_sql("""
SELECT * FROM box_score_2021
""", con=engine)

# %%
postgres_box_score
# Out:
#       ID        DATE HOME_ABBR  MARGIN  HOME_TEAM_WINS VISITOR_ABBR  PTS_home  \
# 0      1  2020-12-22       BRK      26               1          GSW       125
# 1      2  2020-12-22       LAL      -7               0          LAC       109
# 2      3  2020-12-23       CLE       7               1          CHO       121
# 3      4  2020-12-23       IND      14               1          NYK       121
# 4      5  2020-12-23       ORL       6               1          MIA       113
# ..   ...         ...       ...     ...             ...          ...       ...
# 429  430  2021-02-19       MEM      14               1          DET       109
# 430  431  2021-02-19       MIL      13               1          OKC        98
# 431  432  2021-02-19       NOP     -18               0          PHO       114
# 432  433  2021-02-19       MIN      -5               0          TOR        81
# 433  434  2021-02-19       LAC       4               1          UTA       116
#
# ...

# %%
Because of covid the schedule is changing

# %%
from basketball_reference_scraper.seasons import get_schedule, get_standings

schedule_df = get_schedule(2021, playoffs=False)

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                  HOME  \
# 0    2020-12-22  Golden State Warriors           99         Brooklyn Nets
# 1    2020-12-22   Los Angeles Clippers          116    Los Angeles Lakers
# 2    2020-12-23      Charlotte Hornets          114   Cleveland Cavaliers
# 3    2020-12-23        New York Knicks          107        Indiana Pacers
# 4    2020-12-23             Miami Heat          107         Orlando Magic
# ...         ...                    ...          ...                   ...
# 1158 2021-06-26           Phoenix Suns           84  Los Angeles Clippers
# 1159 2021-06-27        Milwaukee Bucks          113         Atlanta Hawks
# 1160 2021-06-28   Los Angeles Clippers          116          Phoenix Suns
# 1161 2021-06-29        Milwaukee Bucks           88         Atlanta Hawks
# 1162 2021-06-30           Phoenix Suns          130  Los Angeles Clippers
#
#       HOME_PTS
# 0          125
# 1          109
# 2          121
# ...

# %%
from basketball_reference_scraper.seasons import get_schedule, get_standings

schedule_df = get_schedule(2021, playoffs=False)

team_to_abbreviation = {
    "ATLANTA HAWKS" : "ATL",
    "ST. LOUIS HAWKS" : "SLH",
    "MILWAUKEE HAWKS" : "MIL",
    "TRI-CITIES BLACKHAWKS" : "TCB",
    "BOSTON CELTICS" : "BOS",
    "BROOKLYN NETS" : "BRK",
    "NEW JERSEY NETS" : "NJN",
    "CHICAGO BULLS" : "CHI",
    "CHARLOTTE HORNETS": "CHO",
    "CHARLOTTE BOBCATS" : "CHA",
    "CLEVELAND CAVALIERS": "CLE",
    "DALLAS MAVERICKS" : "DAL",
    "DENVER NUGGETS" : "DEN",
    "DETROIT PISTONS" : "DET",
    "FORT WAYNE PISTONS" : "FWP",
    "GOLDEN STATE WARRIORS" : "GSW",
    "SAN FRANCISCO WARRIORS" : "SFW",
    "PHILADELPHIA WARRIORS" : "PHI",
    "HOUSTON ROCKETS" : "HOU",
    "INDIANA PACERS" : "IND",
    "LOS ANGELES CLIPPERS" : "LAC",
    "SAN DIEGO CLIPPERS" : "SDC",
    "BUFFALO BRAVES" : "BUF",
    "LOS ANGELES LAKERS" : "LAL",
    "MINNEAPOLIS LAKERS" : "MIN",
    "MEMPHIS GRIZZLIES" : "MEM",
    "VANCOUVER GRIZZLIES" : 'VAN',
    "MIAMI HEAT" : "MIA",
    "MILWAUKEE BUCKS" : "MIL",
    "MINNESOTA TIMBERWOLVES" : "MIN",
    "NEW ORLEANS PELICANS" : "NOP",
    "NEW ORLEANS/OKLAHOMA CITY HORNETS" : "NOK",
    "NEW ORLEANS HORNETS" : "NOH",
    "NEW YORK KNICKS" : "NYK",
    "OKLAHOMA CITY THUNDER" : "OKC",
    "SEATTLE SUPERSONICS" : "SEA",
    "ORLANDO MAGIC" : "ORL",
    "PHILADELPHIA 76ERS" : "PHI",
    "SYRACUSE NATIONALS" : "SYR",
    "PHOENIX SUNS" : "PHO",
    "PORTLAND TRAIL BLAZERS" : "POR",
    "SACRAMENTO KINGS" : "SAC",
    "KANSAS CITY KINGS" : "KCK",
    "KANSAS CITY-OMAHA KINGS" : "KCK",
    "CINCINNATI ROYALS" : "CIN",
    "ROCHESTER ROYALS" : "ROR",
    "SAN ANTONIO SPURS" : "SAS",
    "TORONTO RAPTORS" : "TOR",
    "UTAH JAZZ" : "UTA",
    "NEW ORLEANS JAZZ" : "NOJ",
    "WASHINGTON WIZARDS" : "WAS",
    "WASHINGTON BULLETS" : "WAS",
    "CAPITAL BULLETS" : "CAP",
    "BALTIMORE BULLETS" : "BAL",
    "CHICAGO ZEPHYRS" : "CHI",
    "CHICAGO PACKERS" : "CHI",
    "ANDERSON PACKERS" : "AND",
    "CHICAGO STAGS" : "CHI",
    "INDIANAPOLIS OLYMPIANS" : "IND",
    "SHEBOYGAN RED SKINS" : "SRS",
    "ST. LOUIS BOMBERS" : "SLB",
    "WASHINGTON CAPITOLS" : "WAS",
    "WATERLOO HAWKS" : "WAT"
}
schedule_df['MARGIN'] = 0
schedule_df['HOME_ABBR'] = 0
schedule_df['VISITOR_ABBR'] = 0
schedule_df['HOME_TEAM_WINS'] = 0 
schedule_df = schedule_df.fillna(0)
for ind in schedule_df.index: 
    schedule_df['MARGIN'][ind] = schedule_df['HOME_PTS'][ind] - schedule_df['VISITOR_PTS'][ind]
    schedule_df['VISITOR'][ind] = schedule_df['VISITOR'][ind].upper()
    schedule_df['HOME'][ind] = schedule_df['HOME'][ind].upper()
    schedule_df['HOME_ABBR'][ind] = team_to_abbreviation[schedule_df['HOME'][ind]]
    schedule_df['VISITOR_ABBR'][ind] = team_to_abbreviation[schedule_df['VISITOR'][ind]]
    if schedule_df['MARGIN'][ind] > 0: 
        schedule_df['HOME_TEAM_WINS'][ind] = 1
    else:
        schedule_df['HOME_TEAM_WINS'][ind] = 0 
end_a = len(schedule_df) + 1
a_ = list(range(1, end_a))
schedule_df['ID'] = a_
schedule_df = schedule_df[['ID','DATE', 'VISITOR', 'VISITOR_PTS', 'HOME', 'HOME_PTS', 'MARGIN',
       'HOME_ABBR', 'VISITOR_ABBR', 'HOME_TEAM_WINS']]

# %%
schedule_df.to_sql('full_schedule', engine, if_exists='replace', index=False)

# %%
with engine.connect() as con:
    con.execute('ALTER TABLE full_schedule ADD PRIMARY KEY ("ID");')

# %% [markdown]
# Will need this code later to return an element

# %%
postgres_box_score['DATE'] = pd.to_datetime(postgres_box_score['DATE'])
# Out:
# <ipython-input-92-d72aada2516e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   postgres_box_score['DATE'] = pd.to_datetime(postgres_box_score['DATE'])

# %%
list_of_dates_from_box_score = postgres_box_score['DATE'].dt.strftime("%Y-%m-%d").tolist()
sorted_list_of_dates_from_box_score = list(set(list_of_dates_from_box_score))
sorted_list_of_dates_from_box_score.sort()

# %% [markdown]
# ```
# schedule_df = df_2.copy()
# ```
# 1. change here because calling the schedule into the system

# %%
schedule_df['DATE'] = pd.to_datetime(schedule_df['DATE'])

# %%
list_of_dates_from_schedule = schedule_df['DATE'].dt.strftime("%Y-%m-%d").tolist()
sorted_list_of_dates_from_schedule = list(set(list_of_dates_from_schedule))
sorted_list_of_dates_from_schedule.sort()

# %%
len(sorted_list_of_dates_from_schedule)
#72
len(sorted_list_of_dates_from_box_score)
#51
# Out:
# 51

# %%
import time
from datetime import datetime, date, time, timedelta
today = date.today()
one_day = timedelta(1)
yesterday = today - one_day
date_time = yesterday.strftime('%Y-%m-%d')
date_time
# Out:
# '2021-02-19'

# %%
res = []
if date_time != sorted_list_of_dates_from_box_score[-1]:
    end_ = sorted_list_of_dates_from_schedule.index(date_time) + 1 
    #need to gather the end of the list of schedule
    new_list_of_dates_from_schedule = sorted_list_of_dates_from_schedule[0:end_]
    #after gathered then need to set something
    res = [i for i in new_list_of_dates_from_schedule if i not in list_of_dates_from_box_score]
else:
    print('there does not need to be an update')

# %%
res
# Out:
# ['2021-02-15', '2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19']

# %% [markdown]
# <u> SOMETHING IS WRONG WITH THIS CODE HERE don't know WHY THERE ARE TWO DATES THAT SHOW UP </u>

# %%
res = res[1]

# %%
res

# %%
res = [res]

# %%
schedule_df.head(1)
# Out:
#             ID                VISITOR  VISITOR_PTS           HOME  HOME_PTS  \
# DATE
# 2020-12-22   1  GOLDEN STATE WARRIORS         99.0  BROOKLYN NETS     125.0
#
#             MARGIN HOME_ABBR VISITOR_ABBR  HOME_TEAM_WINS
# DATE
# 2020-12-22      26       BRK          GSW               1

# %%
df.country.isin(countries_to_keep)

# %%
schedule_df1 = schedule_df.loc[schedule_df['DATE'].isin(res)]

# %%
schedule_df1
# Out:
#           DATE                 VISITOR  VISITOR_PTS                    HOME  \
# 399 2021-02-15           CHICAGO BULLS        120.0          INDIANA PACERS
# 400 2021-02-15         HOUSTON ROCKETS        119.0      WASHINGTON WIZARDS
# 401 2021-02-15           ATLANTA HAWKS        112.0         NEW YORK KNICKS
# 402 2021-02-15      PHILADELPHIA 76ERS        123.0               UTAH JAZZ
# 403 2021-02-15     CLEVELAND CAVALIERS         98.0   GOLDEN STATE WARRIORS
# 404 2021-02-15              MIAMI HEAT        118.0    LOS ANGELES CLIPPERS
# 405 2021-02-15           BROOKLYN NETS        136.0        SACRAMENTO KINGS
# 406 2021-02-16          DENVER NUGGETS         99.0          BOSTON CELTICS
# 407 2021-02-16    NEW ORLEANS PELICANS        144.0       MEMPHIS GRIZZLIES
# 408 2021-02-16         TORONTO RAPTORS        124.0         MILWAUKEE BUCKS
# 409 2021-02-16      LOS ANGELES LAKERS        112.0  MINNESOTA TIMBERWOLVES
# ...

# %%
Grabbing the IDs to put into the boxscore

# %%
last_postgres_id_plus_1 = postgres_box_score.tail(1)['ID'].iloc[0] +1 
end_b = len(schedule_df1)
end_c = last_postgres_id_plus_1 + end_b
b_ = list(range(last_postgres_id_plus_1, end_c))
schedule_df1['ID'] = b_
# Out:
# <ipython-input-123-6b53fe91e3f7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   schedule_df1['ID'] = b_

# %%
# schedule_df = schedule_df.loc[schedule_df['VISITOR_PTS'] > 0]
# no need to run

# %% [markdown]
# <u> make this better because I have 0.0 for the scores </u>
# checking how I scrape for information

# %%
box_score_columns = ['ID', 'DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']
box_score_df = pd.DataFrame(columns=box_score_columns)

# %% [markdown]
# TUTORIAL
#
# ```python
# from basketball_reference_scraper.box_scores import get_box_scores
# date = '2021-02-19'
# team1 = 'ATL'
# team2 = 'BOS'
# dict_ = get_box_scores(date, team1, team2, period='GAME', stat_type='BASIC')
# second_ = dict_['ATL']
# second_.loc[second_['PLAYER'] == 'Team Totals']['FG'].iloc[0]
# ```

# %%
schedule_df1.tail(1)
# Out:
#           DATE    VISITOR  VISITOR_PTS                  HOME  HOME_PTS  \
# 433 2021-02-19  UTAH JAZZ        112.0  LOS ANGELES CLIPPERS     116.0
#
#      MARGIN HOME_ABBR VISITOR_ABBR  HOME_TEAM_WINS   ID
# 433       4       LAC          UTA               1  434

# %%
from basketball_reference_scraper.box_scores import get_box_scores

# %%
dict_ = get_box_scores(date_1, visitor_1, home_1, period='GAME', stat_type='BASIC')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8e56ec8c2125> in <module>
# ----> 1 dict_ = get_box_scores(date_1, visitor_1, home_1, period='GAME', stat_type='BASIC')
#
# NameError: name 'date_1' is not defined

# %%
schedule_df
# Out:
#            DATE                VISITOR  VISITOR_PTS                  HOME  \
# 0    2020-12-22  Golden State Warriors           99         Brooklyn Nets
# 1    2020-12-22   Los Angeles Clippers          116    Los Angeles Lakers
# 2    2020-12-23      Charlotte Hornets          114   Cleveland Cavaliers
# 3    2020-12-23        New York Knicks          107        Indiana Pacers
# 4    2020-12-23             Miami Heat          107         Orlando Magic
# ...         ...                    ...          ...                   ...
# 1158 2021-06-26           Phoenix Suns           84  Los Angeles Clippers
# 1159 2021-06-27        Milwaukee Bucks          113         Atlanta Hawks
# 1160 2021-06-28   Los Angeles Clippers          116          Phoenix Suns
# 1161 2021-06-29        Milwaukee Bucks           88         Atlanta Hawks
# 1162 2021-06-30           Phoenix Suns          130  Los Angeles Clippers
#
#       HOME_PTS
# 0          125
# 1          109
# 2          121
# ...

# %%
for ind in schedule_df1.index:
    date_1 = schedule_df1.loc[ind]['DATE']
    home_1 = schedule_df1.loc[ind]['HOME_ABBR']
    visitor_1 = schedule_df1.loc[ind]['VISITOR_ABBR']
    dict_ = get_box_scores(date_1, visitor_1, home_1, period='GAME', stat_type='BASIC')
    home_df = dict_[home_1]
    visitor_df = dict_[visitor_1]
    third_ = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FG'].iloc[0]
    id_ = schedule_df1.loc[ind]['ID']
    home_pts = home_df.loc[home_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    visitor_pts = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['PTS'].iloc[0]
    margin_ = int(home_pts) - int(visitor_pts)
    if margin_ > 0:
        home_team_wins = 1
    else:
        home_team_wins = 0
    home_fg_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    home_ft_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    home_fg3_pct = home_df.loc[home_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    home_ast = home_df.loc[home_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    home_reb = home_df.loc[home_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    visitor_fg_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FG%'].iloc[0]
    visitor_ft_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['FT%'].iloc[0]
    visitor_fg3_pct = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['3P%'].iloc[0]
    visitor_ast = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['AST'].iloc[0]
    visitor_reb = visitor_df.loc[visitor_df['PLAYER'] == 'Team Totals']['TRB'].iloc[0]
    empty_ = []
    empty_.append(id_)
#ID
    empty_.append(date_1)
#DATE
    empty_.append(home_1)
#home abbr
    empty_.append(visitor_1)
#visito abbr
    empty_.append(home_pts)
#home pints
    empty_.append(visitor_pts)
#away points
    empty_.append(margin_)
#margin
    empty_.append(home_team_wins)
#HOME_TEAM_WINS
    empty_.append(home_fg_pct)
#FG_PCT
    empty_.append(home_ft_pct)
#FT_PCT
    empty_.append(home_fg3_pct)
#FG3_PCT
    empty_.append(home_ast)
#AST
    empty_.append(home_reb)
#REBOUNDS
    empty_.append(visitor_fg_pct)
#FG_PCT
    empty_.append(visitor_ft_pct)
#FT_PCT
    empty_.append(visitor_fg3_pct)
#FG3
    empty_.append(visitor_ast)
#AST
    empty_.append(visitor_reb)
#REBOUNDS
    length_of_df = len(box_score_df)
    box_score_df.loc[length_of_df] = empty_
    sleep(0.1)

# %% [markdown]
# Errors that you run into, if a game got cancelled

# %%
#import dependencies
import sqlalchemy
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine

# N.B. external config.py file should be formatted like:
# login = 'postgres:password' where password is set to whatever your database password is. Default username is 
# postgres, but change this if you use a different username.
import psycopg2
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
                .format(username='postgres',
                        password='postgres',
                        ipaddress='localhost',
                        port=5432,
                        dbname='flask_deploy'))
# Create the connection
engine = create_engine(postgres_str)
cnx = engine.connect()

# %%
box_score_df_main_2.to_sql('box_score_2021', engine, if_exists='append', index=False)

# %%
#in case the other scraper does not work
for ind in schedule_df1.index:
    if schedule_df1['VISITOR_PTS'][ind] == 0.0:
        # date_1 = schedule_df1.loc[ind]['DATE'].replace(r"-","") + "0"
        # this stopped working for some reason
        date_1 = schedule_df1.loc[ind]['DATE']
        date_1 = date_1.strftime('%Y%m%d') + '0'
        home_1 = schedule_df1.loc[ind]['HOME_ABBR']
        visitor_1 = schedule_df1.loc[ind]['VISITOR_ABBR']
        basketball_url = "https://www.basketball-reference.com/boxscores/"
        url = basketball_url + date_1 + home_1 + ".html"
        html = urlopen(url)
        soup = BeautifulSoup(html)
        table_home_abbr = "box-{0}-game-basic".format(home_1)
        table_visitor_abbr = "box-{0}-game-basic".format(visitor_1)
        table_home = soup.find('table', {"id":table_home_abbr})
        df_home = pd.read_html(str(table_home))
        df_home = df_home[0]
      
        new_columns = ['STARTERS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', '+/-']
        np_array = np.arange(len(df_home.columns))
        list_ = np_array.tolist()
        df_home.columns = df_home.columns.droplevel(0)
#renaming columns
        for j in range(len(df_home.columns)):
            old = df_home.columns[j]
            new = new_columns[j]
            df_home = df_home.rename(columns = {old:new})
        table_visitor = soup.find('table', {"id":table_visitor_abbr})
        df_visitor = pd.read_html(str(table_visitor))
        df_visitor = df_visitor[0]
        new_columns = ['STARTERS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', '+/-']
        np_array = np.arange(len(df_visitor.columns))
        list_ = np_array.tolist()
        df_visitor.columns = df_visitor.columns.droplevel(0)
#renaming columns
        for j in range(len(df_visitor.columns)):
            old = df_visitor.columns[j]
            new = new_columns[j]
            df_visitor = df_visitor.rename(columns = {old:new})
        df_home_df = df_home.loc[df_home['STARTERS'] == 'Team Totals'].reset_index(drop=True)
        df_visitor_df = df_visitor.loc[df_visitor['STARTERS'] == 'Team Totals'].reset_index(drop=True)

        empty_ = []
        id_ = schedule_df1.loc[ind]['ID']
        date_= schedule_df1.loc[ind]['DATE']
        home_abbr_ = schedule_df1.loc[ind]['HOME_ABBR']
        visitor_abbr_ = schedule_df1.loc[ind]['VISITOR_ABBR']
        home_pts_ = df_home_df.loc[0]['PTS']
        visitor_pts_ = df_visitor_df.loc[0]['PTS'] 
        margin_ = int(df_home_df.loc[0]['PTS']) - int(df_visitor_df.loc[0]['PTS'])
        if margin_ > 1:
                home_team_wins = 1
        else:
                home_team_wins = 0
        home_fg_pct_ = df_home_df.loc[0]['FG%']
        home_ft_pct_ = df_home_df.loc[0]['FT%'] 
        home_fg3_pct_ = df_home_df.loc[0]['3P%']
        home_ast_ = df_home_df.loc[0]['AST'] 
        home_reb_ = df_home_df.loc[0]['TRB']
        visitor_fg_pct_ = df_visitor_df.loc[0]['FG%']
        visitor_ft_pct_ = df_visitor_df.loc[0]['FT%']
        visitor_fg3_pct_ = df_visitor_df.loc[0]['3P%']
        visitor_ast_ = df_visitor_df.loc[0]['AST']
        visitor_reb_ = df_visitor_df.loc[0]['TRB']
        empty_.append(id_)
#ID
        empty_.append(date_)
#DATE
        empty_.append(home_abbr_)
#home abbbr
        empty_.append(visitor_abbr_)
#visitor abbr
        empty_.append(home_pts_)
#home points
        empty_.append(visitor_pts_)
#away points
        empty_.append(margin_)
#margin
        empty_.append(home_team_wins)
#HOME_TEAM_WINS
        empty_.append(home_fg_pct_)
#FG_PCT
        empty_.append(home_ft_pct_)
#FT_PCT
        empty_.append(home_fg3_pct_)
#FG3_PCT
        empty_.append(home_ast_)
#AST
        empty_.append(home_reb_)
#REBOUNDS
        empty_.append(visitor_fg_pct_)
#FG_PCT
        empty_.append(visitor_ft_pct_)
#FT_PCT
        empty_.append(visitor_fg3_pct_)
#FG3
        empty_.append(visitor_ast_)
#AST
        empty_.append(visitor_reb_)
#REBOUNDS
        length_of_df = len(box_score_df)
        box_score_df.loc[length_of_df] = empty_
        sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-23-5a2cfbd452b5> in <module>
#       9         basketball_url = "https://www.basketball-reference.com/boxscores/"
#      10         url = basketball_url + date_1 + home_1 + ".html"
# ---> 11         html = urlopen(url)
#      12         soup = BeautifulSoup(html)
#      13         table_home_abbr = "box-{0}-game-basic".format(home_1)
#
# ~/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
box_score_df
# Out:
#     ID       DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN  \
# 0  390 2021-02-14       WAS          BOS      104       91     13
# 1  391 2021-02-14       TOR          MIN      112      116     -4
# 2  392 2021-02-14       CHO          SAS      110      122    -12
# 3  393 2021-02-14       DET          NOP      123      112     11
# 4  394 2021-02-14       OKC          MIL      114      109      5
# 5  395 2021-02-14       DAL          POR      118      121     -3
# 6  396 2021-02-14       PHO          ORL      109       90     19
# 7  397 2021-02-14       SAC          MEM      110      124    -14
# 8  398 2021-02-14       DEN          LAL      122      105     17
# 9  399 2021-02-14       LAC          CLE      128      111     17
#
#   HOME_TEAM_WINS FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home  \
# 0              1        .398        .861         .233       24       54
# 1              0        .418        .839         .303       24       38
# ...

# %%
schedule_df1
# Out:
#       ID        DATE             VISITOR  VISITOR_PTS                    HOME  \
# 368  369  2021-02-11     TORONTO RAPTORS          0.0          BOSTON CELTICS
# 369  370  2021-02-11          MIAMI HEAT          0.0         HOUSTON ROCKETS
# 370  371  2021-02-11      INDIANA PACERS          0.0         DETROIT PISTONS
# 371  372  2021-02-11       ORLANDO MAGIC          0.0   GOLDEN STATE WARRIORS
# 372  373  2021-02-11  PHILADELPHIA 76ERS          0.0  PORTLAND TRAIL BLAZERS
#
#      HOME_PTS  MARGIN HOME_ABBR VISITOR_ABBR  HOME_TEAM_WINS
# 368       0.0       0       BOS          TOR               0
# 369       0.0       0       HOU          MIA               0
# 370       0.0       0       DET          IND               0
# 371       0.0       0       GSW          ORL               0
# 372       0.0       0       POR          PHI               0

# %%
box_score_df
# Out:
#     ID        DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN  \
# 0  369  2021-02-11       BOS          TOR      120      106     14
# 1  370  2021-02-11       HOU          MIA       94      101     -7
# 2  371  2021-02-11       DET          IND       95      111    -16
# 3  372  2021-02-11       GSW          ORL      111      105      6
# 4  373  2021-02-11       POR          PHI      118      114      4
#
#   HOME_TEAM_WINS FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home  \
# 0              1        .453        .786         .513       30       49
# 1              0        .386        .750         .300       24       42
# 2              0        .447        .737         .179       21       43
# 3              1        .466        .750         .400       29       46
# 4              1        .430        .913         .447       15       47
#
#   FG_PCT_away FT_PCT_away FG3_PCT_away AST_away REB_away
# 0        .494        .789         .321       26       32
# ...

# %%
<u>off of the schedule I can grab certain things</u>
# Out:
#   File "<ipython-input-47-d85dcc8dc324>", line 1
#     <u>off of the schedule I can grab certain things</u>
#     ^
# SyntaxError: invalid syntax

# %%
#import dependencies
import sqlalchemy
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine

# N.B. external config.py file should be formatted like:
# login = 'postgres:password' where password is set to whatever your database password is. Default username is 
# postgres, but change this if you use a different username.
import psycopg2
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
# postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
#                 .format(username='postgres',
#                         password='postgres',
#                         ipaddress='localhost',
#                         port=5432,
#                         dbname='flask_deploy'))

postgres_str = 'postgres://umydthrhevlwbv:a166611fc4fda747769900bb51cfb8cbd633cebe3ec13fdfc2180772a9d3bc8d@ec2-18-204-101-137.compute-1.amazonaws.com:5432/d9ugm948kmolua'



# Create the connection
engine = create_engine(postgres_str)
cnx = engine.connect()

# %% [markdown]
# <u> loading into postgres database</u>

# %%
postgres_box_score
# Out:
#       ID       DATE HOME_ABBR  MARGIN  HOME_TEAM_WINS VISITOR_ABBR  PTS_home  \
# 0      1 2020-12-22       BRK      26               1          GSW       125
# 1      2 2020-12-22       LAL      -7               0          LAC       109
# 2      3 2020-12-23       CLE       7               1          CHO       121
# 3      4 2020-12-23       IND      14               1          NYK       121
# 4      5 2020-12-23       ORL       6               1          MIA       113
# ..   ...        ...       ...     ...             ...          ...       ...
# 363  364 2021-02-10       MIN      -7               0          LAC       112
# 364  365 2021-02-10       CHI      13               1          NOP       129
# 365  366 2021-02-10       DEN      38               1          CLE       133
# 366  367 2021-02-10       LAL       1               0          OKC       114
# 367  368 2021-02-10       PHO       1               0          MIL       125
#
# ...

# %%
box_score_df
# Out:
#      ID       DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN  \
# 0   369 2021-02-11       BOS          TOR      120      106     14
# 1   370 2021-02-11       HOU          MIA       94      101     -7
# 2   371 2021-02-11       DET          IND       95      111    -16
# 3   372 2021-02-11       GSW          ORL      111      105      6
# 4   373 2021-02-11       POR          PHI      118      114      4
# 5   374 2021-02-12       BOS          DET      102      108     -6
# 6   375 2021-02-12       CHO          MIN      120      114      6
# 7   376 2021-02-12       WAS          NYK       91      109    -18
# 8   377 2021-02-12       ATL          SAS      114      125    -11
# 9   378 2021-02-12       DAL          NOP      143      130     13
# 10  379 2021-02-12       CHI          LAC      106      125    -19
# 11  380 2021-02-12       DEN          OKC       97       95      2
# 12  381 2021-02-12       UTA          MIL      129      115     14
# ...

# %%
date_time
# Out:
# '2021-02-14'

# %%
box_score_df = box_score_df.loc[box_score_df['DATE'] == date_time]

# %%
box_score_df['ID'].tolist()
# Out:
# [369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384]

# %%
postgres_box_score = pd.read_sql("""
SELECT * FROM box_score_2021
""", con=engine)

# %%
postgres_box_score
# Out:
#       ID        DATE HOME_ABBR  MARGIN  HOME_TEAM_WINS VISITOR_ABBR  PTS_home  \
# 0      1  2020-12-22       BRK      26               1          GSW       125
# 1      2  2020-12-22       LAL      -7               0          LAC       109
# 2      3  2020-12-23       CLE       7               1          CHO       121
# 3      4  2020-12-23       IND      14               1          NYK       121
# 4      5  2020-12-23       ORL       6               1          MIA       113
# ..   ...         ...       ...     ...             ...          ...       ...
# 379  380  2021-02-12       DEN       2               1          OKC        97
# 380  381  2021-02-12       UTA      14               1          MIL       129
# 381  382  2021-02-12       LAL      10               1          MEM       115
# 382  383  2021-02-12       POR      19               1          CLE       129
# 383  384  2021-02-12       SAC     -11               0          ORL       112
#
# ...

# %%
box_score_df
# Out:
#     ID       DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN  \
# 0  369 2021-02-11       BOS          TOR      120      106     14
# 1  370 2021-02-11       HOU          MIA       94      101     -7
# 2  371 2021-02-11       DET          IND       95      111    -16
# 3  372 2021-02-11       GSW          ORL      111      105      6
# 4  373 2021-02-11       POR          PHI      118      114      4
# 5  385 2021-02-13       PHO          PHI      120      111      9
# 6  386 2021-02-13       ATL          IND      113      125    -12
# 7  387 2021-02-13       NYK          HOU      121       99     22
# 8  388 2021-02-13       GSW          BRK      117      134    -17
# 9  389 2021-02-13       UTA          MIA      112       94     18
#
#   HOME_TEAM_WINS FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home  \
# 0              1        .453        .786         .513       30       49
# 1              0        .386        .750         .300       24       42
# ...

# %%
box_score_df.to_sql('box_score_2021', engine, if_exists='append', index=False)

# %% [markdown]
# <u> error happened because I had double keys here </u>

# %%
box_score_df
# Out:
#     ID       DATE HOME_ABBR VISITOR_ABBR PTS_home PTS_away MARGIN  \
# 0  390 2021-02-14       WAS          BOS      104       91     13
# 1  391 2021-02-14       TOR          MIN      112      116     -4
# 2  392 2021-02-14       CHO          SAS      110      122    -12
# 3  393 2021-02-14       DET          NOP      123      112     11
# 4  394 2021-02-14       OKC          MIL      114      109      5
# 5  395 2021-02-14       DAL          POR      118      121     -3
# 6  396 2021-02-14       PHO          ORL      109       90     19
# 7  397 2021-02-14       SAC          MEM      110      124    -14
# 8  398 2021-02-14       DEN          LAL      122      105     17
# 9  399 2021-02-14       LAC          CLE      128      111     17
#
#   HOME_TEAM_WINS FG_PCT_home FT_PCT_home FG3_PCT_home AST_home REB_home  \
# 0              1        .398        .861         .233       24       54
# 1              0        .418        .839         .303       24       38
# ...

# %%
box_score_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1d8078aa932b> in <module>
# ----> 1 box_score_df.columns
#
# NameError: name 'box_score_df' is not defined

# %%
len(box_score_df.columns)
# Out:
# 18

# %%
box_score_df_main_2.to_csv('box_score_2021_V5.csv', index=False)
