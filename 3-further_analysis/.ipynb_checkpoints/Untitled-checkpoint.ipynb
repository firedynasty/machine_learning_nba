# %%
import pandas as pd
box_score = pd.read_csv('03_03box_score_combined.csv')

# %%
calculated_df = pd.read_csv('03_03_calculated_df_full.csv')

# %%
box_score['diff_%'] = box_score['home_winning_percentage'] - box_score['visitor_winning_percentage']
calculated_df['diff_%'] = calculated_df['home_winning_percentage'] - calculated_df['visitor_winning_percentage']

# %%
box_score.columns
# Out:
# Index(['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
#        'HOME_TEAM_WINS', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home',
#        'AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away',
#        'AST_away', 'REB_away', 'home_winning_percentage',
#        'visitor_winning_percentage', 'diff_%'],
#       dtype='object')

# %%
box_score_2 = box_score[['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN',
       'HOME_TEAM_WINS', 'home_winning_percentage', 'visitor_winning_percentage', 'diff_%']]

# %%
calculated_df_2 = calculated_df[['DATE', 'HOME_ABBR', 'VISITOR_ABBR', 'PTS_home', 'PTS_away', 'MARGIN', 'home_winning_percentage', 'visitor_winning_percentage', 'diff_%']]

# %%
calculated_df_2_explanation = 'box_score - grouped_values from the previous 10 games'

# %%
home_user_input = input('which home team do you want to take a look at?')
# Out:
# which home team do you want to take a look at?NOP

# %%
visitor_user_input = input('which visitor team do you want to take a look at?')
# Out:
# which visitor team do you want to take a look at?SAC

# %%
box_score_2.loc[box_score_2['HOME_ABBR'] == home_user_input].tail(10)
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 701  2022-01-24       NOP          IND       117       113       4
# 731  2022-01-28       NOP          DEN       105       116     -11
# 737  2022-01-29       NOP          BOS        97       107     -10
# 812  2022-02-08       NOP          HOU       110        97      13
# 825  2022-02-10       NOP          MIA        97       112     -15
# 840  2022-02-12       NOP          SAS       114       124     -10
# 856  2022-02-14       NOP          TOR       120        90      30
# 865  2022-02-15       NOP          MEM       109       121     -12
# 880  2022-02-17       NOP          DAL       118       125      -7
# 925  2022-03-02       NOP          SAC       125        95      30
#
#      HOME_TEAM_WINS  home_winning_percentage  visitor_winning_percentage  \
# 701               1                 0.391304                    0.354167
# 731               0                 0.375000                    0.562500
# 737               0                 0.367347                    0.509804
# 812               1                 0.407407                    0.277778
# 825               0                 0.400000                    0.642857
# 840               0                 0.392857                    0.385965
# 856               1                 0.403509                    0.553571
# 865               0                 0.396552                    0.694915
# 880               0                 0.389831                    0.593220
# 925               1                 0.419355                    0.365079
#
#        diff_%
# 701  0.037138
# 731 -0.187500
# 737 -0.142457
# 812  0.129630
# 825 -0.242857
# 840  0.006892
# 856 -0.150063
# 865 -0.298364
# 880 -0.203390
# 925  0.054275

# %%
box_score_2.loc[box_score_2['VISITOR_ABBR'] == visitor_user_input].tail(10)
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 708  2022-01-25       BOS          SAC       128        75      53
# 716  2022-01-26       ATL          SAC       121       104      17
# 738  2022-01-29       PHI          SAC       103       101       2
# 755  2022-01-31       NYK          SAC       116        96      20
# 778  2022-02-03       GSW          SAC       126       114      12
# 841  2022-02-12       WAS          SAC       110       123     -13
# 852  2022-02-14       BRK          SAC       109        85      24
# 871  2022-02-16       CHI          SAC       125       118       7
# 913  2022-02-28       OKC          SAC       110       131     -21
# 925  2022-03-02       NOP          SAC       125        95      30
#
#      HOME_TEAM_WINS  home_winning_percentage  visitor_winning_percentage  \
# 708               1                 0.510204                    0.367347
# 716               1                 0.468085                    0.360000
# 738               1                 0.612245                    0.352941
# 755               1                 0.470588                    0.346154
# 778               1                 0.754717                    0.351852
# 841               0                 0.454545                    0.379310
# 852               1                 0.526316                    0.372881
# 871               1                 0.644068                    0.366667
# 913               0                 0.311475                    0.370968
# 925               1                 0.419355                    0.365079
#
#        diff_%
# 708  0.142857
# 716  0.108085
# 738  0.259304
# 755  0.124434
# 778  0.402865
# 841  0.075235
# 852  0.153434
# 871  0.277401
# 913 -0.059492
# 925  0.054275

# %%
calculated_df_2.loc[calculated_df_2['HOME_ABBR'] == home_user_input].tail(10)
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 503  2022-01-24       NOP          IND       5.8       3.4     2.4
# 533  2022-01-28       NOP          DEN      -6.2      -1.6    -4.6
# 539  2022-01-29       NOP          BOS     -14.2      -5.9    -8.3
# 614  2022-02-08       NOP          HOU      -1.2     -12.8    11.6
# 627  2022-02-10       NOP          MIA     -14.2       2.0   -16.2
# 642  2022-02-12       NOP          SAS       2.8       6.3    -3.5
# 658  2022-02-14       NOP          TOR       8.8     -22.6    31.4
# 667  2022-02-15       NOP          MEM      -2.2       1.3    -3.5
# 682  2022-02-17       NOP          DAL       6.8      16.4    -9.6
# 727  2022-03-02       NOP          SAC      13.8      -9.2    23.0
#
#      home_winning_percentage  visitor_winning_percentage    diff_%
# 503                 0.391304                    0.354167  0.037138
# 533                 0.375000                    0.562500 -0.187500
# 539                 0.367347                    0.509804 -0.142457
# 614                 0.407407                    0.277778  0.129630
# 627                 0.400000                    0.642857 -0.242857
# 642                 0.392857                    0.385965  0.006892
# 658                 0.403509                    0.553571 -0.150063
# 667                 0.396552                    0.694915 -0.298364
# 682                 0.389831                    0.593220 -0.203390
# 727                 0.419355                    0.365079  0.054275

# %%
calculated_df_2.loc[calculated_df_2['VISITOR_ABBR'] == visitor_user_input].tail(10)
# Out:
#            DATE HOME_ABBR VISITOR_ABBR  PTS_home  PTS_away  MARGIN  \
# 510  2022-01-25       BOS          SAC      17.5     -29.2    46.7
# 518  2022-01-26       ATL          SAC       0.6      -0.2     0.8
# 540  2022-01-29       PHI          SAC      -4.2      -3.2    -1.0
# 557  2022-01-31       NYK          SAC      10.0      -8.2    18.2
# 580  2022-02-03       GSW          SAC      12.3       9.8     2.5
# 643  2022-02-12       WAS          SAC       1.8      18.8   -17.0
# 654  2022-02-14       BRK          SAC       2.0     -19.2    21.2
# 673  2022-02-16       CHI          SAC       5.4      13.8    -8.4
# 715  2022-02-28       OKC          SAC       6.9      26.8   -19.9
# 727  2022-03-02       NOP          SAC      13.8      -9.2    23.0
#
#      home_winning_percentage  visitor_winning_percentage    diff_%
# 510                 0.510204                    0.367347  0.142857
# 518                 0.468085                    0.360000  0.108085
# 540                 0.612245                    0.352941  0.259304
# 557                 0.470588                    0.346154  0.124434
# 580                 0.754717                    0.351852  0.402865
# 643                 0.454545                    0.379310  0.075235
# 654                 0.526316                    0.372881  0.153434
# 673                 0.644068                    0.366667  0.277401
# 715                 0.311475                    0.370968 -0.059492
# 727                 0.419355                    0.365079  0.054275

# %%
home_df = calculated_df_2[calculated_df_2['HOME_ABBR'] == home_user_input]
home_df = home_df.round({"diff_%":1})
mean_grouped_home_df = home_df.groupby("diff_%").mean().reset_index()
mean_grouped_home_df
# Out:
#    diff_%  PTS_home   PTS_away     MARGIN  home_winning_percentage  \
# 0    -0.4 -4.000000  -7.620000   3.620000                 0.285780
# 1    -0.3 -4.200000   3.025000  -7.225000                 0.281757
# 2    -0.2 -0.866667  -1.033333   0.166667                 0.366505
# 3    -0.1  1.050000  -7.875000   8.925000                 0.364476
# 4     0.0  4.300000   4.850000  -0.550000                 0.392081
# 5     0.1  3.466667 -12.500000  15.966667                 0.370826
#
#    visitor_winning_percentage
# 0                    0.690057
# 1                    0.582102
# 2                    0.573397
# 3                    0.473058
# 4                    0.370066
# 5                    0.267619

# %%
visitor_df = calculated_df_2[calculated_df_2['VISITOR_ABBR'] == visitor_user_input]
visitor_df = visitor_df.round({"diff_%":1})
mean_grouped_visitor_df = visitor_df.groupby("diff_%").mean().reset_index()
mean_grouped_visitor_df
# Out:
#    diff_%   PTS_home  PTS_away     MARGIN  home_winning_percentage  \
# 0    -0.2  -0.400000      24.8 -25.200000                 0.230769
# 1    -0.1   6.900000      26.8 -19.900000                 0.311475
# 2    -0.0  -6.550000     -11.7   5.150000                 0.370879
# 3     0.1  10.941667       4.8   6.141667                 0.486875
# 4     0.2  10.433333       0.8   9.633333                 0.569996
# 5     0.3   0.600000       5.3  -4.700000                 0.628156
# 6     0.4   5.800000       1.8   4.000000                 0.780584
#
#    visitor_winning_percentage
# 0                    0.428571
# 1                    0.370968
# 2                    0.390476
# 3                    0.383882
# 4                    0.385096
# 5                    0.359804
# 6                    0.379051
